# %%
import os
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from torch.utils.data import Subset
import torch.optim as optim
import torch.nn.functional as F

# %%
torch.cuda.is_available()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
torch.cuda.device_count() # returns 1 in my case


if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)} is available.")
else:
    print("No GPU available. Training will run on CPU.")
# Out:
# cuda:0
# GPU: NVIDIA RTX A6000 is available.

# %%
# === CONFIG ===

CHUNK_SIZE = 16
NUM_FEATURES = 8
NUM_EPOCHS = 50
BATCH_SIZE = 32
K_FOLDS = 5
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# === HELPERS ===
def collate_fn(batch):
    streams, labels = zip(*batch)
    streams = list(zip(*streams))
    streams = [torch.stack(s) for s in streams]
    labels = torch.tensor(labels)
    return streams, labels

def compute_class_weights(labels, device):
    counter = Counter(labels)
    total = sum(counter.values())
    weights = [np.log(total / (counter[i] + 1)) for i in range(len(counter))]
    return torch.tensor(weights, dtype=torch.float).to(device)

def print_model_info(model):
    print("Model Architecture:")
    print(model)
    total_params = sum(p.numel() for p in model.parameters())
    print(f"Total parameters: {total_params:,}")

def plot_loss_curve(train_losses, val_losses):
    epochs = range(len(train_losses))
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_losses, label='Train Loss', color='blue')
    plt.plot(epochs, val_losses, label='Val Loss', color='orange')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training vs Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def plot_accuracy_curve(train_acc, val_acc):
    epochs = range(len(train_acc))
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, train_acc, label='Train Accuracy', color='green')
    plt.plot(epochs, val_acc, label='Val Accuracy', color='red')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# === DATASET CLASS ===
class MultiStreamDataset(Dataset):
    def __init__(self, data, labels, label_encoder, augment=False):
        self.data = data
        self.labels = label_encoder.transform(labels)
        self.augment = augment

    def __len__(self):
        return len(self.data)

    def augment_stream(self, stream):
        jitter = np.random.normal(0, 0.01, stream.shape)
        scale = np.random.normal(1.0, 0.05, stream.shape)
        return stream * scale + jitter

    def __getitem__(self, idx):
        sample = self.data[idx]
        # if idx == 0:
        #     print("🔍 Raw feature sample:")
        #     print(sample)
        #     print("Min:", sample.min(), "Max:", sample.max())
        streams = [sample[:, i].reshape(1, -1).astype(np.float32) for i in range(sample.shape[1])]
        if self.augment:
            streams = [self.augment_stream(s.copy()) for s in streams]
        streams = [torch.tensor(s).float() for s in streams]
        label = torch.tensor(self.labels[idx])
        return streams, label

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, dilation=1, dropout=0.1):
        super().__init__()
        self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size=3, padding=dilation, dilation=dilation)
        self.bn1 = nn.BatchNorm1d(out_channels)
        self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size=3, padding=dilation, dilation=dilation)
        self.bn2 = nn.BatchNorm1d(out_channels)
        self.dropout = nn.Dropout(dropout)
        self.downsample = nn.Conv1d(in_channels, out_channels, 1) if in_channels != out_channels else nn.Identity()

    def forward(self, x):
        identity = self.downsample(x)
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.dropout(self.bn2(self.conv2(out)))
        return F.relu(out + identity)

class MultiStreamCNN(nn.Module):
    def __init__(self, input_length=32, num_classes=12):
        super().__init__()
        self.streams = nn.ModuleList([
            nn.Sequential(
                ResidualBlock(1, 32),
                ResidualBlock(32, 64),
                ResidualBlock(64, 128),
                nn.MaxPool1d(2),
                ResidualBlock(128, 256, dilation=2),
                ResidualBlock(256, 256, dilation=2),
                nn.AdaptiveAvgPool1d(1),
                nn.Flatten()
            ) for _ in range(8)
        ])
        self.fc = nn.Sequential(
            nn.LayerNorm(256 * 8),
            nn.Linear(256 * 8, 512),
            nn.GELU(),
            nn.Dropout(0.4),
            nn.Linear(512, 256),
            nn.GELU(),
            nn.Dropout(0.4),
            nn.Linear(256, 128),   # ✅ extra
            nn.GELU(),             # ✅ extra
            nn.Linear(128, num_classes)
        )
        self.proj = nn.Linear(256 * 8, 128)  # ✅ New: for feature projection

    def forward(self, streams, return_features=False):
        features = [self.streams[i](streams[i]) for i in range(8)]
        x = torch.cat(features, dim=1)
        logits = self.fc(x)
        if return_features:
            feat_proj = self.proj(x)         # ✅ Project [B, 2048] → [B, 128]
            return logits, feat_proj
        return logits  # ✅ Fix: add this

# %%
# === COLLATE FUNCTION ===
def collate_fn(batch):
    streams, labels = zip(*batch)
    streams = list(zip(*streams))
    streams = [torch.stack(s) for s in streams]
    labels = torch.tensor(labels)
    return streams, labels

# === LOAD SPLIT FUNCTION ===
def load_split_from_folder(split_dir, expected_shape):
    X, y = [], []
    for class_name in sorted(os.listdir(split_dir)):
        class_path = os.path.join(split_dir, class_name)
        for fname in sorted(os.listdir(class_path)):
            if fname.endswith(".csv"):
                fpath = os.path.join(class_path, fname)
                chunk = pd.read_csv(fpath, header=None).values
                if chunk.shape == expected_shape:
                    X.append(chunk)
                    y.append(class_name)
    return np.array(X), np.array(y)

# %%
# # === APPLY SMOTE ===
# def apply_smote_on_training(X_chunks, y_labels, chunk_size, num_features):
#     label_encoder = LabelEncoder()
#     y_encoded = label_encoder.fit_transform(y_labels)

#     smote_encoder = LabelEncoder()
#     y_encoded_for_smote = smote_encoder.fit_transform(y_labels)

#     X_flat = X_chunks.reshape(X_chunks.shape[0], -1)
#     X_resampled, y_resampled = SMOTE().fit_resample(X_flat, y_encoded_for_smote)

#     X_res = X_resampled.reshape(-1, chunk_size, num_features)
#     y_res_str = smote_encoder.inverse_transform(y_resampled)

#     return X_res, y_res_str, label_encoder

# # === LOAD DATASETS ===
# expected_shape = (CHUNK_SIZE, NUM_FEATURES)

# X_train_raw, y_train_raw = load_split_from_folder(os.path.join(INPUT_DIR, "train"), expected_shape)
# X_val_raw,   y_val_raw   = load_split_from_folder(os.path.join(INPUT_DIR, "val"), expected_shape)

# # === SMOTE ONLY ON TRAIN ===
# X_train_balanced, y_train_str, label_encoder = apply_smote_on_training(
#     X_train_raw, y_train_raw, CHUNK_SIZE, NUM_FEATURES
# )

# # === CREATE DATASETS ===
# train_dataset = MultiStreamDataset(X_train_balanced, y_train_str, label_encoder, augment=True)
# val_dataset   = MultiStreamDataset(X_val_raw, y_val_raw, label_encoder, augment=False)

# train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)
# val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn)

# %%
# === CLASS WEIGHTING ===
def compute_class_weights(labels, device):
    from collections import Counter
    total = len(labels)
    counts = Counter(labels)
    weights = [np.log(total / (counts[i] + 1)) for i in range(len(counts))]
    return torch.tensor(weights, dtype=torch.float).to(device)

# class_weights_tensor = compute_class_weights(label_encoder.transform(y_train_str), device="cpu")

# %%
def train_model(model, train_loader, val_loader, device, epochs=50, lr=0.001,
                class_weights=None, optimizer=None, scheduler=None,
                best_model_path="best_model.pth"):

    print("🔍 Class Weights Tensor:")
    print(class_weights)

    criterion = nn.CrossEntropyLoss(weight=class_weights)
    if optimizer is None:
        optimizer = optim.Adam(model.parameters(), lr=lr)

    model.to(device)

    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    best_val_acc = 0
    printed_shape = False

    for epoch in range(epochs):
        model.train()
        total_loss, correct = 0, 0

        for streams, labels in train_loader:
            streams = [s.to(device) for s in streams]
            labels = labels.to(device)

            if not printed_shape:
                print("🔍 Shape of one stream sample:", streams[0].shape)
                printed_shape = True

            outputs = model(streams)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=5)
            optimizer.step()

            total_loss += loss.item()
            correct += (outputs.argmax(1) == labels).sum().item()

        train_acc = correct / len(train_loader.dataset)
        train_losses.append(total_loss / len(train_loader))
        train_accuracies.append(train_acc)

        # === Validation ===
        model.eval()
        val_loss, val_correct = 0, 0
        with torch.no_grad():
            for streams, labels in val_loader:
                streams = [s.to(device) for s in streams]
                labels = labels.to(device)

                outputs = model(streams)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                val_correct += (outputs.argmax(1) == labels).sum().item()

        val_acc = val_correct / len(val_loader.dataset)
        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(val_acc)

        print(f"Epoch {epoch+1}/{epochs} - Train Loss: {train_losses[-1]:.4f} - Val Loss: {val_losses[-1]:.4f} - Train Acc: {train_acc:.4f} - Val Acc: {val_acc:.4f}")

        if scheduler:
            scheduler.step()

        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), best_model_path)

    model.load_state_dict(torch.load(best_model_path))
    return train_accuracies, val_accuracies, train_losses, val_losses

# %%
# === UTILS ===
def load_split_from_folder(split_dir, expected_shape):
    X, y = [], []
    for class_name in sorted(os.listdir(split_dir)):
        class_path = os.path.join(split_dir, class_name)
        for fname in sorted(os.listdir(class_path)):
            if fname.endswith(".csv"):
                fpath = os.path.join(class_path, fname)
                chunk = pd.read_csv(fpath, header=None).values
                if chunk.shape == expected_shape:
                    X.append(chunk)
                    y.append(class_name)
    return np.array(X), np.array(y)

# %%
import os
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from torch.utils.data import DataLoader
from torch_lr_finder import LRFinder

# === Configuration ===
base_dir = "/home/HardDisk/Satang/thesis_proj"
save_root = "/home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher"
os.makedirs(save_root, exist_ok=True)

detection_times = [30, 45, 60]
window_sizes = [10, 15, 20]
NUM_EPOCHS = 50
BATCH_SIZE = 64
NUM_FEATURES = 8  # Use 5 if you’re experimenting with the original RanSAP features

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Loop through all combinations ===
for T_d in detection_times:
    for T_w in window_sizes:
        print(f"\n🚀 Running MultiStreamCNN Teacher for Td={T_d}, Tw={T_w}")
        T_len = T_d - T_w + 1
        expected_shape = (T_len, NUM_FEATURES)
        folder_name = f"X_csv_split_{T_len}"
        input_dir = os.path.join(base_dir, f"New_{T_d}", f"{T_w}", "split_tws", folder_name) # change "split_tws to your path name"
        train_path = os.path.join(input_dir, "train")
        val_path   = os.path.join(input_dir, "val")
        model_path = os.path.join(save_root, f"teacher_Td{T_d}_Tw{T_w}.pth")

        # === 1. Load Data ===
        X_train_raw, y_train_raw = load_split_from_folder(train_path, expected_shape)
        X_val_raw, y_val_raw     = load_split_from_folder(val_path, expected_shape)

        # === 2. SMOTE Balancing ===
        label_encoder = LabelEncoder()
        y_train_encoded = label_encoder.fit_transform(y_train_raw)
        X_train_flat = X_train_raw.reshape(X_train_raw.shape[0], -1)
        X_resampled, y_resampled = SMOTE().fit_resample(X_train_flat, y_train_encoded)
        X_train_bal = X_resampled.reshape(-1, T_len, NUM_FEATURES)
        y_train_str = label_encoder.inverse_transform(y_resampled)

        # === 3. Dataset & Loader ===
        train_dataset = MultiStreamDataset(X_train_bal, y_train_str, label_encoder, augment=True)
        val_dataset   = MultiStreamDataset(X_val_raw, y_val_raw, label_encoder, augment=False)
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

        # === 4. Class Weights ===
        class_weights_tensor = compute_class_weights(label_encoder.transform(y_train_str), device)

        # === 5. LR Finder ===
        print("🔍 Finding optimal learning rate...")
        model_for_lr = MultiStreamCNN(input_length=T_len, num_classes=len(label_encoder.classes_)).to(device)
        optimizer = torch.optim.AdamW(model_for_lr.parameters(), lr=1e-7, weight_decay=1e-4)
        criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
        lr_finder = LRFinder(model_for_lr, optimizer, criterion, device=device)
        lr_finder.range_test(train_loader, end_lr=1, num_iter=200)
        lr_finder.plot()
        lr_finder.reset()

        # === Choose LR Manually After Inspecting Plot ===
        BEST_LR = 0.001  # Replace with best LR found from the plot

        # === 6. Train Final Teacher ===
        final_teacher = MultiStreamCNN(input_length=T_len, num_classes=len(label_encoder.classes_)).to(device)
        optimizer = torch.optim.AdamW(final_teacher.parameters(), lr=BEST_LR, weight_decay=1e-4)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS)

        train_accs, val_accs, train_losses, val_losses = train_model(
            model=final_teacher,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            epochs=NUM_EPOCHS,
            class_weights=class_weights_tensor,
            lr=BEST_LR,
            optimizer=optimizer,
            scheduler=scheduler,
            best_model_path=model_path
        )

        print(f"✅ Model saved to {model_path}")
# Out:
# 🚀 Running MultiStreamCNN Teacher for Td=30, Tw=10
# 🔍 Finding optimal learning rate...
#  96%|█████████▌| 191/200 [00:14<00:00, 13.00it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 3.04E-04
# 🔍 Class Weights Tensor:
# tensor([2.4843, 2.4843, 2.4843, 2.4843, 2.4843, 2.4843, 2.4843, 2.4843, 2.4843,
#         2.4843, 2.4843, 2.4843], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 21])
# Epoch 1/50 - Train Loss: 0.6749 - Val Loss: 0.5228 - Train Acc: 0.7529 - Val Acc: 0.7811
# Epoch 2/50 - Train Loss: 0.4443 - Val Loss: 0.5118 - Train Acc: 0.8398 - Val Acc: 0.7921
# Epoch 3/50 - Train Loss: 0.3712 - Val Loss: 0.4425 - Train Acc: 0.8664 - Val Acc: 0.8377
# Epoch 4/50 - Train Loss: 0.3302 - Val Loss: 0.3457 - Train Acc: 0.8809 - Val Acc: 0.8783
# Epoch 5/50 - Train Loss: 0.3023 - Val Loss: 0.3072 - Train Acc: 0.8944 - Val Acc: 0.8858
# Epoch 6/50 - Train Loss: 0.2842 - Val Loss: 0.3296 - Train Acc: 0.8968 - Val Acc: 0.8712
# Epoch 7/50 - Train Loss: 0.2770 - Val Loss: 0.3384 - Train Acc: 0.9032 - Val Acc: 0.8737
# Epoch 8/50 - Train Loss: 0.2526 - Val Loss: 0.3052 - Train Acc: 0.9100 - Val Acc: 0.8793
# Epoch 9/50 - Train Loss: 0.2396 - Val Loss: 0.2914 - Train Acc: 0.9144 - Val Acc: 0.8943
# Epoch 10/50 - Train Loss: 0.2269 - Val Loss: 0.2706 - Train Acc: 0.9208 - Val Acc: 0.9008
# Epoch 11/50 - Train Loss: 0.2157 - Val Loss: 0.2575 - Train Acc: 0.9203 - Val Acc: 0.9088
# Epoch 12/50 - Train Loss: 0.2078 - Val Loss: 0.2954 - Train Acc: 0.9275 - Val Acc: 0.8913
# Epoch 13/50 - Train Loss: 0.1943 - Val Loss: 0.2274 - Train Acc: 0.9323 - Val Acc: 0.9193
# Epoch 14/50 - Train Loss: 0.1883 - Val Loss: 0.2639 - Train Acc: 0.9336 - Val Acc: 0.8993
# Epoch 15/50 - Train Loss: 0.1762 - Val Loss: 0.2873 - Train Acc: 0.9387 - Val Acc: 0.9008
# Epoch 16/50 - Train Loss: 0.1702 - Val Loss: 0.2934 - Train Acc: 0.9408 - Val Acc: 0.8878
# Epoch 17/50 - Train Loss: 0.1504 - Val Loss: 0.2714 - Train Acc: 0.9471 - Val Acc: 0.9128
# Epoch 18/50 - Train Loss: 0.1463 - Val Loss: 0.2641 - Train Acc: 0.9489 - Val Acc: 0.9173
# Epoch 19/50 - Train Loss: 0.1501 - Val Loss: 0.3050 - Train Acc: 0.9500 - Val Acc: 0.8873
# Epoch 20/50 - Train Loss: 0.1401 - Val Loss: 0.2113 - Train Acc: 0.9500 - Val Acc: 0.9178
# Epoch 21/50 - Train Loss: 0.1341 - Val Loss: 0.2693 - Train Acc: 0.9533 - Val Acc: 0.9038
# Epoch 22/50 - Train Loss: 0.1209 - Val Loss: 0.2274 - Train Acc: 0.9571 - Val Acc: 0.9183
# Epoch 23/50 - Train Loss: 0.1176 - Val Loss: 0.2265 - Train Acc: 0.9587 - Val Acc: 0.9188
# Epoch 24/50 - Train Loss: 0.1049 - Val Loss: 0.2058 - Train Acc: 0.9630 - Val Acc: 0.9339
# Epoch 25/50 - Train Loss: 0.1051 - Val Loss: 0.2469 - Train Acc: 0.9647 - Val Acc: 0.9233
# Epoch 26/50 - Train Loss: 0.1010 - Val Loss: 0.2092 - Train Acc: 0.9660 - Val Acc: 0.9274
# Epoch 27/50 - Train Loss: 0.0943 - Val Loss: 0.2015 - Train Acc: 0.9671 - Val Acc: 0.9314
# Epoch 28/50 - Train Loss: 0.0887 - Val Loss: 0.2275 - Train Acc: 0.9698 - Val Acc: 0.9304
# Epoch 29/50 - Train Loss: 0.0833 - Val Loss: 0.2098 - Train Acc: 0.9704 - Val Acc: 0.9309
# Epoch 30/50 - Train Loss: 0.0877 - Val Loss: 0.1886 - Train Acc: 0.9692 - Val Acc: 0.9359
# Epoch 31/50 - Train Loss: 0.0804 - Val Loss: 0.1867 - Train Acc: 0.9731 - Val Acc: 0.9404
# Epoch 32/50 - Train Loss: 0.0766 - Val Loss: 0.2005 - Train Acc: 0.9730 - Val Acc: 0.9359
# Epoch 33/50 - Train Loss: 0.0694 - Val Loss: 0.2393 - Train Acc: 0.9754 - Val Acc: 0.9183
# Epoch 34/50 - Train Loss: 0.0675 - Val Loss: 0.1978 - Train Acc: 0.9764 - Val Acc: 0.9374
# Epoch 35/50 - Train Loss: 0.0632 - Val Loss: 0.2065 - Train Acc: 0.9776 - Val Acc: 0.9329
# Epoch 36/50 - Train Loss: 0.0640 - Val Loss: 0.1933 - Train Acc: 0.9772 - Val Acc: 0.9384
# Epoch 37/50 - Train Loss: 0.0590 - Val Loss: 0.1774 - Train Acc: 0.9797 - Val Acc: 0.9429
# Epoch 38/50 - Train Loss: 0.0615 - Val Loss: 0.1871 - Train Acc: 0.9787 - Val Acc: 0.9424
# Epoch 39/50 - Train Loss: 0.0544 - Val Loss: 0.1817 - Train Acc: 0.9809 - Val Acc: 0.9399
# Epoch 40/50 - Train Loss: 0.0530 - Val Loss: 0.1948 - Train Acc: 0.9815 - Val Acc: 0.9399
# Epoch 41/50 - Train Loss: 0.0484 - Val Loss: 0.2023 - Train Acc: 0.9842 - Val Acc: 0.9364
# Epoch 42/50 - Train Loss: 0.0474 - Val Loss: 0.1753 - Train Acc: 0.9832 - Val Acc: 0.9434
# Epoch 43/50 - Train Loss: 0.0482 - Val Loss: 0.1905 - Train Acc: 0.9839 - Val Acc: 0.9404
# Epoch 44/50 - Train Loss: 0.0447 - Val Loss: 0.1769 - Train Acc: 0.9836 - Val Acc: 0.9449
# Epoch 45/50 - Train Loss: 0.0498 - Val Loss: 0.1882 - Train Acc: 0.9822 - Val Acc: 0.9414
# Epoch 46/50 - Train Loss: 0.0419 - Val Loss: 0.1802 - Train Acc: 0.9856 - Val Acc: 0.9434
# Epoch 47/50 - Train Loss: 0.0433 - Val Loss: 0.1839 - Train Acc: 0.9845 - Val Acc: 0.9439
# Epoch 48/50 - Train Loss: 0.0433 - Val Loss: 0.1801 - Train Acc: 0.9857 - Val Acc: 0.9429
# Epoch 49/50 - Train Loss: 0.0419 - Val Loss: 0.1876 - Train Acc: 0.9848 - Val Acc: 0.9419
# Epoch 50/50 - Train Loss: 0.0404 - Val Loss: 0.1821 - Train Acc: 0.9861 - Val Acc: 0.9444
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td30_Tw10.pth
#
# 🚀 Running MultiStreamCNN Teacher for Td=30, Tw=15
# 🔍 Finding optimal learning rate...
#  86%|████████▋ | 173/200 [00:14<00:02, 12.25it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 6.29E-04
# 🔍 Class Weights Tensor:
# tensor([2.4844, 2.4844, 2.4844, 2.4844, 2.4844, 2.4844, 2.4844, 2.4844, 2.4844,
#         2.4844, 2.4844, 2.4844], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 16])
# Epoch 1/50 - Train Loss: 0.6321 - Val Loss: 0.5305 - Train Acc: 0.7831 - Val Acc: 0.8068
# Epoch 2/50 - Train Loss: 0.3783 - Val Loss: 0.4901 - Train Acc: 0.8663 - Val Acc: 0.8185
# Epoch 3/50 - Train Loss: 0.3095 - Val Loss: 0.3727 - Train Acc: 0.8918 - Val Acc: 0.8565
# Epoch 4/50 - Train Loss: 0.2786 - Val Loss: 0.3572 - Train Acc: 0.9026 - Val Acc: 0.8751
# Epoch 5/50 - Train Loss: 0.2497 - Val Loss: 0.3179 - Train Acc: 0.9120 - Val Acc: 0.8850
# Epoch 6/50 - Train Loss: 0.2330 - Val Loss: 0.2631 - Train Acc: 0.9194 - Val Acc: 0.9077
# Epoch 7/50 - Train Loss: 0.2207 - Val Loss: 0.3183 - Train Acc: 0.9232 - Val Acc: 0.8948
# Epoch 8/50 - Train Loss: 0.1996 - Val Loss: 0.3055 - Train Acc: 0.9315 - Val Acc: 0.8888
# Epoch 9/50 - Train Loss: 0.1897 - Val Loss: 0.2723 - Train Acc: 0.9344 - Val Acc: 0.8983
# Epoch 10/50 - Train Loss: 0.1874 - Val Loss: 0.2864 - Train Acc: 0.9382 - Val Acc: 0.9021
# Epoch 11/50 - Train Loss: 0.1712 - Val Loss: 0.2824 - Train Acc: 0.9412 - Val Acc: 0.9002
# Epoch 12/50 - Train Loss: 0.1654 - Val Loss: 0.2320 - Train Acc: 0.9430 - Val Acc: 0.9199
# Epoch 13/50 - Train Loss: 0.1537 - Val Loss: 0.2554 - Train Acc: 0.9480 - Val Acc: 0.9176
# Epoch 14/50 - Train Loss: 0.1434 - Val Loss: 0.2245 - Train Acc: 0.9513 - Val Acc: 0.9229
# Epoch 15/50 - Train Loss: 0.1301 - Val Loss: 0.2629 - Train Acc: 0.9566 - Val Acc: 0.9184
# Epoch 16/50 - Train Loss: 0.1294 - Val Loss: 0.2206 - Train Acc: 0.9560 - Val Acc: 0.9252
# Epoch 17/50 - Train Loss: 0.1301 - Val Loss: 0.2234 - Train Acc: 0.9562 - Val Acc: 0.9252
# Epoch 18/50 - Train Loss: 0.1233 - Val Loss: 0.2324 - Train Acc: 0.9586 - Val Acc: 0.9244
# Epoch 19/50 - Train Loss: 0.1119 - Val Loss: 0.2516 - Train Acc: 0.9625 - Val Acc: 0.9180
# Epoch 20/50 - Train Loss: 0.1059 - Val Loss: 0.2449 - Train Acc: 0.9647 - Val Acc: 0.9176
# Epoch 21/50 - Train Loss: 0.1025 - Val Loss: 0.2258 - Train Acc: 0.9649 - Val Acc: 0.9188
# Epoch 22/50 - Train Loss: 0.0898 - Val Loss: 0.2165 - Train Acc: 0.9688 - Val Acc: 0.9336
# Epoch 23/50 - Train Loss: 0.0895 - Val Loss: 0.2084 - Train Acc: 0.9698 - Val Acc: 0.9385
# Epoch 24/50 - Train Loss: 0.0897 - Val Loss: 0.2087 - Train Acc: 0.9697 - Val Acc: 0.9301
# Epoch 25/50 - Train Loss: 0.0805 - Val Loss: 0.2077 - Train Acc: 0.9726 - Val Acc: 0.9358
# Epoch 26/50 - Train Loss: 0.0800 - Val Loss: 0.2188 - Train Acc: 0.9738 - Val Acc: 0.9317
# Epoch 27/50 - Train Loss: 0.0711 - Val Loss: 0.1902 - Train Acc: 0.9764 - Val Acc: 0.9389
# Epoch 28/50 - Train Loss: 0.0697 - Val Loss: 0.2114 - Train Acc: 0.9772 - Val Acc: 0.9339
# Epoch 29/50 - Train Loss: 0.0693 - Val Loss: 0.1812 - Train Acc: 0.9762 - Val Acc: 0.9431
# Epoch 30/50 - Train Loss: 0.0642 - Val Loss: 0.2087 - Train Acc: 0.9776 - Val Acc: 0.9381
# Epoch 31/50 - Train Loss: 0.0562 - Val Loss: 0.1932 - Train Acc: 0.9795 - Val Acc: 0.9415
# Epoch 32/50 - Train Loss: 0.0578 - Val Loss: 0.2116 - Train Acc: 0.9803 - Val Acc: 0.9366
# Epoch 33/50 - Train Loss: 0.0537 - Val Loss: 0.1938 - Train Acc: 0.9820 - Val Acc: 0.9446
# Epoch 34/50 - Train Loss: 0.0519 - Val Loss: 0.1913 - Train Acc: 0.9821 - Val Acc: 0.9465
# Epoch 35/50 - Train Loss: 0.0499 - Val Loss: 0.2197 - Train Acc: 0.9828 - Val Acc: 0.9412
# Epoch 36/50 - Train Loss: 0.0468 - Val Loss: 0.1946 - Train Acc: 0.9838 - Val Acc: 0.9419
# Epoch 37/50 - Train Loss: 0.0419 - Val Loss: 0.1963 - Train Acc: 0.9855 - Val Acc: 0.9491
# Epoch 38/50 - Train Loss: 0.0429 - Val Loss: 0.1990 - Train Acc: 0.9840 - Val Acc: 0.9442
# Epoch 39/50 - Train Loss: 0.0399 - Val Loss: 0.1896 - Train Acc: 0.9863 - Val Acc: 0.9480
# Epoch 40/50 - Train Loss: 0.0405 - Val Loss: 0.1883 - Train Acc: 0.9859 - Val Acc: 0.9472
# Epoch 41/50 - Train Loss: 0.0372 - Val Loss: 0.1848 - Train Acc: 0.9867 - Val Acc: 0.9495
# Epoch 42/50 - Train Loss: 0.0344 - Val Loss: 0.1966 - Train Acc: 0.9876 - Val Acc: 0.9457
# Epoch 43/50 - Train Loss: 0.0350 - Val Loss: 0.1990 - Train Acc: 0.9878 - Val Acc: 0.9476
# Epoch 44/50 - Train Loss: 0.0357 - Val Loss: 0.1907 - Train Acc: 0.9877 - Val Acc: 0.9468
# Epoch 45/50 - Train Loss: 0.0375 - Val Loss: 0.1917 - Train Acc: 0.9875 - Val Acc: 0.9491
# Epoch 46/50 - Train Loss: 0.0376 - Val Loss: 0.2055 - Train Acc: 0.9875 - Val Acc: 0.9484
# Epoch 47/50 - Train Loss: 0.0318 - Val Loss: 0.1977 - Train Acc: 0.9888 - Val Acc: 0.9484
# Epoch 48/50 - Train Loss: 0.0342 - Val Loss: 0.1982 - Train Acc: 0.9879 - Val Acc: 0.9461
# Epoch 49/50 - Train Loss: 0.0340 - Val Loss: 0.1969 - Train Acc: 0.9895 - Val Acc: 0.9491
# Epoch 50/50 - Train Loss: 0.0320 - Val Loss: 0.2069 - Train Acc: 0.9887 - Val Acc: 0.9461
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td30_Tw15.pth
#
# 🚀 Running MultiStreamCNN Teacher for Td=30, Tw=20
# 🔍 Finding optimal learning rate...
#  86%|████████▌ | 172/200 [00:14<00:02, 11.93it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 8.03E-04
# 🔍 Class Weights Tensor:
# tensor([2.4847, 2.4847, 2.4847, 2.4847, 2.4847, 2.4847, 2.4847, 2.4847, 2.4847,
#         2.4847, 2.4847, 2.4847], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 11])
# Epoch 1/50 - Train Loss: 0.5486 - Val Loss: 0.4386 - Train Acc: 0.8099 - Val Acc: 0.8417
# Epoch 2/50 - Train Loss: 0.3240 - Val Loss: 0.4639 - Train Acc: 0.8877 - Val Acc: 0.8514
# Epoch 3/50 - Train Loss: 0.2700 - Val Loss: 0.4150 - Train Acc: 0.9074 - Val Acc: 0.8641
# Epoch 4/50 - Train Loss: 0.2414 - Val Loss: 0.3526 - Train Acc: 0.9153 - Val Acc: 0.8683
# Epoch 5/50 - Train Loss: 0.2140 - Val Loss: 0.2996 - Train Acc: 0.9273 - Val Acc: 0.8901
# Epoch 6/50 - Train Loss: 0.1930 - Val Loss: 0.2511 - Train Acc: 0.9338 - Val Acc: 0.9122
# Epoch 7/50 - Train Loss: 0.1844 - Val Loss: 0.2840 - Train Acc: 0.9373 - Val Acc: 0.9021
# Epoch 8/50 - Train Loss: 0.1697 - Val Loss: 0.2901 - Train Acc: 0.9437 - Val Acc: 0.9000
# Epoch 9/50 - Train Loss: 0.1558 - Val Loss: 0.3167 - Train Acc: 0.9479 - Val Acc: 0.9033
# Epoch 10/50 - Train Loss: 0.1467 - Val Loss: 0.2882 - Train Acc: 0.9499 - Val Acc: 0.9052
# Epoch 11/50 - Train Loss: 0.1340 - Val Loss: 0.2750 - Train Acc: 0.9557 - Val Acc: 0.9073
# Epoch 12/50 - Train Loss: 0.1304 - Val Loss: 0.2889 - Train Acc: 0.9568 - Val Acc: 0.9185
# Epoch 13/50 - Train Loss: 0.1248 - Val Loss: 0.2977 - Train Acc: 0.9588 - Val Acc: 0.9096
# Epoch 14/50 - Train Loss: 0.1149 - Val Loss: 0.3136 - Train Acc: 0.9614 - Val Acc: 0.9231
# Epoch 15/50 - Train Loss: 0.1080 - Val Loss: 0.2590 - Train Acc: 0.9635 - Val Acc: 0.9193
# Epoch 16/50 - Train Loss: 0.1092 - Val Loss: 0.2864 - Train Acc: 0.9650 - Val Acc: 0.9214
# Epoch 17/50 - Train Loss: 0.0999 - Val Loss: 0.2602 - Train Acc: 0.9664 - Val Acc: 0.9270
# Epoch 18/50 - Train Loss: 0.0937 - Val Loss: 0.2463 - Train Acc: 0.9687 - Val Acc: 0.9247
# Epoch 19/50 - Train Loss: 0.0869 - Val Loss: 0.2837 - Train Acc: 0.9710 - Val Acc: 0.9226
# Epoch 20/50 - Train Loss: 0.0895 - Val Loss: 0.2462 - Train Acc: 0.9705 - Val Acc: 0.9275
# Epoch 21/50 - Train Loss: 0.0808 - Val Loss: 0.2195 - Train Acc: 0.9734 - Val Acc: 0.9340
# Epoch 22/50 - Train Loss: 0.0770 - Val Loss: 0.2273 - Train Acc: 0.9741 - Val Acc: 0.9329
# Epoch 23/50 - Train Loss: 0.0729 - Val Loss: 0.2716 - Train Acc: 0.9755 - Val Acc: 0.9252
# Epoch 24/50 - Train Loss: 0.0706 - Val Loss: 0.2671 - Train Acc: 0.9763 - Val Acc: 0.9285
# Epoch 25/50 - Train Loss: 0.0653 - Val Loss: 0.2488 - Train Acc: 0.9776 - Val Acc: 0.9354
# Epoch 26/50 - Train Loss: 0.0617 - Val Loss: 0.2582 - Train Acc: 0.9791 - Val Acc: 0.9285
# Epoch 27/50 - Train Loss: 0.0561 - Val Loss: 0.2438 - Train Acc: 0.9804 - Val Acc: 0.9373
# Epoch 28/50 - Train Loss: 0.0571 - Val Loss: 0.2702 - Train Acc: 0.9809 - Val Acc: 0.9275
# Epoch 29/50 - Train Loss: 0.0547 - Val Loss: 0.2651 - Train Acc: 0.9814 - Val Acc: 0.9329
# Epoch 30/50 - Train Loss: 0.0521 - Val Loss: 0.2751 - Train Acc: 0.9812 - Val Acc: 0.9314
# Epoch 31/50 - Train Loss: 0.0504 - Val Loss: 0.2615 - Train Acc: 0.9833 - Val Acc: 0.9327
# Epoch 32/50 - Train Loss: 0.0464 - Val Loss: 0.2710 - Train Acc: 0.9840 - Val Acc: 0.9340
# Epoch 33/50 - Train Loss: 0.0459 - Val Loss: 0.2611 - Train Acc: 0.9842 - Val Acc: 0.9346
# Epoch 34/50 - Train Loss: 0.0467 - Val Loss: 0.2522 - Train Acc: 0.9849 - Val Acc: 0.9371
# Epoch 35/50 - Train Loss: 0.0425 - Val Loss: 0.2578 - Train Acc: 0.9851 - Val Acc: 0.9363
# Epoch 36/50 - Train Loss: 0.0423 - Val Loss: 0.2757 - Train Acc: 0.9863 - Val Acc: 0.9321
# Epoch 37/50 - Train Loss: 0.0377 - Val Loss: 0.2756 - Train Acc: 0.9873 - Val Acc: 0.9335
# Epoch 38/50 - Train Loss: 0.0415 - Val Loss: 0.2707 - Train Acc: 0.9868 - Val Acc: 0.9327
# Epoch 39/50 - Train Loss: 0.0367 - Val Loss: 0.2381 - Train Acc: 0.9874 - Val Acc: 0.9413
# Epoch 40/50 - Train Loss: 0.0340 - Val Loss: 0.2506 - Train Acc: 0.9879 - Val Acc: 0.9388
# Epoch 41/50 - Train Loss: 0.0343 - Val Loss: 0.2713 - Train Acc: 0.9880 - Val Acc: 0.9405
# Epoch 42/50 - Train Loss: 0.0331 - Val Loss: 0.2526 - Train Acc: 0.9887 - Val Acc: 0.9405
# Epoch 43/50 - Train Loss: 0.0330 - Val Loss: 0.2937 - Train Acc: 0.9891 - Val Acc: 0.9344
# Epoch 44/50 - Train Loss: 0.0316 - Val Loss: 0.2629 - Train Acc: 0.9886 - Val Acc: 0.9377
# Epoch 45/50 - Train Loss: 0.0304 - Val Loss: 0.2689 - Train Acc: 0.9899 - Val Acc: 0.9380
# Epoch 46/50 - Train Loss: 0.0293 - Val Loss: 0.2560 - Train Acc: 0.9893 - Val Acc: 0.9409
# Epoch 47/50 - Train Loss: 0.0303 - Val Loss: 0.2617 - Train Acc: 0.9894 - Val Acc: 0.9400
# Epoch 48/50 - Train Loss: 0.0302 - Val Loss: 0.2649 - Train Acc: 0.9895 - Val Acc: 0.9398
# Epoch 49/50 - Train Loss: 0.0308 - Val Loss: 0.2808 - Train Acc: 0.9894 - Val Acc: 0.9365
# Epoch 50/50 - Train Loss: 0.0293 - Val Loss: 0.2597 - Train Acc: 0.9898 - Val Acc: 0.9409
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td30_Tw20.pth
#
# 🚀 Running MultiStreamCNN Teacher for Td=45, Tw=10
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# 🔍 Finding optimal learning rate...
#  88%|████████▊ | 177/200 [00:14<00:01, 11.91it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.12E-01
# 🔍 Class Weights Tensor:
# tensor([2.4837, 2.4837, 2.4837, 2.4837, 2.4837, 2.4837, 2.4837, 2.4837, 2.4837,
#         2.4837, 2.4837, 2.4837], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 36])
# Epoch 1/50 - Train Loss: 0.6251 - Val Loss: 0.6234 - Train Acc: 0.7901 - Val Acc: 0.7645
# Epoch 2/50 - Train Loss: 0.3329 - Val Loss: 0.4413 - Train Acc: 0.8855 - Val Acc: 0.8343
# Epoch 3/50 - Train Loss: 0.2437 - Val Loss: 0.4530 - Train Acc: 0.9124 - Val Acc: 0.8547
# Epoch 4/50 - Train Loss: 0.2655 - Val Loss: 0.3533 - Train Acc: 0.9284 - Val Acc: 0.8837
# Epoch 5/50 - Train Loss: 0.1947 - Val Loss: 0.3704 - Train Acc: 0.9339 - Val Acc: 0.8837
# Epoch 6/50 - Train Loss: 0.2597 - Val Loss: 0.3138 - Train Acc: 0.9364 - Val Acc: 0.9070
# Epoch 7/50 - Train Loss: 0.1645 - Val Loss: 0.3354 - Train Acc: 0.9454 - Val Acc: 0.9041
# Epoch 8/50 - Train Loss: 0.1846 - Val Loss: 0.2632 - Train Acc: 0.9440 - Val Acc: 0.9041
# Epoch 9/50 - Train Loss: 0.1349 - Val Loss: 0.2012 - Train Acc: 0.9535 - Val Acc: 0.9205
# Epoch 10/50 - Train Loss: 0.1471 - Val Loss: 0.2836 - Train Acc: 0.9553 - Val Acc: 0.9050
# Epoch 11/50 - Train Loss: 0.1181 - Val Loss: 0.3713 - Train Acc: 0.9613 - Val Acc: 0.8760
# Epoch 12/50 - Train Loss: 0.1680 - Val Loss: 0.2868 - Train Acc: 0.9624 - Val Acc: 0.9050
# Epoch 13/50 - Train Loss: 0.1002 - Val Loss: 0.2888 - Train Acc: 0.9662 - Val Acc: 0.9118
# Epoch 14/50 - Train Loss: 0.0976 - Val Loss: 0.2299 - Train Acc: 0.9704 - Val Acc: 0.9186
# Epoch 15/50 - Train Loss: 0.1184 - Val Loss: 0.2358 - Train Acc: 0.9675 - Val Acc: 0.9360
# Epoch 16/50 - Train Loss: 0.1069 - Val Loss: 0.2476 - Train Acc: 0.9705 - Val Acc: 0.9264
# Epoch 17/50 - Train Loss: 0.0873 - Val Loss: 0.1936 - Train Acc: 0.9736 - Val Acc: 0.9409
# Epoch 18/50 - Train Loss: 0.0751 - Val Loss: 0.2408 - Train Acc: 0.9782 - Val Acc: 0.9322
# Epoch 19/50 - Train Loss: 0.0845 - Val Loss: 0.2266 - Train Acc: 0.9746 - Val Acc: 0.9341
# Epoch 20/50 - Train Loss: 0.0846 - Val Loss: 0.2039 - Train Acc: 0.9761 - Val Acc: 0.9351
# Epoch 21/50 - Train Loss: 0.0811 - Val Loss: 0.2794 - Train Acc: 0.9764 - Val Acc: 0.9244
# Epoch 22/50 - Train Loss: 0.0674 - Val Loss: 0.1997 - Train Acc: 0.9795 - Val Acc: 0.9390
# Epoch 23/50 - Train Loss: 0.0666 - Val Loss: 0.2771 - Train Acc: 0.9808 - Val Acc: 0.9254
# Epoch 24/50 - Train Loss: 0.0629 - Val Loss: 0.1863 - Train Acc: 0.9829 - Val Acc: 0.9428
# Epoch 25/50 - Train Loss: 0.0967 - Val Loss: 0.1948 - Train Acc: 0.9845 - Val Acc: 0.9380
# Epoch 26/50 - Train Loss: 0.0603 - Val Loss: 0.1752 - Train Acc: 0.9831 - Val Acc: 0.9516
# Epoch 27/50 - Train Loss: 0.0352 - Val Loss: 0.2046 - Train Acc: 0.9886 - Val Acc: 0.9486
# Epoch 28/50 - Train Loss: 0.0381 - Val Loss: 0.2160 - Train Acc: 0.9880 - Val Acc: 0.9419
# Epoch 29/50 - Train Loss: 0.0635 - Val Loss: 0.1852 - Train Acc: 0.9896 - Val Acc: 0.9467
# Epoch 30/50 - Train Loss: 0.0350 - Val Loss: 0.1826 - Train Acc: 0.9901 - Val Acc: 0.9496
# Epoch 31/50 - Train Loss: 0.0420 - Val Loss: 0.1622 - Train Acc: 0.9892 - Val Acc: 0.9535
# Epoch 32/50 - Train Loss: 0.0443 - Val Loss: 0.1626 - Train Acc: 0.9892 - Val Acc: 0.9535
# Epoch 33/50 - Train Loss: 0.0467 - Val Loss: 0.1716 - Train Acc: 0.9910 - Val Acc: 0.9516
# Epoch 34/50 - Train Loss: 0.0227 - Val Loss: 0.1824 - Train Acc: 0.9923 - Val Acc: 0.9486
# Epoch 35/50 - Train Loss: 0.0316 - Val Loss: 0.2195 - Train Acc: 0.9940 - Val Acc: 0.9428
# Epoch 36/50 - Train Loss: 0.0368 - Val Loss: 0.1944 - Train Acc: 0.9927 - Val Acc: 0.9545
# Epoch 37/50 - Train Loss: 0.0382 - Val Loss: 0.1934 - Train Acc: 0.9931 - Val Acc: 0.9525
# Epoch 38/50 - Train Loss: 0.0250 - Val Loss: 0.1970 - Train Acc: 0.9933 - Val Acc: 0.9516
# Epoch 39/50 - Train Loss: 0.0301 - Val Loss: 0.2113 - Train Acc: 0.9939 - Val Acc: 0.9448
# Epoch 40/50 - Train Loss: 0.0164 - Val Loss: 0.1963 - Train Acc: 0.9948 - Val Acc: 0.9496
# Epoch 41/50 - Train Loss: 0.0309 - Val Loss: 0.2087 - Train Acc: 0.9959 - Val Acc: 0.9486
# Epoch 42/50 - Train Loss: 0.0290 - Val Loss: 0.1925 - Train Acc: 0.9951 - Val Acc: 0.9467
# Epoch 43/50 - Train Loss: 0.0174 - Val Loss: 0.2098 - Train Acc: 0.9953 - Val Acc: 0.9496
# Epoch 44/50 - Train Loss: 0.0279 - Val Loss: 0.2264 - Train Acc: 0.9950 - Val Acc: 0.9467
# Epoch 45/50 - Train Loss: 0.0372 - Val Loss: 0.2114 - Train Acc: 0.9949 - Val Acc: 0.9486
# Epoch 46/50 - Train Loss: 0.0212 - Val Loss: 0.1874 - Train Acc: 0.9953 - Val Acc: 0.9525
# Epoch 47/50 - Train Loss: 0.0637 - Val Loss: 0.1722 - Train Acc: 0.9955 - Val Acc: 0.9583
# Epoch 48/50 - Train Loss: 0.0235 - Val Loss: 0.1902 - Train Acc: 0.9957 - Val Acc: 0.9564
# Epoch 49/50 - Train Loss: 0.0237 - Val Loss: 0.1728 - Train Acc: 0.9957 - Val Acc: 0.9564
# Epoch 50/50 - Train Loss: 0.0339 - Val Loss: 0.1697 - Train Acc: 0.9950 - Val Acc: 0.9535
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td45_Tw10.pth
#
# 🚀 Running MultiStreamCNN Teacher for Td=45, Tw=15
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# 🔍 Finding optimal learning rate...
#  90%|█████████ | 180/200 [00:16<00:01, 10.94it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.22E-01
# 🔍 Class Weights Tensor:
# tensor([2.4840, 2.4840, 2.4840, 2.4840, 2.4840, 2.4840, 2.4840, 2.4840, 2.4840,
#         2.4840, 2.4840, 2.4840], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 31])
# Epoch 1/50 - Train Loss: 0.5532 - Val Loss: 0.4092 - Train Acc: 0.8119 - Val Acc: 0.8532
# Epoch 2/50 - Train Loss: 0.3021 - Val Loss: 0.7319 - Train Acc: 0.8947 - Val Acc: 0.7962
# Epoch 3/50 - Train Loss: 0.2397 - Val Loss: 0.3603 - Train Acc: 0.9155 - Val Acc: 0.8751
# Epoch 4/50 - Train Loss: 0.2214 - Val Loss: 0.3027 - Train Acc: 0.9246 - Val Acc: 0.8977
# Epoch 5/50 - Train Loss: 0.1822 - Val Loss: 0.2508 - Train Acc: 0.9372 - Val Acc: 0.9058
# Epoch 6/50 - Train Loss: 0.1820 - Val Loss: 0.3130 - Train Acc: 0.9404 - Val Acc: 0.8985
# Epoch 7/50 - Train Loss: 0.1519 - Val Loss: 0.2418 - Train Acc: 0.9488 - Val Acc: 0.9160
# Epoch 8/50 - Train Loss: 0.1419 - Val Loss: 0.2138 - Train Acc: 0.9517 - Val Acc: 0.9357
# Epoch 9/50 - Train Loss: 0.1204 - Val Loss: 0.2961 - Train Acc: 0.9602 - Val Acc: 0.8934
# Epoch 10/50 - Train Loss: 0.1189 - Val Loss: 0.1843 - Train Acc: 0.9589 - Val Acc: 0.9357
# Epoch 11/50 - Train Loss: 0.1160 - Val Loss: 0.2246 - Train Acc: 0.9621 - Val Acc: 0.9226
# Epoch 12/50 - Train Loss: 0.0950 - Val Loss: 0.2130 - Train Acc: 0.9672 - Val Acc: 0.9372
# Epoch 13/50 - Train Loss: 0.1022 - Val Loss: 0.1812 - Train Acc: 0.9664 - Val Acc: 0.9350
# Epoch 14/50 - Train Loss: 0.1006 - Val Loss: 0.2213 - Train Acc: 0.9680 - Val Acc: 0.9284
# Epoch 15/50 - Train Loss: 0.0858 - Val Loss: 0.2087 - Train Acc: 0.9718 - Val Acc: 0.9357
# Epoch 16/50 - Train Loss: 0.0787 - Val Loss: 0.2498 - Train Acc: 0.9731 - Val Acc: 0.9328
# Epoch 17/50 - Train Loss: 0.0817 - Val Loss: 0.1815 - Train Acc: 0.9745 - Val Acc: 0.9379
# Epoch 18/50 - Train Loss: 0.0747 - Val Loss: 0.1890 - Train Acc: 0.9743 - Val Acc: 0.9430
# Epoch 19/50 - Train Loss: 0.0621 - Val Loss: 0.2024 - Train Acc: 0.9807 - Val Acc: 0.9364
# Epoch 20/50 - Train Loss: 0.0637 - Val Loss: 0.1679 - Train Acc: 0.9791 - Val Acc: 0.9467
# Epoch 21/50 - Train Loss: 0.0634 - Val Loss: 0.3208 - Train Acc: 0.9800 - Val Acc: 0.9335
# Epoch 22/50 - Train Loss: 0.0639 - Val Loss: 0.1632 - Train Acc: 0.9791 - Val Acc: 0.9489
# Epoch 23/50 - Train Loss: 0.0524 - Val Loss: 0.2003 - Train Acc: 0.9835 - Val Acc: 0.9350
# Epoch 24/50 - Train Loss: 0.0515 - Val Loss: 0.1923 - Train Acc: 0.9844 - Val Acc: 0.9416
# Epoch 25/50 - Train Loss: 0.0402 - Val Loss: 0.1672 - Train Acc: 0.9884 - Val Acc: 0.9474
# Epoch 26/50 - Train Loss: 0.0474 - Val Loss: 0.1770 - Train Acc: 0.9850 - Val Acc: 0.9511
# Epoch 27/50 - Train Loss: 0.0380 - Val Loss: 0.1380 - Train Acc: 0.9882 - Val Acc: 0.9562
# Epoch 28/50 - Train Loss: 0.0432 - Val Loss: 0.1471 - Train Acc: 0.9857 - Val Acc: 0.9562
# Epoch 29/50 - Train Loss: 0.0361 - Val Loss: 0.1467 - Train Acc: 0.9885 - Val Acc: 0.9562
# Epoch 30/50 - Train Loss: 0.0343 - Val Loss: 0.1835 - Train Acc: 0.9891 - Val Acc: 0.9547
# Epoch 31/50 - Train Loss: 0.0279 - Val Loss: 0.1878 - Train Acc: 0.9915 - Val Acc: 0.9525
# Epoch 32/50 - Train Loss: 0.0257 - Val Loss: 0.1774 - Train Acc: 0.9915 - Val Acc: 0.9547
# Epoch 33/50 - Train Loss: 0.0257 - Val Loss: 0.1654 - Train Acc: 0.9913 - Val Acc: 0.9511
# Epoch 34/50 - Train Loss: 0.0227 - Val Loss: 0.1868 - Train Acc: 0.9932 - Val Acc: 0.9503
# Epoch 35/50 - Train Loss: 0.0200 - Val Loss: 0.1638 - Train Acc: 0.9937 - Val Acc: 0.9569
# Epoch 36/50 - Train Loss: 0.0202 - Val Loss: 0.1415 - Train Acc: 0.9941 - Val Acc: 0.9620
# Epoch 37/50 - Train Loss: 0.0183 - Val Loss: 0.1815 - Train Acc: 0.9944 - Val Acc: 0.9576
# Epoch 38/50 - Train Loss: 0.0164 - Val Loss: 0.1365 - Train Acc: 0.9942 - Val Acc: 0.9598
# Epoch 39/50 - Train Loss: 0.0200 - Val Loss: 0.1572 - Train Acc: 0.9941 - Val Acc: 0.9591
# Epoch 40/50 - Train Loss: 0.0155 - Val Loss: 0.1630 - Train Acc: 0.9949 - Val Acc: 0.9540
# Epoch 41/50 - Train Loss: 0.0130 - Val Loss: 0.1545 - Train Acc: 0.9958 - Val Acc: 0.9576
# Epoch 42/50 - Train Loss: 0.0133 - Val Loss: 0.1563 - Train Acc: 0.9953 - Val Acc: 0.9606
# Epoch 43/50 - Train Loss: 0.0104 - Val Loss: 0.1614 - Train Acc: 0.9968 - Val Acc: 0.9598
# Epoch 44/50 - Train Loss: 0.0131 - Val Loss: 0.1633 - Train Acc: 0.9957 - Val Acc: 0.9576
# Epoch 45/50 - Train Loss: 0.0131 - Val Loss: 0.1630 - Train Acc: 0.9964 - Val Acc: 0.9620
# Epoch 46/50 - Train Loss: 0.0112 - Val Loss: 0.1650 - Train Acc: 0.9960 - Val Acc: 0.9598
# Epoch 47/50 - Train Loss: 0.0130 - Val Loss: 0.1581 - Train Acc: 0.9961 - Val Acc: 0.9620
# Epoch 48/50 - Train Loss: 0.0114 - Val Loss: 0.1628 - Train Acc: 0.9970 - Val Acc: 0.9584
# Epoch 49/50 - Train Loss: 0.0119 - Val Loss: 0.1624 - Train Acc: 0.9961 - Val Acc: 0.9591
# Epoch 50/50 - Train Loss: 0.0099 - Val Loss: 0.1608 - Train Acc: 0.9967 - Val Acc: 0.9606
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td45_Tw15.pth
#
# 🚀 Running MultiStreamCNN Teacher for Td=45, Tw=20
# 🔍 Finding optimal learning rate...
#  92%|█████████▏| 184/200 [00:14<00:01, 12.33it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.68E-01
# 🔍 Class Weights Tensor:
# tensor([2.4841, 2.4841, 2.4841, 2.4841, 2.4841, 2.4841, 2.4841, 2.4841, 2.4841,
#         2.4841, 2.4841, 2.4841], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 26])
# Epoch 1/50 - Train Loss: 0.5850 - Val Loss: 0.6090 - Train Acc: 0.7960 - Val Acc: 0.7754
# Epoch 2/50 - Train Loss: 0.3320 - Val Loss: 0.3786 - Train Acc: 0.8810 - Val Acc: 0.8732
# Epoch 3/50 - Train Loss: 0.2739 - Val Loss: 0.4242 - Train Acc: 0.9035 - Val Acc: 0.8479
# Epoch 4/50 - Train Loss: 0.2271 - Val Loss: 0.3469 - Train Acc: 0.9195 - Val Acc: 0.8953
# Epoch 5/50 - Train Loss: 0.2041 - Val Loss: 0.2626 - Train Acc: 0.9307 - Val Acc: 0.9104
# Epoch 6/50 - Train Loss: 0.1880 - Val Loss: 0.3602 - Train Acc: 0.9361 - Val Acc: 0.8795
# Epoch 7/50 - Train Loss: 0.1627 - Val Loss: 0.2876 - Train Acc: 0.9445 - Val Acc: 0.8946
# Epoch 8/50 - Train Loss: 0.1509 - Val Loss: 0.2973 - Train Acc: 0.9487 - Val Acc: 0.8965
# Epoch 9/50 - Train Loss: 0.1581 - Val Loss: 0.3060 - Train Acc: 0.9449 - Val Acc: 0.8972
# Epoch 10/50 - Train Loss: 0.1422 - Val Loss: 0.2636 - Train Acc: 0.9524 - Val Acc: 0.9186
# Epoch 11/50 - Train Loss: 0.1205 - Val Loss: 0.2413 - Train Acc: 0.9588 - Val Acc: 0.9281
# Epoch 12/50 - Train Loss: 0.1197 - Val Loss: 0.2521 - Train Acc: 0.9609 - Val Acc: 0.9300
# Epoch 13/50 - Train Loss: 0.1103 - Val Loss: 0.2777 - Train Acc: 0.9622 - Val Acc: 0.9047
# Epoch 14/50 - Train Loss: 0.1098 - Val Loss: 0.2922 - Train Acc: 0.9634 - Val Acc: 0.9047
# Epoch 15/50 - Train Loss: 0.1012 - Val Loss: 0.3276 - Train Acc: 0.9676 - Val Acc: 0.8997
# Epoch 16/50 - Train Loss: 0.0937 - Val Loss: 0.2213 - Train Acc: 0.9675 - Val Acc: 0.9338
# Epoch 17/50 - Train Loss: 0.0905 - Val Loss: 0.2342 - Train Acc: 0.9702 - Val Acc: 0.9319
# Epoch 18/50 - Train Loss: 0.0886 - Val Loss: 0.2137 - Train Acc: 0.9714 - Val Acc: 0.9438
# Epoch 19/50 - Train Loss: 0.0763 - Val Loss: 0.1746 - Train Acc: 0.9741 - Val Acc: 0.9413
# Epoch 20/50 - Train Loss: 0.0756 - Val Loss: 0.2408 - Train Acc: 0.9761 - Val Acc: 0.9274
# Epoch 21/50 - Train Loss: 0.0708 - Val Loss: 0.2272 - Train Acc: 0.9780 - Val Acc: 0.9382
# Epoch 22/50 - Train Loss: 0.0632 - Val Loss: 0.2711 - Train Acc: 0.9797 - Val Acc: 0.9256
# Epoch 23/50 - Train Loss: 0.0601 - Val Loss: 0.2082 - Train Acc: 0.9799 - Val Acc: 0.9338
# Epoch 24/50 - Train Loss: 0.0568 - Val Loss: 0.2287 - Train Acc: 0.9812 - Val Acc: 0.9287
# Epoch 25/50 - Train Loss: 0.0468 - Val Loss: 0.2056 - Train Acc: 0.9841 - Val Acc: 0.9350
# Epoch 26/50 - Train Loss: 0.0480 - Val Loss: 0.2211 - Train Acc: 0.9847 - Val Acc: 0.9394
# Epoch 27/50 - Train Loss: 0.0440 - Val Loss: 0.2811 - Train Acc: 0.9857 - Val Acc: 0.9319
# Epoch 28/50 - Train Loss: 0.0471 - Val Loss: 0.2237 - Train Acc: 0.9849 - Val Acc: 0.9331
# Epoch 29/50 - Train Loss: 0.0422 - Val Loss: 0.2043 - Train Acc: 0.9855 - Val Acc: 0.9451
# Epoch 30/50 - Train Loss: 0.0378 - Val Loss: 0.2684 - Train Acc: 0.9875 - Val Acc: 0.9356
# Epoch 31/50 - Train Loss: 0.0321 - Val Loss: 0.2068 - Train Acc: 0.9897 - Val Acc: 0.9445
# Epoch 32/50 - Train Loss: 0.0306 - Val Loss: 0.2072 - Train Acc: 0.9902 - Val Acc: 0.9483
# Epoch 33/50 - Train Loss: 0.0299 - Val Loss: 0.2586 - Train Acc: 0.9898 - Val Acc: 0.9388
# Epoch 34/50 - Train Loss: 0.0291 - Val Loss: 0.2093 - Train Acc: 0.9902 - Val Acc: 0.9457
# Epoch 35/50 - Train Loss: 0.0227 - Val Loss: 0.2255 - Train Acc: 0.9926 - Val Acc: 0.9464
# Epoch 36/50 - Train Loss: 0.0256 - Val Loss: 0.1864 - Train Acc: 0.9919 - Val Acc: 0.9527
# Epoch 37/50 - Train Loss: 0.0245 - Val Loss: 0.2101 - Train Acc: 0.9917 - Val Acc: 0.9476
# Epoch 38/50 - Train Loss: 0.0221 - Val Loss: 0.2346 - Train Acc: 0.9926 - Val Acc: 0.9438
# Epoch 39/50 - Train Loss: 0.0207 - Val Loss: 0.2290 - Train Acc: 0.9930 - Val Acc: 0.9451
# Epoch 40/50 - Train Loss: 0.0202 - Val Loss: 0.2534 - Train Acc: 0.9928 - Val Acc: 0.9426
# Epoch 41/50 - Train Loss: 0.0188 - Val Loss: 0.2083 - Train Acc: 0.9926 - Val Acc: 0.9476
# Epoch 42/50 - Train Loss: 0.0182 - Val Loss: 0.2029 - Train Acc: 0.9939 - Val Acc: 0.9514
# Epoch 43/50 - Train Loss: 0.0148 - Val Loss: 0.2125 - Train Acc: 0.9948 - Val Acc: 0.9489
# Epoch 44/50 - Train Loss: 0.0181 - Val Loss: 0.2101 - Train Acc: 0.9943 - Val Acc: 0.9489
# Epoch 45/50 - Train Loss: 0.0152 - Val Loss: 0.2166 - Train Acc: 0.9952 - Val Acc: 0.9502
# Epoch 46/50 - Train Loss: 0.0141 - Val Loss: 0.2062 - Train Acc: 0.9951 - Val Acc: 0.9483
# Epoch 47/50 - Train Loss: 0.0160 - Val Loss: 0.2116 - Train Acc: 0.9947 - Val Acc: 0.9489
# Epoch 48/50 - Train Loss: 0.0160 - Val Loss: 0.2177 - Train Acc: 0.9946 - Val Acc: 0.9470
# Epoch 49/50 - Train Loss: 0.0136 - Val Loss: 0.2098 - Train Acc: 0.9958 - Val Acc: 0.9502
# Epoch 50/50 - Train Loss: 0.0138 - Val Loss: 0.2096 - Train Acc: 0.9953 - Val Acc: 0.9495
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td45_Tw20.pth
#
# 🚀 Running MultiStreamCNN Teacher for Td=60, Tw=10
# 🔍 Finding optimal learning rate...
#  90%|████████▉ | 179/200 [00:14<00:01, 12.08it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 2.38E-04
# 🔍 Class Weights Tensor:
# tensor([2.4832, 2.4832, 2.4832, 2.4832, 2.4832, 2.4832, 2.4832, 2.4832, 2.4832,
#         2.4832, 2.4832, 2.4832], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 51])
# Epoch 1/50 - Train Loss: 0.5795 - Val Loss: 0.4947 - Train Acc: 0.8048 - Val Acc: 0.8064
# Epoch 2/50 - Train Loss: 0.2663 - Val Loss: 0.3797 - Train Acc: 0.9032 - Val Acc: 0.8748
# Epoch 3/50 - Train Loss: 0.2320 - Val Loss: 0.5111 - Train Acc: 0.9161 - Val Acc: 0.8326
# Epoch 4/50 - Train Loss: 0.1797 - Val Loss: 0.3445 - Train Acc: 0.9360 - Val Acc: 0.8792
# Epoch 5/50 - Train Loss: 0.1453 - Val Loss: 0.3989 - Train Acc: 0.9517 - Val Acc: 0.8574
# Epoch 6/50 - Train Loss: 0.1615 - Val Loss: 0.2230 - Train Acc: 0.9464 - Val Acc: 0.9491
# Epoch 7/50 - Train Loss: 0.1286 - Val Loss: 0.3327 - Train Acc: 0.9572 - Val Acc: 0.9141
# Epoch 8/50 - Train Loss: 0.1412 - Val Loss: 0.2700 - Train Acc: 0.9541 - Val Acc: 0.9272
# Epoch 9/50 - Train Loss: 0.1065 - Val Loss: 0.2940 - Train Acc: 0.9649 - Val Acc: 0.9127
# Epoch 10/50 - Train Loss: 0.0928 - Val Loss: 0.3104 - Train Acc: 0.9668 - Val Acc: 0.9039
# Epoch 11/50 - Train Loss: 0.0879 - Val Loss: 0.5258 - Train Acc: 0.9702 - Val Acc: 0.8777
# Epoch 12/50 - Train Loss: 0.0866 - Val Loss: 0.2618 - Train Acc: 0.9726 - Val Acc: 0.9301
# Epoch 13/50 - Train Loss: 0.0809 - Val Loss: 0.2261 - Train Acc: 0.9733 - Val Acc: 0.9301
# Epoch 14/50 - Train Loss: 0.0752 - Val Loss: 0.2060 - Train Acc: 0.9776 - Val Acc: 0.9389
# Epoch 15/50 - Train Loss: 0.0695 - Val Loss: 0.2174 - Train Acc: 0.9772 - Val Acc: 0.9403
# Epoch 16/50 - Train Loss: 0.0480 - Val Loss: 0.2025 - Train Acc: 0.9855 - Val Acc: 0.9549
# Epoch 17/50 - Train Loss: 0.0661 - Val Loss: 0.2060 - Train Acc: 0.9814 - Val Acc: 0.9461
# Epoch 18/50 - Train Loss: 0.0651 - Val Loss: 0.1926 - Train Acc: 0.9797 - Val Acc: 0.9476
# Epoch 19/50 - Train Loss: 0.0427 - Val Loss: 0.1637 - Train Acc: 0.9858 - Val Acc: 0.9622
# Epoch 20/50 - Train Loss: 0.0469 - Val Loss: 0.1368 - Train Acc: 0.9868 - Val Acc: 0.9651
# Epoch 21/50 - Train Loss: 0.0448 - Val Loss: 0.1572 - Train Acc: 0.9868 - Val Acc: 0.9607
# Epoch 22/50 - Train Loss: 0.0350 - Val Loss: 0.1940 - Train Acc: 0.9889 - Val Acc: 0.9520
# Epoch 23/50 - Train Loss: 0.0278 - Val Loss: 0.1855 - Train Acc: 0.9901 - Val Acc: 0.9636
# Epoch 24/50 - Train Loss: 0.0265 - Val Loss: 0.2349 - Train Acc: 0.9911 - Val Acc: 0.9520
# Epoch 25/50 - Train Loss: 0.0312 - Val Loss: 0.1838 - Train Acc: 0.9900 - Val Acc: 0.9636
# Epoch 26/50 - Train Loss: 0.0253 - Val Loss: 0.2408 - Train Acc: 0.9912 - Val Acc: 0.9476
# Epoch 27/50 - Train Loss: 0.0345 - Val Loss: 0.1313 - Train Acc: 0.9919 - Val Acc: 0.9563
# Epoch 28/50 - Train Loss: 0.0324 - Val Loss: 0.1211 - Train Acc: 0.9896 - Val Acc: 0.9651
# Epoch 29/50 - Train Loss: 0.0179 - Val Loss: 0.1550 - Train Acc: 0.9949 - Val Acc: 0.9578
# Epoch 30/50 - Train Loss: 0.0207 - Val Loss: 0.1835 - Train Acc: 0.9937 - Val Acc: 0.9694
# Epoch 31/50 - Train Loss: 0.0160 - Val Loss: 0.2030 - Train Acc: 0.9954 - Val Acc: 0.9563
# Epoch 32/50 - Train Loss: 0.0270 - Val Loss: 0.1271 - Train Acc: 0.9932 - Val Acc: 0.9665
# Epoch 33/50 - Train Loss: 0.0191 - Val Loss: 0.1818 - Train Acc: 0.9954 - Val Acc: 0.9651
# Epoch 34/50 - Train Loss: 0.0164 - Val Loss: 0.1591 - Train Acc: 0.9950 - Val Acc: 0.9709
# Epoch 35/50 - Train Loss: 0.0181 - Val Loss: 0.1447 - Train Acc: 0.9946 - Val Acc: 0.9680
# Epoch 36/50 - Train Loss: 0.0121 - Val Loss: 0.1518 - Train Acc: 0.9965 - Val Acc: 0.9694
# Epoch 37/50 - Train Loss: 0.0154 - Val Loss: 0.1595 - Train Acc: 0.9958 - Val Acc: 0.9680
# Epoch 38/50 - Train Loss: 0.0108 - Val Loss: 0.1311 - Train Acc: 0.9968 - Val Acc: 0.9680
# Epoch 39/50 - Train Loss: 0.0127 - Val Loss: 0.1308 - Train Acc: 0.9964 - Val Acc: 0.9680
# Epoch 40/50 - Train Loss: 0.0079 - Val Loss: 0.1368 - Train Acc: 0.9976 - Val Acc: 0.9753
# Epoch 41/50 - Train Loss: 0.0071 - Val Loss: 0.1486 - Train Acc: 0.9974 - Val Acc: 0.9709
# Epoch 42/50 - Train Loss: 0.0104 - Val Loss: 0.1435 - Train Acc: 0.9975 - Val Acc: 0.9723
# Epoch 43/50 - Train Loss: 0.0091 - Val Loss: 0.1415 - Train Acc: 0.9972 - Val Acc: 0.9694
# Epoch 44/50 - Train Loss: 0.0079 - Val Loss: 0.1421 - Train Acc: 0.9976 - Val Acc: 0.9709
# Epoch 45/50 - Train Loss: 0.0060 - Val Loss: 0.1421 - Train Acc: 0.9986 - Val Acc: 0.9709
# Epoch 46/50 - Train Loss: 0.0069 - Val Loss: 0.1425 - Train Acc: 0.9979 - Val Acc: 0.9709
# Epoch 47/50 - Train Loss: 0.0054 - Val Loss: 0.1442 - Train Acc: 0.9986 - Val Acc: 0.9694
# Epoch 48/50 - Train Loss: 0.0056 - Val Loss: 0.1439 - Train Acc: 0.9985 - Val Acc: 0.9709
# Epoch 49/50 - Train Loss: 0.0045 - Val Loss: 0.1476 - Train Acc: 0.9985 - Val Acc: 0.9694
# Epoch 50/50 - Train Loss: 0.0069 - Val Loss: 0.1434 - Train Acc: 0.9982 - Val Acc: 0.9709
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td60_Tw10.pth
#
# 🚀 Running MultiStreamCNN Teacher for Td=60, Tw=15
# 🔍 Finding optimal learning rate...
#  88%|████████▊ | 177/200 [00:15<00:01, 11.72it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 2.80E-04
# 🔍 Class Weights Tensor:
# tensor([2.4834, 2.4834, 2.4834, 2.4834, 2.4834, 2.4834, 2.4834, 2.4834, 2.4834,
#         2.4834, 2.4834, 2.4834], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 46])
# Epoch 1/50 - Train Loss: 0.5383 - Val Loss: 0.5793 - Train Acc: 0.8251 - Val Acc: 0.7747
# Epoch 2/50 - Train Loss: 0.2731 - Val Loss: 0.7993 - Train Acc: 0.9076 - Val Acc: 0.8608
# Epoch 3/50 - Train Loss: 0.2049 - Val Loss: 0.2764 - Train Acc: 0.9311 - Val Acc: 0.8924
# Epoch 4/50 - Train Loss: 0.1695 - Val Loss: 0.3523 - Train Acc: 0.9407 - Val Acc: 0.8949
# Epoch 5/50 - Train Loss: 0.1651 - Val Loss: 0.3211 - Train Acc: 0.9435 - Val Acc: 0.9051
# Epoch 6/50 - Train Loss: 0.1270 - Val Loss: 0.2556 - Train Acc: 0.9594 - Val Acc: 0.9165
# Epoch 7/50 - Train Loss: 0.1205 - Val Loss: 0.2859 - Train Acc: 0.9589 - Val Acc: 0.9215
# Epoch 8/50 - Train Loss: 0.1104 - Val Loss: 0.2478 - Train Acc: 0.9630 - Val Acc: 0.9291
# Epoch 9/50 - Train Loss: 0.1012 - Val Loss: 0.1416 - Train Acc: 0.9673 - Val Acc: 0.9544
# Epoch 10/50 - Train Loss: 0.0964 - Val Loss: 0.2017 - Train Acc: 0.9655 - Val Acc: 0.9392
# Epoch 11/50 - Train Loss: 0.1052 - Val Loss: 0.1217 - Train Acc: 0.9679 - Val Acc: 0.9620
# Epoch 12/50 - Train Loss: 0.0870 - Val Loss: 0.2592 - Train Acc: 0.9685 - Val Acc: 0.9190
# Epoch 13/50 - Train Loss: 0.0720 - Val Loss: 0.1954 - Train Acc: 0.9768 - Val Acc: 0.9481
# Epoch 14/50 - Train Loss: 0.0769 - Val Loss: 0.1706 - Train Acc: 0.9766 - Val Acc: 0.9405
# Epoch 15/50 - Train Loss: 0.0779 - Val Loss: 0.1498 - Train Acc: 0.9763 - Val Acc: 0.9430
# Epoch 16/50 - Train Loss: 0.0650 - Val Loss: 0.2379 - Train Acc: 0.9803 - Val Acc: 0.9405
# Epoch 17/50 - Train Loss: 0.0580 - Val Loss: 0.1994 - Train Acc: 0.9823 - Val Acc: 0.9468
# Epoch 18/50 - Train Loss: 0.0541 - Val Loss: 0.2970 - Train Acc: 0.9826 - Val Acc: 0.9228
# Epoch 19/50 - Train Loss: 0.0550 - Val Loss: 0.1873 - Train Acc: 0.9828 - Val Acc: 0.9468
# Epoch 20/50 - Train Loss: 0.0456 - Val Loss: 0.2537 - Train Acc: 0.9852 - Val Acc: 0.9506
# Epoch 21/50 - Train Loss: 0.0415 - Val Loss: 0.1838 - Train Acc: 0.9877 - Val Acc: 0.9494
# Epoch 22/50 - Train Loss: 0.0386 - Val Loss: 0.1782 - Train Acc: 0.9881 - Val Acc: 0.9418
# Epoch 23/50 - Train Loss: 0.0406 - Val Loss: 0.1693 - Train Acc: 0.9881 - Val Acc: 0.9456
# Epoch 24/50 - Train Loss: 0.0385 - Val Loss: 0.1556 - Train Acc: 0.9883 - Val Acc: 0.9595
# Epoch 25/50 - Train Loss: 0.0320 - Val Loss: 0.1230 - Train Acc: 0.9901 - Val Acc: 0.9519
# Epoch 26/50 - Train Loss: 0.0373 - Val Loss: 0.1246 - Train Acc: 0.9893 - Val Acc: 0.9633
# Epoch 27/50 - Train Loss: 0.0333 - Val Loss: 0.1285 - Train Acc: 0.9892 - Val Acc: 0.9620
# Epoch 28/50 - Train Loss: 0.0246 - Val Loss: 0.1637 - Train Acc: 0.9932 - Val Acc: 0.9608
# Epoch 29/50 - Train Loss: 0.0253 - Val Loss: 0.1788 - Train Acc: 0.9927 - Val Acc: 0.9544
# Epoch 30/50 - Train Loss: 0.0232 - Val Loss: 0.1577 - Train Acc: 0.9927 - Val Acc: 0.9544
# Epoch 31/50 - Train Loss: 0.0232 - Val Loss: 0.1674 - Train Acc: 0.9926 - Val Acc: 0.9582
# Epoch 32/50 - Train Loss: 0.0211 - Val Loss: 0.1372 - Train Acc: 0.9935 - Val Acc: 0.9608
# Epoch 33/50 - Train Loss: 0.0195 - Val Loss: 0.1580 - Train Acc: 0.9937 - Val Acc: 0.9633
# Epoch 34/50 - Train Loss: 0.0164 - Val Loss: 0.1637 - Train Acc: 0.9945 - Val Acc: 0.9608
# Epoch 35/50 - Train Loss: 0.0145 - Val Loss: 0.1838 - Train Acc: 0.9949 - Val Acc: 0.9570
# Epoch 36/50 - Train Loss: 0.0134 - Val Loss: 0.1586 - Train Acc: 0.9960 - Val Acc: 0.9620
# Epoch 37/50 - Train Loss: 0.0105 - Val Loss: 0.1589 - Train Acc: 0.9966 - Val Acc: 0.9633
# Epoch 38/50 - Train Loss: 0.0104 - Val Loss: 0.1624 - Train Acc: 0.9966 - Val Acc: 0.9658
# Epoch 39/50 - Train Loss: 0.0108 - Val Loss: 0.1795 - Train Acc: 0.9966 - Val Acc: 0.9557
# Epoch 40/50 - Train Loss: 0.0150 - Val Loss: 0.1610 - Train Acc: 0.9952 - Val Acc: 0.9608
# Epoch 41/50 - Train Loss: 0.0080 - Val Loss: 0.1711 - Train Acc: 0.9972 - Val Acc: 0.9620
# Epoch 42/50 - Train Loss: 0.0073 - Val Loss: 0.1522 - Train Acc: 0.9976 - Val Acc: 0.9620
# Epoch 43/50 - Train Loss: 0.0079 - Val Loss: 0.1617 - Train Acc: 0.9967 - Val Acc: 0.9646
# Epoch 44/50 - Train Loss: 0.0075 - Val Loss: 0.1610 - Train Acc: 0.9974 - Val Acc: 0.9633
# Epoch 45/50 - Train Loss: 0.0058 - Val Loss: 0.1866 - Train Acc: 0.9979 - Val Acc: 0.9582
# Epoch 46/50 - Train Loss: 0.0085 - Val Loss: 0.1766 - Train Acc: 0.9976 - Val Acc: 0.9582
# Epoch 47/50 - Train Loss: 0.0085 - Val Loss: 0.1852 - Train Acc: 0.9976 - Val Acc: 0.9582
# Epoch 48/50 - Train Loss: 0.0079 - Val Loss: 0.1890 - Train Acc: 0.9977 - Val Acc: 0.9570
# Epoch 49/50 - Train Loss: 0.0050 - Val Loss: 0.1815 - Train Acc: 0.9989 - Val Acc: 0.9608
# Epoch 50/50 - Train Loss: 0.0065 - Val Loss: 0.1953 - Train Acc: 0.9979 - Val Acc: 0.9582
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td60_Tw15.pth
#
# 🚀 Running MultiStreamCNN Teacher for Td=60, Tw=20
# 🔍 Finding optimal learning rate...
#  90%|█████████ | 180/200 [00:16<00:01, 11.25it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 3.87E-04
# 🔍 Class Weights Tensor:
# tensor([2.4835, 2.4835, 2.4835, 2.4835, 2.4835, 2.4835, 2.4835, 2.4835, 2.4835,
#         2.4835, 2.4835, 2.4835], device='cuda:0')
# 🔍 Shape of one stream sample: torch.Size([64, 1, 41])
# Epoch 1/50 - Train Loss: 0.5817 - Val Loss: 0.5308 - Train Acc: 0.8011 - Val Acc: 0.7693
# Epoch 2/50 - Train Loss: 0.2797 - Val Loss: 0.6155 - Train Acc: 0.8942 - Val Acc: 0.7916
# Epoch 3/50 - Train Loss: 0.2351 - Val Loss: 0.3760 - Train Acc: 0.9166 - Val Acc: 0.8841
# Epoch 4/50 - Train Loss: 0.1869 - Val Loss: 0.3207 - Train Acc: 0.9344 - Val Acc: 0.8501
# Epoch 5/50 - Train Loss: 0.1666 - Val Loss: 0.2245 - Train Acc: 0.9394 - Val Acc: 0.9169
# Epoch 6/50 - Train Loss: 0.1530 - Val Loss: 0.3651 - Train Acc: 0.9455 - Val Acc: 0.8653
# Epoch 7/50 - Train Loss: 0.1253 - Val Loss: 0.3023 - Train Acc: 0.9572 - Val Acc: 0.8993
# Epoch 8/50 - Train Loss: 0.1555 - Val Loss: 0.2802 - Train Acc: 0.9496 - Val Acc: 0.8946
# Epoch 9/50 - Train Loss: 0.1205 - Val Loss: 0.3471 - Train Acc: 0.9599 - Val Acc: 0.8899
# Epoch 10/50 - Train Loss: 0.1003 - Val Loss: 0.3307 - Train Acc: 0.9656 - Val Acc: 0.8946
# Epoch 11/50 - Train Loss: 0.0935 - Val Loss: 0.2231 - Train Acc: 0.9685 - Val Acc: 0.9192
# Epoch 12/50 - Train Loss: 0.1100 - Val Loss: 0.2858 - Train Acc: 0.9664 - Val Acc: 0.9180
# Epoch 13/50 - Train Loss: 0.0897 - Val Loss: 0.2795 - Train Acc: 0.9720 - Val Acc: 0.9157
# Epoch 14/50 - Train Loss: 0.0786 - Val Loss: 0.2822 - Train Acc: 0.9729 - Val Acc: 0.9110
# Epoch 15/50 - Train Loss: 0.0809 - Val Loss: 0.1941 - Train Acc: 0.9756 - Val Acc: 0.9368
# Epoch 16/50 - Train Loss: 0.0800 - Val Loss: 0.1895 - Train Acc: 0.9745 - Val Acc: 0.9403
# Epoch 17/50 - Train Loss: 0.0597 - Val Loss: 0.1957 - Train Acc: 0.9808 - Val Acc: 0.9450
# Epoch 18/50 - Train Loss: 0.0658 - Val Loss: 0.2654 - Train Acc: 0.9786 - Val Acc: 0.9333
# Epoch 19/50 - Train Loss: 0.0724 - Val Loss: 0.2052 - Train Acc: 0.9778 - Val Acc: 0.9368
# Epoch 20/50 - Train Loss: 0.0517 - Val Loss: 0.2852 - Train Acc: 0.9835 - Val Acc: 0.9297
# Epoch 21/50 - Train Loss: 0.0585 - Val Loss: 0.2374 - Train Acc: 0.9829 - Val Acc: 0.9450
# Epoch 22/50 - Train Loss: 0.0490 - Val Loss: 0.1817 - Train Acc: 0.9857 - Val Acc: 0.9485
# Epoch 23/50 - Train Loss: 0.0463 - Val Loss: 0.2043 - Train Acc: 0.9863 - Val Acc: 0.9461
# Epoch 24/50 - Train Loss: 0.0418 - Val Loss: 0.2254 - Train Acc: 0.9878 - Val Acc: 0.9368
# Epoch 25/50 - Train Loss: 0.0406 - Val Loss: 0.1761 - Train Acc: 0.9878 - Val Acc: 0.9496
# Epoch 26/50 - Train Loss: 0.0435 - Val Loss: 0.1851 - Train Acc: 0.9866 - Val Acc: 0.9461
# Epoch 27/50 - Train Loss: 0.0308 - Val Loss: 0.2424 - Train Acc: 0.9902 - Val Acc: 0.9403
# Epoch 28/50 - Train Loss: 0.0344 - Val Loss: 0.2375 - Train Acc: 0.9900 - Val Acc: 0.9426
# Epoch 29/50 - Train Loss: 0.0304 - Val Loss: 0.2164 - Train Acc: 0.9908 - Val Acc: 0.9461
# Epoch 30/50 - Train Loss: 0.0273 - Val Loss: 0.1673 - Train Acc: 0.9916 - Val Acc: 0.9532
# Epoch 31/50 - Train Loss: 0.0212 - Val Loss: 0.1777 - Train Acc: 0.9936 - Val Acc: 0.9508
# Epoch 32/50 - Train Loss: 0.0196 - Val Loss: 0.1918 - Train Acc: 0.9945 - Val Acc: 0.9438
# Epoch 33/50 - Train Loss: 0.0164 - Val Loss: 0.2435 - Train Acc: 0.9948 - Val Acc: 0.9403
# Epoch 34/50 - Train Loss: 0.0178 - Val Loss: 0.1508 - Train Acc: 0.9946 - Val Acc: 0.9578
# Epoch 35/50 - Train Loss: 0.0195 - Val Loss: 0.1532 - Train Acc: 0.9945 - Val Acc: 0.9614
# Epoch 36/50 - Train Loss: 0.0128 - Val Loss: 0.1820 - Train Acc: 0.9959 - Val Acc: 0.9590
# Epoch 37/50 - Train Loss: 0.0139 - Val Loss: 0.1680 - Train Acc: 0.9957 - Val Acc: 0.9637
# Epoch 38/50 - Train Loss: 0.0118 - Val Loss: 0.1773 - Train Acc: 0.9962 - Val Acc: 0.9578
# Epoch 39/50 - Train Loss: 0.0142 - Val Loss: 0.1879 - Train Acc: 0.9954 - Val Acc: 0.9520
# Epoch 40/50 - Train Loss: 0.0178 - Val Loss: 0.1799 - Train Acc: 0.9951 - Val Acc: 0.9543
# Epoch 41/50 - Train Loss: 0.0107 - Val Loss: 0.1701 - Train Acc: 0.9969 - Val Acc: 0.9567
# Epoch 42/50 - Train Loss: 0.0113 - Val Loss: 0.1623 - Train Acc: 0.9965 - Val Acc: 0.9590
# Epoch 43/50 - Train Loss: 0.0131 - Val Loss: 0.1839 - Train Acc: 0.9958 - Val Acc: 0.9567
# Epoch 44/50 - Train Loss: 0.0106 - Val Loss: 0.1854 - Train Acc: 0.9968 - Val Acc: 0.9555
# Epoch 45/50 - Train Loss: 0.0072 - Val Loss: 0.1791 - Train Acc: 0.9976 - Val Acc: 0.9555
# Epoch 46/50 - Train Loss: 0.0085 - Val Loss: 0.1705 - Train Acc: 0.9974 - Val Acc: 0.9578
# Epoch 47/50 - Train Loss: 0.0073 - Val Loss: 0.1749 - Train Acc: 0.9980 - Val Acc: 0.9602
# Epoch 48/50 - Train Loss: 0.0057 - Val Loss: 0.1743 - Train Acc: 0.9981 - Val Acc: 0.9590
# Epoch 49/50 - Train Loss: 0.0079 - Val Loss: 0.1651 - Train Acc: 0.9976 - Val Acc: 0.9578
# Epoch 50/50 - Train Loss: 0.0090 - Val Loss: 0.1781 - Train Acc: 0.9974 - Val Acc: 0.9590
# /tmp/ipykernel_2377727/2455991897.py:74: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))
# ✅ Model saved to /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher_Td60_Tw20.pth

# %%
# === 🔍 Plot training curves
plot_loss_curve(train_losses, val_losses)
plot_accuracy_curve(train_accs, val_accs)

# === 📊 Evaluate on validation set (same used during training)
final_teacher.eval()
all_preds, all_labels = [], []
with torch.no_grad():
    for streams, labels in val_loader:
        streams = [s.to(device) for s in streams]
        labels = labels.to(device)
        outputs = final_teacher(streams)
        preds = torch.argmax(outputs, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# === Confusion Matrix & Report
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Teacher Model - Confusion Matrix (Validation Set)')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

print("\nFinal Classification Report (Teacher):\n")
print(classification_report(all_labels, all_preds, target_names=label_encoder.classes_))

print(f"\nFinal Training Accuracy: {train_accs[-1]:.4f}")
print(f"Final Validation Accuracy: {val_accs[-1]:.4f}")
# Out:
# Final Classification Report (Teacher):
#
#               precision    recall  f1-score   support
#
#     AESCrypt       1.00      1.00      1.00        28
#       Cerber       1.00      0.95      0.98        84
#     Darkside       1.00      0.90      0.95       154
#        Excel       1.00      1.00      1.00        61
#      Firefox       0.99      1.00      0.99        91
#    GandCrab4       0.91      0.97      0.94       151
#         Ryuk       0.91      0.94      0.93        88
#      SDelete       1.00      1.00      1.00        24
#   Sodinokibi       0.98      0.97      0.97        91
#   TeslaCrypt       0.85      1.00      0.92        28
#     WannaCry       1.00      1.00      1.00        25
#          Zip       1.00      1.00      1.00        29
#
#     accuracy                           0.96       854
#    macro avg       0.97      0.98      0.97       854
# weighted avg       0.97      0.96      0.96       854
#
#
# Final Training Accuracy: 0.9974
# Final Validation Accuracy: 0.9590

# %%
from sklearn.metrics import roc_auc_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

# === 1. Get predictions on validation set ===
final_teacher.eval()
y_true = []
y_probs = []

with torch.no_grad():
    for streams, labels in val_loader:
        streams = [s.to(device) for s in streams]
        labels = labels.cpu().numpy()
        outputs = final_teacher(streams)
        probs = torch.softmax(outputs, dim=1).cpu().numpy()
        
        y_probs.extend(probs)
        y_true.extend(labels)

y_true = np.array(y_true)
y_probs = np.array(y_probs)

# === 2. Binarize labels for ROC AUC ===
y_true_bin = label_binarize(y_true, classes=range(len(label_encoder.classes_)))

# === 3. Compute AUC score (macro-average) ===
auc_macro = roc_auc_score(y_true_bin, y_probs, average="macro", multi_class="ovr")
print(f"🧠 Multi-class AUC (macro): {auc_macro:.4f}")

# === 4. Plot ROC curves per class ===
plt.figure(figsize=(10, 8))
for i in range(len(label_encoder.classes_)):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{label_encoder.classes_[i]} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], "k--", lw=2)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - Multi-Class Teacher Model")
plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 🧠 Multi-class AUC (macro): 0.9992

# %%
import torch
import torch.nn as nn
import time
import os
import psutil
import copy
from thop import profile

# === Profiling functions using clean model copies ===
def get_stream_macs_params(stream, CHUNK_SIZE):
    dummy_input = torch.randn(1, 1, CHUNK_SIZE)
    stream_copy = copy.deepcopy(stream)
    macs, params = profile(stream_copy, inputs=(dummy_input,), verbose=False)
    return macs, params

def get_linear_macs_params(layer, in_features):
    dummy_input = torch.randn(1, in_features)
    layer_copy = copy.deepcopy(layer)
    macs, params = profile(layer_copy, inputs=(dummy_input,), verbose=False)
    return macs, params

# === Utility functions ===
def get_model_size(model):
    temp_path = "temp_model.pth"
    torch.save(model.state_dict(), temp_path)
    size_mb = os.path.getsize(temp_path) / (1024 ** 2)
    os.remove(temp_path)
    return size_mb

def measure_latency(model, inputs, n_runs=100):
    model.eval()
    with torch.no_grad():
        start = time.time()
        for _ in range(n_runs):
            model(inputs)
        end = time.time()
    return (end - start) / n_runs * 1000

def measure_cpu_usage(model, inputs, duration=2):
    model.eval()
    process = psutil.Process(os.getpid())
    num_cpus = psutil.cpu_count(logical=True)
    _ = process.cpu_percent(interval=None)
    with torch.no_grad():
        start_time = time.time()
        while time.time() - start_time < duration:
            model(inputs)
    total_cpu_percent = process.cpu_percent(interval=None)
    return total_cpu_percent / num_cpus

# === Final evaluation logic ===
def evaluate_full_model(model_class, model_path, input_length, *args, **kwargs):
    # 🔁 Load profiling and clean model instances
    prof_model = model_class(input_length=input_length, *args, **kwargs)
    prof_model.load_state_dict(torch.load(model_path))
    prof_model.eval()

    clean_model = model_class(input_length=input_length, *args, **kwargs)
    clean_model.load_state_dict(torch.load(model_path))
    clean_model.eval()

    total_macs, total_params = 0, 0

    print("🔍 Stream MAC breakdown:")
    for i in range(8):
        macs_i, params_i = get_stream_macs_params(prof_model.streams[i], input_length)
        print(f"  Stream[{i}] MACs: {macs_i}, Params: {params_i}")
        total_macs += macs_i
        total_params += params_i

    # FC block
    print("\n🔍 FC Layer breakdown:")
    fc0, fc3, fc6, fc8, fc9 = prof_model.fc[1], prof_model.fc[4], prof_model.fc[7], prof_model.fc[8], prof_model.fc[9]
    macs_fc0, params_fc0 = get_linear_macs_params(fc0, in_features=2048)
    macs_fc3, params_fc3 = get_linear_macs_params(fc3, in_features=512)
    macs_fc6, params_fc6 = get_linear_macs_params(fc6, in_features=256)
    macs_fc8, params_fc8 = get_linear_macs_params(fc8, in_features=128)
    total_macs += macs_fc0 + macs_fc3 + macs_fc6 + macs_fc8
    total_params += params_fc0 + params_fc3 + params_fc6 + params_fc8
    print(f"  FC[0] (2048→512):  {macs_fc0}, Params: {params_fc0}")
    print(f"  FC[3] (512→256):  {macs_fc3}, Params: {params_fc3}")
    print(f"  FC[6] (256→128):  {macs_fc6}, Params: {params_fc6}")
    print(f"  FC[8] (128→classes): {macs_fc8}, Params: {params_fc8}")

    # Projection
    print("\n🔍 Projection Layer:")
    macs_proj, params_proj = get_linear_macs_params(prof_model.proj, in_features=2048)
    total_macs += macs_proj
    total_params += params_proj
    print(f"  Proj (2048→128): {macs_proj}, Params: {params_proj}")

    flops = 2 * total_macs
    size_mb = get_model_size(clean_model)

    dummy_inputs = [torch.randn(1, 1, input_length) for _ in range(8)]
    latency = measure_latency(clean_model, dummy_inputs)
    cpu_usage = measure_cpu_usage(clean_model, dummy_inputs)

    return {
        "Model Size (MB)": round(size_mb, 4),
        "Latency (ms)": round(latency, 3),
        "CPU Usage (%)": round(cpu_usage, 2),
        "Total MACs": int(total_macs),
        "FLOPs": int(flops),
        "Total Params": int(total_params)
    }

# === Usage ===
# You must define your StudentCNN class and load the model first
model = MultiStreamCNN(input_length=CHUNK_SIZE, num_classes=len(label_encoder.classes_))
model.load_state_dict(torch.load("teacher_full.pth"))
# Then:
#torch.save(model.state_dict(), "student_model.pth")
stats = evaluate_full_model(MultiStreamCNN, "teacher_full.pth", input_length=CHUNK_SIZE, num_classes=len(label_encoder.classes_))
for k, v in stats.items():
    print(f"{k}: {v}")
# Out:
# /tmp/ipykernel_2377727/3605911462.py:111: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("teacher_full.pth"))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 111
#     108 # === Usage ===
#     109 # You must define your StudentCNN class and load the model first
#     110 model = MultiStreamCNN(input_length=CHUNK_SIZE, num_classes=len(label_encoder.classes_))
# --> 111 model.load_state_dict(torch.load("teacher_full.pth"))
#     112 # Then:
#     113 #torch.save(model.state_dict(), "student_model.pth")
#     114 stats = evaluate_full_model(MultiStreamCNN, "teacher_full.pth", input_length=CHUNK_SIZE, num_classes=len(label_encoder.classes_))
#
# File ~/anaconda3/envs/dl_satang/lib/python3.11/site-packages/torch/serialization.py:1319, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1316 if "encoding" not in pickle_load_args.keys():
#    1317     pickle_load_args["encoding"] = "utf-8"
# -> 1319 with _open_file_like(f, "rb") as opened_file:
#    1320     if _is_zipfile(opened_file):
#    1321         # The zipfile reader is going to advance the current file position.
#    1322         # If we want to actually tail call to torch.jit.load, we need to
#    1323         # reset back to the original position.
#    1324         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/dl_satang/lib/python3.11/site-packages/torch/serialization.py:659, in _open_file_like(name_or_buffer, mode)
#     657 def _open_file_like(name_or_buffer, mode):
#     658     if _is_path(name_or_buffer):
# --> 659         return _open_file(name_or_buffer, mode)
#     660     else:
#     661         if "w" in mode:
#
# File ~/anaconda3/envs/dl_satang/lib/python3.11/site-packages/torch/serialization.py:640, in _open_file.__init__(self, name, mode)
#     639 def __init__(self, name, mode):
# --> 640     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'teacher_full.pth'

# %%
# expected_shape = (CHUNK_SIZE, NUM_FEATURES)
# X_test, y_test = load_split_from_folder(os.path.join(INPUT_DIR, "test"), expected_shape)
# y_test_str = y_test

# test_dataset = MultiStreamDataset(X_test, y_test_str, label_encoder, augment=False)
# test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn)

# from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# # Rebuild same model architecture
# model = MultiStreamCNN(input_length=CHUNK_SIZE, num_classes=len(label_encoder.classes_))
# model.load_state_dict(torch.load("teacher_full.pth"))
# model.to(device)
# model.eval()
# all_preds = []
# all_labels = []

# with torch.no_grad():
#     for streams, labels in test_loader:
#         # Move to device
#         streams = [s.to(device) for s in streams]
#         labels = labels.to(device)

#         outputs = model(streams)
#         preds = outputs.argmax(dim=1)

#         all_preds.extend(preds.cpu().numpy())
#         all_labels.extend(labels.cpu().numpy())

# # Inverse-transform for reporting
# pred_labels_str = label_encoder.inverse_transform(all_preds)
# true_labels_str = label_encoder.inverse_transform(all_labels)

# # === 5. Classification Report
# print("=== 🧪 Final Test Set Classification Report ===")
# print(classification_report(true_labels_str, pred_labels_str, digits=4))

# # === 6. Seaborn Confusion Matrix
# cm = confusion_matrix(true_labels_str, pred_labels_str, labels=label_encoder.classes_)
# plt.figure(figsize=(10, 8))
# sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
# plt.xlabel("Predicted")
# plt.ylabel("True Label")
# plt.title("Seaborn Confusion Matrix (Test Set)")
# plt.xticks(rotation=45)
# plt.yticks(rotation=0)
# plt.tight_layout()
# plt.show()
# Out:
# /tmp/ipykernel_3245880/3475220102.py:12: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("teacher_full.pth"))
# === 🧪 Final Test Set Classification Report ===
#               precision    recall  f1-score   support
#
#     AESCrypt     1.0000    0.9464    0.9725       112
#       Cerber     0.9916    0.9673    0.9793       245
#     Darkside     0.9822    0.9085    0.9439       426
#        Excel     1.0000    1.0000    1.0000       249
#      Firefox     0.9736    0.9847    0.9791       262
#    GandCrab4     0.8430    0.9577    0.8967       426
#         Ryuk     0.9108    0.9142    0.9125       268
#      SDelete     0.9487    1.0000    0.9737       111
#   Sodinokibi     0.9480    0.8778    0.9115       270
#   TeslaCrypt     0.9161    0.8912    0.9034       147
#     WannaCry     1.0000    1.0000    1.0000       128
#          Zip     1.0000    1.0000    1.0000       113
#
#     accuracy                         0.9467      2757
#    macro avg     0.9595    0.9540    0.9561      2757
# weighted avg     0.9494    0.9467    0.9471      2757

# %%
import torch
import torch.nn as nn

class StudentCNN(nn.Module):
    def __init__(self, input_length, num_classes=12):
        super().__init__()
        self.streams = nn.ModuleList([
            nn.Sequential(
                nn.Conv1d(1, 4, kernel_size=3, padding=1),  # reduced filters
                nn.ReLU(),
                nn.Conv1d(4, 8, kernel_size=3, padding=1),
                nn.ReLU(),
                nn.AdaptiveAvgPool1d(1),
                nn.Flatten()
            ) for _ in range(8)
        ])

        self.fc = nn.Sequential(
            nn.Linear(8 * 8, 128),
            nn.LayerNorm(128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, num_classes)
        )

        # 🔄 Smaller projection for lightweight feature distillation
        self.proj = nn.Linear(8 * 8, 128)

    def forward(self, streams, return_features=False):
        features = [self.streams[i](streams[i]) for i in range(8)]
        x = torch.cat(features, dim=1)  # Shape: [B, 64]

        if return_features:
            feat_proj = self.proj(x)  # [B, 128]
            return self.fc(x), feat_proj

        return self.fc(x)

# %%
import torch.nn.functional as F

def distillation_loss(student_logits, teacher_logits, student_feat, teacher_feat, true_labels, T=3.0, alpha=0.5, beta=0.3, gamma=0.2):

    # Hard loss
    ce_loss = F.cross_entropy(student_logits, true_labels)

    # Soft loss (logits)
    soft_teacher = F.softmax(teacher_logits / T, dim=1)
    soft_student = F.log_softmax(student_logits / T, dim=1)
    kl_loss = F.kl_div(soft_student, soft_teacher, reduction='batchmean') * (T * T)

    # Feature loss (projection-matched MSE)
    feat_loss = F.mse_loss(student_feat, teacher_feat)

    return alpha * ce_loss + beta * kl_loss + gamma * feat_loss

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def train_distilled(student, teacher, train_loader, val_loader, device,
                    epochs=50, lr=0.0005, class_weights=None,
                    T=3.0, alpha=0.5, beta=0.4, gamma=0.3,
                    best_model_path="best_student.pth"):


    teacher.eval()
    student.to(device)
    teacher.to(device)

    optimizer = optim.Adam(student.parameters(), lr=lr)
    criterion_ce = nn.CrossEntropyLoss(weight=class_weights)

    best_val_acc = 0
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    for epoch in range(epochs):
        student.train()
        running_loss, correct = 0.0, 0

        for streams, labels in train_loader:
            streams = [s.to(device) for s in streams]
            labels = labels.to(device)

            # Forward pass (with feature outputs)
            student_logits, student_feat = student(streams, return_features=True)
            with torch.no_grad():
                teacher_logits, teacher_feat = teacher(streams, return_features=True)

            # Compute KD loss
            loss = distillation_loss(
                student_logits, teacher_logits,
                student_feat, teacher_feat,
                labels,
                T=T, alpha=alpha, beta=beta, gamma=gamma
            )

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            correct += (student_logits.argmax(dim=1) == labels).sum().item()

        train_acc = correct / len(train_loader.dataset)
        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)

        # === Validation
        student.eval()
        val_loss, val_correct = 0.0, 0
        with torch.no_grad():
            for streams, labels in val_loader:
                streams = [s.to(device) for s in streams]
                labels = labels.to(device)
                outputs = student(streams)
                loss = criterion_ce(outputs, labels)
                val_loss += loss.item()
                val_correct += (outputs.argmax(dim=1) == labels).sum().item()

        val_acc = val_correct / len(val_loader.dataset)
        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(val_acc)

        print(f"[Distill] Epoch {epoch+1:02d}/{epochs} - "
              f"Train Loss: {train_loss:.4f} - Train Acc: {train_acc:.4f} "
              f"- Val Loss: {val_losses[-1]:.4f} - Val Acc: {val_acc:.4f}")

        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(student.state_dict(), best_model_path)

    # Load best model before returning
    student.load_state_dict(torch.load(best_model_path))
    return train_accuracies, val_accuracies, train_losses, val_losses

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from torch_lr_finder import LRFinder

# === Config
base_dir = "/home/HardDisk/Satang/thesis_proj"
teacher_dir = "/home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/teacher"
save_root = "/home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/student"
os.makedirs(save_root, exist_ok=True)

detection_times = [30, 45, 60]
window_sizes = [10, 15, 20]
NUM_EPOCHS = 50
BATCH_SIZE = 64
NUM_FEATURES = 8
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

for T_d in detection_times:
    for T_w in window_sizes:
        print(f"\n🚀 Knowledge Distillation for Td={T_d}, Tw={T_w}")
        T_len = T_d - T_w + 1
        expected_shape = (T_len, NUM_FEATURES)
        folder = f"X_csv_split_{T_len}"
        input_dir = os.path.join(base_dir, f"New_{T_d}", f"{T_w}", "split_tws", folder)
        train_path = os.path.join(input_dir, "train")
        val_path = os.path.join(input_dir, "val")

        # === Load Data
        X_train, y_train = load_split_from_folder(train_path, expected_shape)
        X_val, y_val = load_split_from_folder(val_path, expected_shape)

        # === SMOTE
        label_encoder = LabelEncoder()
        y_train_enc = label_encoder.fit_transform(y_train)
        X_train_flat = X_train.reshape(X_train.shape[0], -1)
        X_bal, y_bal = SMOTE().fit_resample(X_train_flat, y_train_enc)
        X_train_res = X_bal.reshape(-1, T_len, NUM_FEATURES)
        y_train_res = label_encoder.inverse_transform(y_bal)

        # === Dataset
        train_dataset = MultiStreamDataset(X_train_res, y_train_res, label_encoder, augment=True)
        val_dataset = MultiStreamDataset(X_val, y_val, label_encoder, augment=False)
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

        # === Load Teacher
        teacher_path = os.path.join(teacher_dir, f"teacher_Td{T_d}_Tw{T_w}.pth")
        teacher = MultiStreamCNN(input_length=T_len, num_classes=len(label_encoder.classes_))
        teacher.load_state_dict(torch.load(teacher_path, map_location=device))
        teacher.to(device)
        teacher.eval()

        # === Class Weights
        class_weights = compute_class_weights(label_encoder.transform(y_train_res), device)

        # === LR Finder
        model_for_lr = StudentCNN(input_length=T_len, num_classes=len(label_encoder.classes_)).to(device)
        optimizer = torch.optim.Adam(model_for_lr.parameters(), lr=1e-7)
        criterion = nn.CrossEntropyLoss(weight=class_weights)
        print("🔍 Finding optimal learning rate...")
        lr_finder = LRFinder(model_for_lr, optimizer, criterion, device=device)
        lr_finder.range_test(train_loader, end_lr=1, num_iter=200)
        lr_finder.plot()
        lr_finder.reset()
        BEST_LR = 0.01  # Manually update this after inspecting plots

        # === Train Student KD
        student = StudentCNN(input_length=T_len, num_classes=len(label_encoder.classes_)).to(device)
        train_accs, val_accs, train_losses, val_losses = train_distilled(
            student=student,
            teacher=teacher,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            epochs=NUM_EPOCHS,
            lr=BEST_LR,
            class_weights=class_weights,
            T=3.0,
            alpha=0.5,
            best_model_path=os.path.join(save_root, f"student_KD_Td{T_d}_Tw{T_w}.pth")
        )

        # === Evaluate
        # === Evaluate on Test Set
        test_path = os.path.join(input_dir, "test")
        X_test, y_test = load_split_from_folder(test_path, expected_shape)
        test_dataset = MultiStreamDataset(X_test, y_test, label_encoder, augment=False)
        test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

        # === Test Evaluation and Confusion Matrix
        student.eval()
        test_preds, test_labels = [], []
        with torch.no_grad():
            for streams, labels in test_loader:
                streams = [s.to(device) for s in streams]
                labels = labels.to(device)
                outputs = student(streams)
                preds = torch.argmax(outputs, dim=1)
                test_preds.extend(preds.cpu().numpy())
                test_labels.extend(labels.cpu().numpy())

        # === Save Confusion Matrix (Test Only)
        cm_test = confusion_matrix(test_labels, test_preds)
        plt.figure(figsize=(10, 8))
        sns.heatmap(cm_test, annot=True, fmt="d", cmap="Blues",
                    xticklabels=label_encoder.classes_,
                    yticklabels=label_encoder.classes_)
        plt.title(f"Test Confusion Matrix (Td={T_d}, Tw={T_w})")
        plt.tight_layout()
        plt.savefig(os.path.join(save_root, f"confmat_TEST_Td{T_d}_Tw{T_w}.png"))
        plt.close()

        # === Classification Report
        print(f"\n📋 TEST Classification Report (Td={T_d}, Tw={T_w}):")
        print(classification_report(test_labels, test_preds, target_names=label_encoder.classes_))
# Out:
# 🚀 Knowledge Distillation for Td=30, Tw=10
# /tmp/ipykernel_2377727/1966671643.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher.load_state_dict(torch.load(teacher_path, map_location=device))
# 🔍 Finding optimal learning rate...
# 100%|██████████| 200/200 [00:05<00:00, 39.23it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 2.41E-02
# [Distill] Epoch 01/50 - Train Loss: 3.7661 - Train Acc: 0.6284 - Val Loss: 1.0163 - Val Acc: 0.6653
# [Distill] Epoch 02/50 - Train Loss: 1.9383 - Train Acc: 0.7892 - Val Loss: 0.5779 - Val Acc: 0.8021
# [Distill] Epoch 03/50 - Train Loss: 1.4833 - Train Acc: 0.8389 - Val Loss: 0.5095 - Val Acc: 0.8196
# [Distill] Epoch 04/50 - Train Loss: 1.3013 - Train Acc: 0.8587 - Val Loss: 0.7160 - Val Acc: 0.7896
# [Distill] Epoch 05/50 - Train Loss: 1.1561 - Train Acc: 0.8710 - Val Loss: 0.4956 - Val Acc: 0.8437
# [Distill] Epoch 06/50 - Train Loss: 1.1036 - Train Acc: 0.8761 - Val Loss: 0.3888 - Val Acc: 0.8657
# [Distill] Epoch 07/50 - Train Loss: 1.0197 - Train Acc: 0.8867 - Val Loss: 0.3433 - Val Acc: 0.8803
# [Distill] Epoch 08/50 - Train Loss: 0.9436 - Train Acc: 0.8919 - Val Loss: 0.3456 - Val Acc: 0.8863
# [Distill] Epoch 09/50 - Train Loss: 0.9150 - Train Acc: 0.8950 - Val Loss: 0.5194 - Val Acc: 0.8327
# [Distill] Epoch 10/50 - Train Loss: 0.8817 - Train Acc: 0.9012 - Val Loss: 0.3977 - Val Acc: 0.8682
# [Distill] Epoch 11/50 - Train Loss: 0.8432 - Train Acc: 0.9029 - Val Loss: 0.3426 - Val Acc: 0.8923
# [Distill] Epoch 12/50 - Train Loss: 0.8162 - Train Acc: 0.9061 - Val Loss: 0.3587 - Val Acc: 0.8978
# [Distill] Epoch 13/50 - Train Loss: 0.7816 - Train Acc: 0.9090 - Val Loss: 0.3388 - Val Acc: 0.9018
# [Distill] Epoch 14/50 - Train Loss: 0.7533 - Train Acc: 0.9117 - Val Loss: 0.3718 - Val Acc: 0.8983
# [Distill] Epoch 15/50 - Train Loss: 0.7335 - Train Acc: 0.9142 - Val Loss: 0.2868 - Val Acc: 0.9113
# [Distill] Epoch 16/50 - Train Loss: 0.7615 - Train Acc: 0.9114 - Val Loss: 0.3157 - Val Acc: 0.9043
# [Distill] Epoch 17/50 - Train Loss: 0.6988 - Train Acc: 0.9179 - Val Loss: 0.3801 - Val Acc: 0.8928
# [Distill] Epoch 18/50 - Train Loss: 0.6643 - Train Acc: 0.9218 - Val Loss: 0.3074 - Val Acc: 0.9143
# [Distill] Epoch 19/50 - Train Loss: 0.6795 - Train Acc: 0.9212 - Val Loss: 0.3434 - Val Acc: 0.9073
# [Distill] Epoch 20/50 - Train Loss: 0.6560 - Train Acc: 0.9221 - Val Loss: 0.4163 - Val Acc: 0.8798
# [Distill] Epoch 21/50 - Train Loss: 0.6966 - Train Acc: 0.9203 - Val Loss: 0.4069 - Val Acc: 0.8943
# [Distill] Epoch 22/50 - Train Loss: 0.6426 - Train Acc: 0.9237 - Val Loss: 0.3351 - Val Acc: 0.8853
# [Distill] Epoch 23/50 - Train Loss: 0.6607 - Train Acc: 0.9224 - Val Loss: 0.2946 - Val Acc: 0.9108
# [Distill] Epoch 24/50 - Train Loss: 0.6334 - Train Acc: 0.9229 - Val Loss: 0.3086 - Val Acc: 0.9113
# [Distill] Epoch 25/50 - Train Loss: 0.5952 - Train Acc: 0.9305 - Val Loss: 0.2679 - Val Acc: 0.9188
# [Distill] Epoch 26/50 - Train Loss: 0.6166 - Train Acc: 0.9275 - Val Loss: 0.2999 - Val Acc: 0.9148
# [Distill] Epoch 27/50 - Train Loss: 0.5985 - Train Acc: 0.9295 - Val Loss: 0.4735 - Val Acc: 0.8793
# [Distill] Epoch 28/50 - Train Loss: 0.6196 - Train Acc: 0.9253 - Val Loss: 0.2737 - Val Acc: 0.9098
# [Distill] Epoch 29/50 - Train Loss: 0.6003 - Train Acc: 0.9304 - Val Loss: 0.3781 - Val Acc: 0.9068
# [Distill] Epoch 30/50 - Train Loss: 0.6294 - Train Acc: 0.9272 - Val Loss: 0.3228 - Val Acc: 0.9108
# [Distill] Epoch 31/50 - Train Loss: 0.5840 - Train Acc: 0.9316 - Val Loss: 0.3813 - Val Acc: 0.9008
# [Distill] Epoch 32/50 - Train Loss: 0.5730 - Train Acc: 0.9308 - Val Loss: 0.3105 - Val Acc: 0.9148
# [Distill] Epoch 33/50 - Train Loss: 0.5845 - Train Acc: 0.9311 - Val Loss: 0.2656 - Val Acc: 0.9269
# [Distill] Epoch 34/50 - Train Loss: 0.5585 - Train Acc: 0.9343 - Val Loss: 0.2961 - Val Acc: 0.9183
# [Distill] Epoch 35/50 - Train Loss: 0.5487 - Train Acc: 0.9346 - Val Loss: 0.3188 - Val Acc: 0.9048
# [Distill] Epoch 36/50 - Train Loss: 0.5665 - Train Acc: 0.9313 - Val Loss: 0.3208 - Val Acc: 0.9068
# [Distill] Epoch 37/50 - Train Loss: 0.5464 - Train Acc: 0.9344 - Val Loss: 0.2734 - Val Acc: 0.9118
# [Distill] Epoch 38/50 - Train Loss: 0.5685 - Train Acc: 0.9336 - Val Loss: 0.3639 - Val Acc: 0.9133
# [Distill] Epoch 39/50 - Train Loss: 0.5437 - Train Acc: 0.9367 - Val Loss: 0.3379 - Val Acc: 0.9083
# [Distill] Epoch 40/50 - Train Loss: 0.5385 - Train Acc: 0.9356 - Val Loss: 0.3490 - Val Acc: 0.9063
# [Distill] Epoch 41/50 - Train Loss: 0.5279 - Train Acc: 0.9369 - Val Loss: 0.3377 - Val Acc: 0.9113
# [Distill] Epoch 42/50 - Train Loss: 0.5429 - Train Acc: 0.9355 - Val Loss: 0.3141 - Val Acc: 0.9173
# [Distill] Epoch 43/50 - Train Loss: 0.5303 - Train Acc: 0.9378 - Val Loss: 0.3288 - Val Acc: 0.9158
# [Distill] Epoch 44/50 - Train Loss: 0.5219 - Train Acc: 0.9388 - Val Loss: 0.2792 - Val Acc: 0.9254
# [Distill] Epoch 45/50 - Train Loss: 0.4988 - Train Acc: 0.9421 - Val Loss: 0.3145 - Val Acc: 0.9233
# [Distill] Epoch 46/50 - Train Loss: 0.5119 - Train Acc: 0.9413 - Val Loss: 0.3654 - Val Acc: 0.9073
# [Distill] Epoch 47/50 - Train Loss: 0.5181 - Train Acc: 0.9383 - Val Loss: 0.3285 - Val Acc: 0.9018
# [Distill] Epoch 48/50 - Train Loss: 0.5253 - Train Acc: 0.9376 - Val Loss: 0.3040 - Val Acc: 0.9213
# [Distill] Epoch 49/50 - Train Loss: 0.5213 - Train Acc: 0.9370 - Val Loss: 0.2788 - Val Acc: 0.9218
# [Distill] Epoch 50/50 - Train Loss: 0.4968 - Train Acc: 0.9404 - Val Loss: 0.2934 - Val Acc: 0.9193
# /tmp/ipykernel_2377727/969224989.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# 📋 TEST Classification Report (Td=30, Tw=10):
#               precision    recall  f1-score   support
#
#     AESCrypt       1.00      0.97      0.98        86
#       Cerber       0.93      0.88      0.90       185
#     Darkside       0.97      0.90      0.93       324
#        Excel       1.00      1.00      1.00       188
#      Firefox       0.99      0.99      0.99       199
#    GandCrab4       0.80      0.95      0.87       323
#         Ryuk       0.94      0.93      0.93       203
#      SDelete       1.00      1.00      1.00        84
#   Sodinokibi       0.89      0.84      0.86       205
#   TeslaCrypt       0.97      0.79      0.87       111
#     WannaCry       1.00      1.00      1.00        95
#          Zip       0.97      1.00      0.98        87
#
#     accuracy                           0.93      2090
#    macro avg       0.95      0.94      0.94      2090
# weighted avg       0.94      0.93      0.93      2090
#
#
# 🚀 Knowledge Distillation for Td=30, Tw=15
# /tmp/ipykernel_2377727/1966671643.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher.load_state_dict(torch.load(teacher_path, map_location=device))
# 🔍 Finding optimal learning rate...
# 100%|██████████| 200/200 [00:04<00:00, 41.79it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 2.22E-02
# [Distill] Epoch 01/50 - Train Loss: 3.2725 - Train Acc: 0.7121 - Val Loss: 1.0414 - Val Acc: 0.7187
# [Distill] Epoch 02/50 - Train Loss: 1.6001 - Train Acc: 0.8442 - Val Loss: 0.6402 - Val Acc: 0.8117
# [Distill] Epoch 03/50 - Train Loss: 1.2750 - Train Acc: 0.8713 - Val Loss: 0.7726 - Val Acc: 0.8128
# [Distill] Epoch 04/50 - Train Loss: 1.1125 - Train Acc: 0.8871 - Val Loss: 0.6759 - Val Acc: 0.8436
# [Distill] Epoch 05/50 - Train Loss: 1.0596 - Train Acc: 0.8911 - Val Loss: 0.5615 - Val Acc: 0.8470
# [Distill] Epoch 06/50 - Train Loss: 0.9548 - Train Acc: 0.8994 - Val Loss: 0.6299 - Val Acc: 0.8455
# [Distill] Epoch 07/50 - Train Loss: 0.8995 - Train Acc: 0.9051 - Val Loss: 0.6952 - Val Acc: 0.8307
# [Distill] Epoch 08/50 - Train Loss: 0.8468 - Train Acc: 0.9099 - Val Loss: 0.6099 - Val Acc: 0.8576
# [Distill] Epoch 09/50 - Train Loss: 0.8310 - Train Acc: 0.9127 - Val Loss: 0.4481 - Val Acc: 0.8675
# [Distill] Epoch 10/50 - Train Loss: 0.7562 - Train Acc: 0.9182 - Val Loss: 0.4728 - Val Acc: 0.8762
# [Distill] Epoch 11/50 - Train Loss: 0.7418 - Train Acc: 0.9198 - Val Loss: 0.4481 - Val Acc: 0.8785
# [Distill] Epoch 12/50 - Train Loss: 0.7080 - Train Acc: 0.9224 - Val Loss: 0.4509 - Val Acc: 0.8880
# [Distill] Epoch 13/50 - Train Loss: 0.6931 - Train Acc: 0.9260 - Val Loss: 0.4623 - Val Acc: 0.8724
# [Distill] Epoch 14/50 - Train Loss: 0.6525 - Train Acc: 0.9284 - Val Loss: 0.4250 - Val Acc: 0.8838
# [Distill] Epoch 15/50 - Train Loss: 0.6636 - Train Acc: 0.9293 - Val Loss: 0.4705 - Val Acc: 0.8732
# [Distill] Epoch 16/50 - Train Loss: 0.6316 - Train Acc: 0.9313 - Val Loss: 0.4435 - Val Acc: 0.8827
# [Distill] Epoch 17/50 - Train Loss: 0.6459 - Train Acc: 0.9308 - Val Loss: 0.5113 - Val Acc: 0.8770
# [Distill] Epoch 18/50 - Train Loss: 0.5915 - Train Acc: 0.9383 - Val Loss: 0.3479 - Val Acc: 0.9043
# [Distill] Epoch 19/50 - Train Loss: 0.6026 - Train Acc: 0.9363 - Val Loss: 0.5053 - Val Acc: 0.8724
# [Distill] Epoch 20/50 - Train Loss: 0.5496 - Train Acc: 0.9404 - Val Loss: 0.4044 - Val Acc: 0.9009
# [Distill] Epoch 21/50 - Train Loss: 0.5534 - Train Acc: 0.9416 - Val Loss: 0.4715 - Val Acc: 0.8922
# [Distill] Epoch 22/50 - Train Loss: 0.5622 - Train Acc: 0.9396 - Val Loss: 0.3692 - Val Acc: 0.9039
# [Distill] Epoch 23/50 - Train Loss: 0.5509 - Train Acc: 0.9401 - Val Loss: 0.4113 - Val Acc: 0.9036
# [Distill] Epoch 24/50 - Train Loss: 0.5259 - Train Acc: 0.9439 - Val Loss: 0.5143 - Val Acc: 0.8853
# [Distill] Epoch 25/50 - Train Loss: 0.5358 - Train Acc: 0.9410 - Val Loss: 0.3616 - Val Acc: 0.9100
# [Distill] Epoch 26/50 - Train Loss: 0.5143 - Train Acc: 0.9446 - Val Loss: 0.4357 - Val Acc: 0.8948
# [Distill] Epoch 27/50 - Train Loss: 0.5274 - Train Acc: 0.9434 - Val Loss: 0.4592 - Val Acc: 0.8861
# [Distill] Epoch 28/50 - Train Loss: 0.5051 - Train Acc: 0.9453 - Val Loss: 0.3611 - Val Acc: 0.9104
# [Distill] Epoch 29/50 - Train Loss: 0.5250 - Train Acc: 0.9436 - Val Loss: 0.3697 - Val Acc: 0.9002
# [Distill] Epoch 30/50 - Train Loss: 0.4874 - Train Acc: 0.9473 - Val Loss: 0.3445 - Val Acc: 0.9123
# [Distill] Epoch 31/50 - Train Loss: 0.5043 - Train Acc: 0.9453 - Val Loss: 0.3652 - Val Acc: 0.9070
# [Distill] Epoch 32/50 - Train Loss: 0.4768 - Train Acc: 0.9489 - Val Loss: 0.3724 - Val Acc: 0.9002
# [Distill] Epoch 33/50 - Train Loss: 0.4692 - Train Acc: 0.9506 - Val Loss: 0.3539 - Val Acc: 0.9108
# [Distill] Epoch 34/50 - Train Loss: 0.4826 - Train Acc: 0.9498 - Val Loss: 0.4061 - Val Acc: 0.9028
# [Distill] Epoch 35/50 - Train Loss: 0.4904 - Train Acc: 0.9476 - Val Loss: 0.3978 - Val Acc: 0.9039
# [Distill] Epoch 36/50 - Train Loss: 0.4455 - Train Acc: 0.9519 - Val Loss: 0.3604 - Val Acc: 0.9066
# [Distill] Epoch 37/50 - Train Loss: 0.4571 - Train Acc: 0.9517 - Val Loss: 0.3626 - Val Acc: 0.9115
# [Distill] Epoch 38/50 - Train Loss: 0.4493 - Train Acc: 0.9511 - Val Loss: 0.3981 - Val Acc: 0.8979
# [Distill] Epoch 39/50 - Train Loss: 0.4459 - Train Acc: 0.9523 - Val Loss: 0.3798 - Val Acc: 0.9058
# [Distill] Epoch 40/50 - Train Loss: 0.4456 - Train Acc: 0.9520 - Val Loss: 0.3378 - Val Acc: 0.9157
# [Distill] Epoch 41/50 - Train Loss: 0.4435 - Train Acc: 0.9517 - Val Loss: 0.4326 - Val Acc: 0.8983
# [Distill] Epoch 42/50 - Train Loss: 0.4540 - Train Acc: 0.9507 - Val Loss: 0.4038 - Val Acc: 0.8975
# [Distill] Epoch 43/50 - Train Loss: 0.4237 - Train Acc: 0.9557 - Val Loss: 0.2873 - Val Acc: 0.9142
# [Distill] Epoch 44/50 - Train Loss: 0.4057 - Train Acc: 0.9563 - Val Loss: 0.3483 - Val Acc: 0.9089
# [Distill] Epoch 45/50 - Train Loss: 0.4143 - Train Acc: 0.9573 - Val Loss: 0.3589 - Val Acc: 0.9070
# [Distill] Epoch 46/50 - Train Loss: 0.4495 - Train Acc: 0.9533 - Val Loss: 0.3620 - Val Acc: 0.9100
# [Distill] Epoch 47/50 - Train Loss: 0.4246 - Train Acc: 0.9536 - Val Loss: 0.3651 - Val Acc: 0.9112
# [Distill] Epoch 48/50 - Train Loss: 0.3859 - Train Acc: 0.9584 - Val Loss: 0.3546 - Val Acc: 0.9119
# [Distill] Epoch 49/50 - Train Loss: 0.4065 - Train Acc: 0.9571 - Val Loss: 0.3537 - Val Acc: 0.9104
# [Distill] Epoch 50/50 - Train Loss: 0.4066 - Train Acc: 0.9572 - Val Loss: 0.2988 - Val Acc: 0.9188
# /tmp/ipykernel_2377727/969224989.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# 📋 TEST Classification Report (Td=30, Tw=15):
#               precision    recall  f1-score   support
#
#     AESCrypt       1.00      1.00      1.00       112
#       Cerber       0.95      0.96      0.96       245
#     Darkside       0.97      0.88      0.92       426
#        Excel       0.99      0.98      0.99       249
#      Firefox       0.98      0.97      0.98       262
#    GandCrab4       0.82      0.90      0.86       426
#         Ryuk       0.86      0.91      0.88       268
#      SDelete       1.00      1.00      1.00       111
#   Sodinokibi       0.95      0.84      0.89       270
#   TeslaCrypt       0.82      0.87      0.84       147
#     WannaCry       0.98      0.98      0.98       128
#          Zip       1.00      1.00      1.00       113
#
#     accuracy                           0.93      2757
#    macro avg       0.94      0.94      0.94      2757
# weighted avg       0.93      0.93      0.93      2757
#
#
# 🚀 Knowledge Distillation for Td=30, Tw=20
# /tmp/ipykernel_2377727/1966671643.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher.load_state_dict(torch.load(teacher_path, map_location=device))
# 🔍 Finding optimal learning rate...
# 100%|██████████| 200/200 [00:04<00:00, 43.76it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.74E-02
# [Distill] Epoch 01/50 - Train Loss: 2.7275 - Train Acc: 0.7226 - Val Loss: 1.0806 - Val Acc: 0.6973
# [Distill] Epoch 02/50 - Train Loss: 1.4247 - Train Acc: 0.8320 - Val Loss: 0.7392 - Val Acc: 0.7685
# [Distill] Epoch 03/50 - Train Loss: 1.1992 - Train Acc: 0.8507 - Val Loss: 0.6645 - Val Acc: 0.7952
# [Distill] Epoch 04/50 - Train Loss: 1.0654 - Train Acc: 0.8643 - Val Loss: 0.6581 - Val Acc: 0.7805
# [Distill] Epoch 05/50 - Train Loss: 0.9859 - Train Acc: 0.8687 - Val Loss: 0.7006 - Val Acc: 0.7880
# [Distill] Epoch 06/50 - Train Loss: 0.9261 - Train Acc: 0.8744 - Val Loss: 0.8106 - Val Acc: 0.7681
# [Distill] Epoch 07/50 - Train Loss: 0.8875 - Train Acc: 0.8771 - Val Loss: 0.7049 - Val Acc: 0.7899
# [Distill] Epoch 08/50 - Train Loss: 0.8487 - Train Acc: 0.8803 - Val Loss: 0.6190 - Val Acc: 0.8033
# [Distill] Epoch 09/50 - Train Loss: 0.8332 - Train Acc: 0.8828 - Val Loss: 0.5851 - Val Acc: 0.8141
# [Distill] Epoch 10/50 - Train Loss: 0.8003 - Train Acc: 0.8858 - Val Loss: 0.5139 - Val Acc: 0.8283
# [Distill] Epoch 11/50 - Train Loss: 0.7843 - Train Acc: 0.8870 - Val Loss: 0.5533 - Val Acc: 0.8109
# [Distill] Epoch 12/50 - Train Loss: 0.7692 - Train Acc: 0.8895 - Val Loss: 0.5618 - Val Acc: 0.8138
# [Distill] Epoch 13/50 - Train Loss: 0.7459 - Train Acc: 0.8913 - Val Loss: 0.4846 - Val Acc: 0.8434
# [Distill] Epoch 14/50 - Train Loss: 0.7316 - Train Acc: 0.8925 - Val Loss: 0.5745 - Val Acc: 0.8252
# [Distill] Epoch 15/50 - Train Loss: 0.7196 - Train Acc: 0.8944 - Val Loss: 0.5218 - Val Acc: 0.8423
# [Distill] Epoch 16/50 - Train Loss: 0.7151 - Train Acc: 0.8963 - Val Loss: 0.7075 - Val Acc: 0.7937
# [Distill] Epoch 17/50 - Train Loss: 0.7000 - Train Acc: 0.8967 - Val Loss: 0.5459 - Val Acc: 0.8398
# [Distill] Epoch 18/50 - Train Loss: 0.6872 - Train Acc: 0.8969 - Val Loss: 0.5519 - Val Acc: 0.8197
# [Distill] Epoch 19/50 - Train Loss: 0.6766 - Train Acc: 0.8988 - Val Loss: 0.5570 - Val Acc: 0.8294
# [Distill] Epoch 20/50 - Train Loss: 0.6735 - Train Acc: 0.9001 - Val Loss: 0.4715 - Val Acc: 0.8446
# [Distill] Epoch 21/50 - Train Loss: 0.6634 - Train Acc: 0.8994 - Val Loss: 0.4988 - Val Acc: 0.8402
# [Distill] Epoch 22/50 - Train Loss: 0.6565 - Train Acc: 0.9015 - Val Loss: 0.4773 - Val Acc: 0.8465
# [Distill] Epoch 23/50 - Train Loss: 0.6501 - Train Acc: 0.9012 - Val Loss: 0.4960 - Val Acc: 0.8333
# [Distill] Epoch 24/50 - Train Loss: 0.6449 - Train Acc: 0.9017 - Val Loss: 0.4536 - Val Acc: 0.8379
# [Distill] Epoch 25/50 - Train Loss: 0.6418 - Train Acc: 0.9017 - Val Loss: 0.5185 - Val Acc: 0.8367
# [Distill] Epoch 26/50 - Train Loss: 0.6314 - Train Acc: 0.9033 - Val Loss: 0.5403 - Val Acc: 0.8294
# [Distill] Epoch 27/50 - Train Loss: 0.6262 - Train Acc: 0.9038 - Val Loss: 0.5395 - Val Acc: 0.8319
# [Distill] Epoch 28/50 - Train Loss: 0.6257 - Train Acc: 0.9044 - Val Loss: 0.4662 - Val Acc: 0.8488
# [Distill] Epoch 29/50 - Train Loss: 0.6228 - Train Acc: 0.9038 - Val Loss: 0.5700 - Val Acc: 0.8250
# [Distill] Epoch 30/50 - Train Loss: 0.6214 - Train Acc: 0.9025 - Val Loss: 0.4759 - Val Acc: 0.8554
# [Distill] Epoch 31/50 - Train Loss: 0.6129 - Train Acc: 0.9054 - Val Loss: 0.5068 - Val Acc: 0.8449
# [Distill] Epoch 32/50 - Train Loss: 0.6109 - Train Acc: 0.9050 - Val Loss: 0.4915 - Val Acc: 0.8484
# [Distill] Epoch 33/50 - Train Loss: 0.6063 - Train Acc: 0.9065 - Val Loss: 0.5121 - Val Acc: 0.8386
# [Distill] Epoch 34/50 - Train Loss: 0.5998 - Train Acc: 0.9070 - Val Loss: 0.5195 - Val Acc: 0.8455
# [Distill] Epoch 35/50 - Train Loss: 0.5926 - Train Acc: 0.9071 - Val Loss: 0.6083 - Val Acc: 0.8224
# [Distill] Epoch 36/50 - Train Loss: 0.5957 - Train Acc: 0.9060 - Val Loss: 0.4662 - Val Acc: 0.8468
# [Distill] Epoch 37/50 - Train Loss: 0.5884 - Train Acc: 0.9076 - Val Loss: 0.4407 - Val Acc: 0.8593
# [Distill] Epoch 38/50 - Train Loss: 0.5902 - Train Acc: 0.9067 - Val Loss: 0.5027 - Val Acc: 0.8409
# [Distill] Epoch 39/50 - Train Loss: 0.5961 - Train Acc: 0.9077 - Val Loss: 0.5977 - Val Acc: 0.8226
# [Distill] Epoch 40/50 - Train Loss: 0.5789 - Train Acc: 0.9082 - Val Loss: 0.5488 - Val Acc: 0.8277
# [Distill] Epoch 41/50 - Train Loss: 0.5801 - Train Acc: 0.9068 - Val Loss: 0.5602 - Val Acc: 0.8258
# [Distill] Epoch 42/50 - Train Loss: 0.5731 - Train Acc: 0.9097 - Val Loss: 0.4934 - Val Acc: 0.8566
# [Distill] Epoch 43/50 - Train Loss: 0.5758 - Train Acc: 0.9091 - Val Loss: 0.5527 - Val Acc: 0.8256
# [Distill] Epoch 44/50 - Train Loss: 0.5648 - Train Acc: 0.9097 - Val Loss: 0.6695 - Val Acc: 0.8174
# [Distill] Epoch 45/50 - Train Loss: 0.5779 - Train Acc: 0.9095 - Val Loss: 0.4665 - Val Acc: 0.8509
# [Distill] Epoch 46/50 - Train Loss: 0.5700 - Train Acc: 0.9089 - Val Loss: 0.6076 - Val Acc: 0.8207
# [Distill] Epoch 47/50 - Train Loss: 0.5684 - Train Acc: 0.9084 - Val Loss: 0.5281 - Val Acc: 0.8484
# [Distill] Epoch 48/50 - Train Loss: 0.5577 - Train Acc: 0.9105 - Val Loss: 0.5377 - Val Acc: 0.8342
# [Distill] Epoch 49/50 - Train Loss: 0.5590 - Train Acc: 0.9095 - Val Loss: 0.5263 - Val Acc: 0.8447
# [Distill] Epoch 50/50 - Train Loss: 0.5604 - Train Acc: 0.9108 - Val Loss: 0.5008 - Val Acc: 0.8405
# /tmp/ipykernel_2377727/969224989.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# 📋 TEST Classification Report (Td=30, Tw=20):
#               precision    recall  f1-score   support
#
#     AESCrypt       1.00      0.94      0.97       222
#       Cerber       0.94      0.95      0.95       486
#     Darkside       0.95      0.92      0.93       849
#        Excel       1.00      0.99      0.99       494
#      Firefox       0.99      0.97      0.98       522
#    GandCrab4       0.82      0.86      0.84       849
#         Ryuk       0.89      0.46      0.61       530
#      SDelete       0.96      1.00      0.98       219
#   Sodinokibi       0.60      0.85      0.71       538
#   TeslaCrypt       0.78      0.91      0.84       292
#     WannaCry       0.99      1.00      0.99       252
#          Zip       0.99      0.95      0.97       223
#
#     accuracy                           0.88      5476
#    macro avg       0.91      0.90      0.90      5476
# weighted avg       0.90      0.88      0.88      5476
#
#
# 🚀 Knowledge Distillation for Td=45, Tw=10
# /tmp/ipykernel_2377727/1966671643.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher.load_state_dict(torch.load(teacher_path, map_location=device))
# 🔍 Finding optimal learning rate...
# 100%|██████████| 200/200 [00:04<00:00, 41.16it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 8.41E-03
# [Distill] Epoch 01/50 - Train Loss: 4.3107 - Train Acc: 0.6415 - Val Loss: 1.4634 - Val Acc: 0.6047
# [Distill] Epoch 02/50 - Train Loss: 1.8071 - Train Acc: 0.8413 - Val Loss: 0.7852 - Val Acc: 0.7587
# [Distill] Epoch 03/50 - Train Loss: 1.3679 - Train Acc: 0.8750 - Val Loss: 0.6030 - Val Acc: 0.8256
# [Distill] Epoch 04/50 - Train Loss: 1.1556 - Train Acc: 0.8952 - Val Loss: 0.9259 - Val Acc: 0.7762
# [Distill] Epoch 05/50 - Train Loss: 1.0773 - Train Acc: 0.9015 - Val Loss: 0.4803 - Val Acc: 0.8721
# [Distill] Epoch 06/50 - Train Loss: 0.9044 - Train Acc: 0.9161 - Val Loss: 0.5176 - Val Acc: 0.8731
# [Distill] Epoch 07/50 - Train Loss: 0.8388 - Train Acc: 0.9243 - Val Loss: 0.4558 - Val Acc: 0.8779
# [Distill] Epoch 08/50 - Train Loss: 0.7894 - Train Acc: 0.9272 - Val Loss: 0.4257 - Val Acc: 0.8963
# [Distill] Epoch 09/50 - Train Loss: 0.7496 - Train Acc: 0.9335 - Val Loss: 0.4248 - Val Acc: 0.8857
# [Distill] Epoch 10/50 - Train Loss: 0.7423 - Train Acc: 0.9347 - Val Loss: 0.3831 - Val Acc: 0.8818
# [Distill] Epoch 11/50 - Train Loss: 0.7033 - Train Acc: 0.9376 - Val Loss: 0.4062 - Val Acc: 0.8992
# [Distill] Epoch 12/50 - Train Loss: 0.6509 - Train Acc: 0.9448 - Val Loss: 0.4685 - Val Acc: 0.9089
# [Distill] Epoch 13/50 - Train Loss: 0.6961 - Train Acc: 0.9366 - Val Loss: 0.3748 - Val Acc: 0.9060
# [Distill] Epoch 14/50 - Train Loss: 0.5892 - Train Acc: 0.9479 - Val Loss: 0.4815 - Val Acc: 0.8915
# [Distill] Epoch 15/50 - Train Loss: 0.5667 - Train Acc: 0.9485 - Val Loss: 0.4239 - Val Acc: 0.8789
# [Distill] Epoch 16/50 - Train Loss: 0.6272 - Train Acc: 0.9462 - Val Loss: 0.3361 - Val Acc: 0.9079
# [Distill] Epoch 17/50 - Train Loss: 0.5537 - Train Acc: 0.9509 - Val Loss: 0.4422 - Val Acc: 0.8886
# [Distill] Epoch 18/50 - Train Loss: 0.5324 - Train Acc: 0.9536 - Val Loss: 0.3811 - Val Acc: 0.9147
# [Distill] Epoch 19/50 - Train Loss: 0.5112 - Train Acc: 0.9559 - Val Loss: 0.4768 - Val Acc: 0.9070
# [Distill] Epoch 20/50 - Train Loss: 0.5226 - Train Acc: 0.9537 - Val Loss: 0.3322 - Val Acc: 0.9109
# [Distill] Epoch 21/50 - Train Loss: 0.4789 - Train Acc: 0.9597 - Val Loss: 0.2948 - Val Acc: 0.9273
# [Distill] Epoch 22/50 - Train Loss: 0.4886 - Train Acc: 0.9588 - Val Loss: 0.4184 - Val Acc: 0.9118
# [Distill] Epoch 23/50 - Train Loss: 0.5167 - Train Acc: 0.9563 - Val Loss: 0.5861 - Val Acc: 0.8886
# [Distill] Epoch 24/50 - Train Loss: 0.4865 - Train Acc: 0.9569 - Val Loss: 0.3882 - Val Acc: 0.9147
# [Distill] Epoch 25/50 - Train Loss: 0.4600 - Train Acc: 0.9617 - Val Loss: 0.3238 - Val Acc: 0.9341
# [Distill] Epoch 26/50 - Train Loss: 0.4875 - Train Acc: 0.9620 - Val Loss: 0.3317 - Val Acc: 0.9244
# [Distill] Epoch 27/50 - Train Loss: 0.4375 - Train Acc: 0.9647 - Val Loss: 0.3596 - Val Acc: 0.9070
# [Distill] Epoch 28/50 - Train Loss: 0.4416 - Train Acc: 0.9658 - Val Loss: 0.5805 - Val Acc: 0.8876
# [Distill] Epoch 29/50 - Train Loss: 0.5478 - Train Acc: 0.9573 - Val Loss: 0.3326 - Val Acc: 0.9264
# [Distill] Epoch 30/50 - Train Loss: 0.4077 - Train Acc: 0.9680 - Val Loss: 0.3214 - Val Acc: 0.9293
# [Distill] Epoch 31/50 - Train Loss: 0.3873 - Train Acc: 0.9685 - Val Loss: 0.5387 - Val Acc: 0.8905
# [Distill] Epoch 32/50 - Train Loss: 0.6036 - Train Acc: 0.9464 - Val Loss: 0.3628 - Val Acc: 0.9234
# [Distill] Epoch 33/50 - Train Loss: 0.4063 - Train Acc: 0.9666 - Val Loss: 0.2971 - Val Acc: 0.9399
# [Distill] Epoch 34/50 - Train Loss: 0.4190 - Train Acc: 0.9669 - Val Loss: 0.3974 - Val Acc: 0.8934
# [Distill] Epoch 35/50 - Train Loss: 0.4770 - Train Acc: 0.9601 - Val Loss: 0.3021 - Val Acc: 0.9312
# [Distill] Epoch 36/50 - Train Loss: 0.3742 - Train Acc: 0.9701 - Val Loss: 0.4002 - Val Acc: 0.9273
# [Distill] Epoch 37/50 - Train Loss: 0.3898 - Train Acc: 0.9691 - Val Loss: 0.3859 - Val Acc: 0.9041
# [Distill] Epoch 38/50 - Train Loss: 0.4062 - Train Acc: 0.9678 - Val Loss: 0.3733 - Val Acc: 0.9089
# [Distill] Epoch 39/50 - Train Loss: 0.3553 - Train Acc: 0.9720 - Val Loss: 0.3197 - Val Acc: 0.9109
# [Distill] Epoch 40/50 - Train Loss: 0.3493 - Train Acc: 0.9742 - Val Loss: 0.3236 - Val Acc: 0.9331
# [Distill] Epoch 41/50 - Train Loss: 0.3849 - Train Acc: 0.9696 - Val Loss: 0.3990 - Val Acc: 0.9205
# [Distill] Epoch 42/50 - Train Loss: 0.4007 - Train Acc: 0.9687 - Val Loss: 0.3756 - Val Acc: 0.9264
# [Distill] Epoch 43/50 - Train Loss: 0.3368 - Train Acc: 0.9741 - Val Loss: 0.2759 - Val Acc: 0.9283
# [Distill] Epoch 44/50 - Train Loss: 0.3372 - Train Acc: 0.9732 - Val Loss: 0.2921 - Val Acc: 0.9273
# [Distill] Epoch 45/50 - Train Loss: 0.3361 - Train Acc: 0.9742 - Val Loss: 0.3196 - Val Acc: 0.9234
# [Distill] Epoch 46/50 - Train Loss: 0.3209 - Train Acc: 0.9748 - Val Loss: 0.2881 - Val Acc: 0.9351
# [Distill] Epoch 47/50 - Train Loss: 0.3636 - Train Acc: 0.9753 - Val Loss: 0.3063 - Val Acc: 0.9215
# [Distill] Epoch 48/50 - Train Loss: 0.4579 - Train Acc: 0.9638 - Val Loss: 0.3942 - Val Acc: 0.9147
# [Distill] Epoch 49/50 - Train Loss: 0.3582 - Train Acc: 0.9729 - Val Loss: 0.2653 - Val Acc: 0.9322
# [Distill] Epoch 50/50 - Train Loss: 0.3476 - Train Acc: 0.9730 - Val Loss: 0.3595 - Val Acc: 0.9215
# /tmp/ipykernel_2377727/969224989.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# 📋 TEST Classification Report (Td=45, Tw=10):
#               precision    recall  f1-score   support
#
#     AESCrypt       1.00      0.95      0.97        39
#       Cerber       0.98      0.98      0.98        97
#     Darkside       0.98      0.93      0.95       177
#        Excel       1.00      1.00      1.00        97
#      Firefox       0.97      0.94      0.96       105
#    GandCrab4       0.89      0.90      0.90       178
#         Ryuk       0.82      0.95      0.88       106
#      SDelete       1.00      1.00      1.00        38
#   Sodinokibi       0.94      0.87      0.90       108
#   TeslaCrypt       0.81      0.81      0.81        54
#     WannaCry       1.00      1.00      1.00        45
#          Zip       0.95      1.00      0.97        39
#
#     accuracy                           0.94      1083
#    macro avg       0.95      0.95      0.94      1083
# weighted avg       0.94      0.94      0.94      1083
#
#
# 🚀 Knowledge Distillation for Td=45, Tw=15
# /tmp/ipykernel_2377727/1966671643.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher.load_state_dict(torch.load(teacher_path, map_location=device))
# 🔍 Finding optimal learning rate...
# 100%|██████████| 200/200 [00:04<00:00, 41.07it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.61E-02
# [Distill] Epoch 01/50 - Train Loss: 4.4218 - Train Acc: 0.6338 - Val Loss: 0.9701 - Val Acc: 0.7253
# [Distill] Epoch 02/50 - Train Loss: 1.8690 - Train Acc: 0.8376 - Val Loss: 0.9886 - Val Acc: 0.7487
# [Distill] Epoch 03/50 - Train Loss: 1.4218 - Train Acc: 0.8757 - Val Loss: 0.7698 - Val Acc: 0.7882
# [Distill] Epoch 04/50 - Train Loss: 1.2241 - Train Acc: 0.8923 - Val Loss: 0.5314 - Val Acc: 0.8517
# [Distill] Epoch 05/50 - Train Loss: 1.0684 - Train Acc: 0.9051 - Val Loss: 0.7390 - Val Acc: 0.8254
# [Distill] Epoch 06/50 - Train Loss: 0.9733 - Train Acc: 0.9135 - Val Loss: 0.6598 - Val Acc: 0.8327
# [Distill] Epoch 07/50 - Train Loss: 0.9304 - Train Acc: 0.9175 - Val Loss: 0.6421 - Val Acc: 0.8466
# [Distill] Epoch 08/50 - Train Loss: 0.8361 - Train Acc: 0.9265 - Val Loss: 0.5965 - Val Acc: 0.8663
# [Distill] Epoch 09/50 - Train Loss: 0.8166 - Train Acc: 0.9306 - Val Loss: 0.5205 - Val Acc: 0.8970
# [Distill] Epoch 10/50 - Train Loss: 0.7931 - Train Acc: 0.9316 - Val Loss: 0.4416 - Val Acc: 0.8912
# [Distill] Epoch 11/50 - Train Loss: 0.6853 - Train Acc: 0.9413 - Val Loss: 0.4870 - Val Acc: 0.8904
# [Distill] Epoch 12/50 - Train Loss: 0.6740 - Train Acc: 0.9403 - Val Loss: 0.4740 - Val Acc: 0.8985
# [Distill] Epoch 13/50 - Train Loss: 0.6581 - Train Acc: 0.9424 - Val Loss: 0.6003 - Val Acc: 0.8722
# [Distill] Epoch 14/50 - Train Loss: 0.6428 - Train Acc: 0.9448 - Val Loss: 0.4177 - Val Acc: 0.9094
# [Distill] Epoch 15/50 - Train Loss: 0.6121 - Train Acc: 0.9479 - Val Loss: 0.4965 - Val Acc: 0.9050
# [Distill] Epoch 16/50 - Train Loss: 0.6090 - Train Acc: 0.9463 - Val Loss: 0.5097 - Val Acc: 0.8853
# [Distill] Epoch 17/50 - Train Loss: 0.6046 - Train Acc: 0.9475 - Val Loss: 0.4496 - Val Acc: 0.9065
# [Distill] Epoch 18/50 - Train Loss: 0.5569 - Train Acc: 0.9532 - Val Loss: 0.3773 - Val Acc: 0.9175
# [Distill] Epoch 19/50 - Train Loss: 0.5295 - Train Acc: 0.9562 - Val Loss: 0.4770 - Val Acc: 0.9072
# [Distill] Epoch 20/50 - Train Loss: 0.5523 - Train Acc: 0.9523 - Val Loss: 0.4365 - Val Acc: 0.9043
# [Distill] Epoch 21/50 - Train Loss: 0.5445 - Train Acc: 0.9544 - Val Loss: 0.4292 - Val Acc: 0.9080
# [Distill] Epoch 22/50 - Train Loss: 0.5466 - Train Acc: 0.9545 - Val Loss: 0.5062 - Val Acc: 0.9014
# [Distill] Epoch 23/50 - Train Loss: 0.5220 - Train Acc: 0.9563 - Val Loss: 0.3987 - Val Acc: 0.9204
# [Distill] Epoch 24/50 - Train Loss: 0.4862 - Train Acc: 0.9591 - Val Loss: 0.6559 - Val Acc: 0.8722
# [Distill] Epoch 25/50 - Train Loss: 0.4808 - Train Acc: 0.9586 - Val Loss: 0.3492 - Val Acc: 0.9321
# [Distill] Epoch 26/50 - Train Loss: 0.4655 - Train Acc: 0.9625 - Val Loss: 0.4612 - Val Acc: 0.9167
# [Distill] Epoch 27/50 - Train Loss: 0.5536 - Train Acc: 0.9519 - Val Loss: 0.3917 - Val Acc: 0.9145
# [Distill] Epoch 28/50 - Train Loss: 0.4612 - Train Acc: 0.9601 - Val Loss: 0.4009 - Val Acc: 0.9240
# [Distill] Epoch 29/50 - Train Loss: 0.4718 - Train Acc: 0.9598 - Val Loss: 0.3837 - Val Acc: 0.9262
# [Distill] Epoch 30/50 - Train Loss: 0.4482 - Train Acc: 0.9616 - Val Loss: 0.3353 - Val Acc: 0.9160
# [Distill] Epoch 31/50 - Train Loss: 0.4503 - Train Acc: 0.9624 - Val Loss: 0.4028 - Val Acc: 0.9167
# [Distill] Epoch 32/50 - Train Loss: 0.4389 - Train Acc: 0.9637 - Val Loss: 0.3463 - Val Acc: 0.9321
# [Distill] Epoch 33/50 - Train Loss: 0.4281 - Train Acc: 0.9674 - Val Loss: 0.4425 - Val Acc: 0.9182
# [Distill] Epoch 34/50 - Train Loss: 0.4910 - Train Acc: 0.9589 - Val Loss: 0.3892 - Val Acc: 0.9240
# [Distill] Epoch 35/50 - Train Loss: 0.4399 - Train Acc: 0.9645 - Val Loss: 0.3949 - Val Acc: 0.9233
# [Distill] Epoch 36/50 - Train Loss: 0.4104 - Train Acc: 0.9661 - Val Loss: 0.3415 - Val Acc: 0.9233
# [Distill] Epoch 37/50 - Train Loss: 0.3745 - Train Acc: 0.9702 - Val Loss: 0.4626 - Val Acc: 0.9160
# [Distill] Epoch 38/50 - Train Loss: 0.4064 - Train Acc: 0.9665 - Val Loss: 0.4413 - Val Acc: 0.9094
# [Distill] Epoch 39/50 - Train Loss: 0.4186 - Train Acc: 0.9659 - Val Loss: 0.4620 - Val Acc: 0.9138
# [Distill] Epoch 40/50 - Train Loss: 0.4171 - Train Acc: 0.9654 - Val Loss: 0.4088 - Val Acc: 0.9218
# [Distill] Epoch 41/50 - Train Loss: 0.3694 - Train Acc: 0.9705 - Val Loss: 0.2987 - Val Acc: 0.9262
# [Distill] Epoch 42/50 - Train Loss: 0.3710 - Train Acc: 0.9690 - Val Loss: 0.3739 - Val Acc: 0.9299
# [Distill] Epoch 43/50 - Train Loss: 0.3580 - Train Acc: 0.9728 - Val Loss: 0.4422 - Val Acc: 0.9233
# [Distill] Epoch 44/50 - Train Loss: 0.3667 - Train Acc: 0.9709 - Val Loss: 0.3490 - Val Acc: 0.9364
# [Distill] Epoch 45/50 - Train Loss: 0.4064 - Train Acc: 0.9676 - Val Loss: 0.2813 - Val Acc: 0.9372
# [Distill] Epoch 46/50 - Train Loss: 0.3450 - Train Acc: 0.9739 - Val Loss: 0.4727 - Val Acc: 0.9211
# [Distill] Epoch 47/50 - Train Loss: 0.3969 - Train Acc: 0.9690 - Val Loss: 0.5022 - Val Acc: 0.9299
# [Distill] Epoch 48/50 - Train Loss: 0.3530 - Train Acc: 0.9727 - Val Loss: 0.3874 - Val Acc: 0.9291
# [Distill] Epoch 49/50 - Train Loss: 0.3611 - Train Acc: 0.9709 - Val Loss: 0.4189 - Val Acc: 0.9284
# [Distill] Epoch 50/50 - Train Loss: 0.3097 - Train Acc: 0.9766 - Val Loss: 0.3349 - Val Acc: 0.9372
# /tmp/ipykernel_2377727/969224989.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# 📋 TEST Classification Report (Td=45, Tw=15):
#               precision    recall  f1-score   support
#
#     AESCrypt       1.00      1.00      1.00        53
#       Cerber       0.95      0.98      0.97       129
#     Darkside       0.96      0.94      0.95       231
#        Excel       1.00      1.00      1.00       129
#      Firefox       1.00      0.97      0.99       139
#    GandCrab4       0.90      0.90      0.90       230
#         Ryuk       0.99      0.94      0.96       139
#      SDelete       1.00      1.00      1.00        52
#   Sodinokibi       0.93      0.89      0.91       143
#   TeslaCrypt       0.79      0.99      0.88        72
#     WannaCry       1.00      1.00      1.00        61
#          Zip       1.00      1.00      1.00        53
#
#     accuracy                           0.95      1431
#    macro avg       0.96      0.97      0.96      1431
# weighted avg       0.95      0.95      0.95      1431
#
#
# 🚀 Knowledge Distillation for Td=45, Tw=20
# /tmp/ipykernel_2377727/1966671643.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher.load_state_dict(torch.load(teacher_path, map_location=device))
# 🔍 Finding optimal learning rate...
# 100%|██████████| 200/200 [00:05<00:00, 38.16it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 7.15E-03
# [Distill] Epoch 01/50 - Train Loss: 3.4304 - Train Acc: 0.6824 - Val Loss: 0.7866 - Val Acc: 0.7470
# [Distill] Epoch 02/50 - Train Loss: 1.3627 - Train Acc: 0.8570 - Val Loss: 0.6535 - Val Acc: 0.7931
# [Distill] Epoch 03/50 - Train Loss: 1.0591 - Train Acc: 0.8853 - Val Loss: 0.4437 - Val Acc: 0.8517
# [Distill] Epoch 04/50 - Train Loss: 0.9083 - Train Acc: 0.8993 - Val Loss: 0.5815 - Val Acc: 0.8227
# [Distill] Epoch 05/50 - Train Loss: 0.8243 - Train Acc: 0.9093 - Val Loss: 0.4101 - Val Acc: 0.8839
# [Distill] Epoch 06/50 - Train Loss: 0.7310 - Train Acc: 0.9171 - Val Loss: 0.5572 - Val Acc: 0.8505
# [Distill] Epoch 07/50 - Train Loss: 0.6428 - Train Acc: 0.9309 - Val Loss: 0.4286 - Val Acc: 0.8890
# [Distill] Epoch 08/50 - Train Loss: 0.5999 - Train Acc: 0.9352 - Val Loss: 0.4280 - Val Acc: 0.8833
# [Distill] Epoch 09/50 - Train Loss: 0.6115 - Train Acc: 0.9312 - Val Loss: 0.4237 - Val Acc: 0.8713
# [Distill] Epoch 10/50 - Train Loss: 0.5532 - Train Acc: 0.9377 - Val Loss: 0.4035 - Val Acc: 0.8896
# [Distill] Epoch 11/50 - Train Loss: 0.5328 - Train Acc: 0.9404 - Val Loss: 0.4644 - Val Acc: 0.8713
# [Distill] Epoch 12/50 - Train Loss: 0.5122 - Train Acc: 0.9422 - Val Loss: 0.4248 - Val Acc: 0.8896
# [Distill] Epoch 13/50 - Train Loss: 0.5052 - Train Acc: 0.9461 - Val Loss: 0.4187 - Val Acc: 0.8883
# [Distill] Epoch 14/50 - Train Loss: 0.4892 - Train Acc: 0.9458 - Val Loss: 0.3990 - Val Acc: 0.8921
# [Distill] Epoch 15/50 - Train Loss: 0.4457 - Train Acc: 0.9507 - Val Loss: 0.4419 - Val Acc: 0.8984
# [Distill] Epoch 16/50 - Train Loss: 0.4447 - Train Acc: 0.9504 - Val Loss: 0.3989 - Val Acc: 0.9041
# [Distill] Epoch 17/50 - Train Loss: 0.4604 - Train Acc: 0.9505 - Val Loss: 0.3397 - Val Acc: 0.8940
# [Distill] Epoch 18/50 - Train Loss: 0.4535 - Train Acc: 0.9516 - Val Loss: 0.3741 - Val Acc: 0.9060
# [Distill] Epoch 19/50 - Train Loss: 0.4187 - Train Acc: 0.9560 - Val Loss: 0.3052 - Val Acc: 0.9066
# [Distill] Epoch 20/50 - Train Loss: 0.4157 - Train Acc: 0.9554 - Val Loss: 0.3695 - Val Acc: 0.8991
# [Distill] Epoch 21/50 - Train Loss: 0.3922 - Train Acc: 0.9584 - Val Loss: 0.3039 - Val Acc: 0.9211
# [Distill] Epoch 22/50 - Train Loss: 0.3895 - Train Acc: 0.9560 - Val Loss: 0.3079 - Val Acc: 0.8940
# [Distill] Epoch 23/50 - Train Loss: 0.3782 - Train Acc: 0.9603 - Val Loss: 0.3571 - Val Acc: 0.8946
# [Distill] Epoch 24/50 - Train Loss: 0.3727 - Train Acc: 0.9595 - Val Loss: 0.2948 - Val Acc: 0.9091
# [Distill] Epoch 25/50 - Train Loss: 0.3890 - Train Acc: 0.9579 - Val Loss: 0.3412 - Val Acc: 0.8991
# [Distill] Epoch 26/50 - Train Loss: 0.3725 - Train Acc: 0.9618 - Val Loss: 0.2944 - Val Acc: 0.9022
# [Distill] Epoch 27/50 - Train Loss: 0.4109 - Train Acc: 0.9567 - Val Loss: 0.2989 - Val Acc: 0.9028
# [Distill] Epoch 28/50 - Train Loss: 0.3482 - Train Acc: 0.9638 - Val Loss: 0.2957 - Val Acc: 0.9123
# [Distill] Epoch 29/50 - Train Loss: 0.3419 - Train Acc: 0.9640 - Val Loss: 0.2517 - Val Acc: 0.9218
# [Distill] Epoch 30/50 - Train Loss: 0.3480 - Train Acc: 0.9641 - Val Loss: 0.2766 - Val Acc: 0.9136
# [Distill] Epoch 31/50 - Train Loss: 0.3304 - Train Acc: 0.9659 - Val Loss: 0.2025 - Val Acc: 0.9338
# [Distill] Epoch 32/50 - Train Loss: 0.3070 - Train Acc: 0.9691 - Val Loss: 0.2291 - Val Acc: 0.9306
# [Distill] Epoch 33/50 - Train Loss: 0.3381 - Train Acc: 0.9662 - Val Loss: 0.2810 - Val Acc: 0.9161
# [Distill] Epoch 34/50 - Train Loss: 0.3208 - Train Acc: 0.9671 - Val Loss: 0.2382 - Val Acc: 0.9180
# [Distill] Epoch 35/50 - Train Loss: 0.2952 - Train Acc: 0.9714 - Val Loss: 0.2594 - Val Acc: 0.9338
# [Distill] Epoch 36/50 - Train Loss: 0.3420 - Train Acc: 0.9646 - Val Loss: 0.2764 - Val Acc: 0.9028
# [Distill] Epoch 37/50 - Train Loss: 0.3031 - Train Acc: 0.9708 - Val Loss: 0.2709 - Val Acc: 0.9129
# [Distill] Epoch 38/50 - Train Loss: 0.3075 - Train Acc: 0.9694 - Val Loss: 0.2751 - Val Acc: 0.9155
# [Distill] Epoch 39/50 - Train Loss: 0.2916 - Train Acc: 0.9715 - Val Loss: 0.2871 - Val Acc: 0.9224
# [Distill] Epoch 40/50 - Train Loss: 0.2748 - Train Acc: 0.9737 - Val Loss: 0.2290 - Val Acc: 0.9356
# [Distill] Epoch 41/50 - Train Loss: 0.3078 - Train Acc: 0.9677 - Val Loss: 0.2501 - Val Acc: 0.9218
# [Distill] Epoch 42/50 - Train Loss: 0.2928 - Train Acc: 0.9711 - Val Loss: 0.2184 - Val Acc: 0.9344
# [Distill] Epoch 43/50 - Train Loss: 0.2823 - Train Acc: 0.9720 - Val Loss: 0.2324 - Val Acc: 0.9319
# [Distill] Epoch 44/50 - Train Loss: 0.2909 - Train Acc: 0.9717 - Val Loss: 0.2623 - Val Acc: 0.9249
# [Distill] Epoch 45/50 - Train Loss: 0.2749 - Train Acc: 0.9728 - Val Loss: 0.2332 - Val Acc: 0.9237
# [Distill] Epoch 46/50 - Train Loss: 0.2991 - Train Acc: 0.9713 - Val Loss: 0.2253 - Val Acc: 0.9312
# [Distill] Epoch 47/50 - Train Loss: 0.2771 - Train Acc: 0.9726 - Val Loss: 0.2324 - Val Acc: 0.9356
# [Distill] Epoch 48/50 - Train Loss: 0.3258 - Train Acc: 0.9684 - Val Loss: 0.2854 - Val Acc: 0.9117
# [Distill] Epoch 49/50 - Train Loss: 0.2822 - Train Acc: 0.9728 - Val Loss: 0.2528 - Val Acc: 0.9237
# [Distill] Epoch 50/50 - Train Loss: 0.2671 - Train Acc: 0.9730 - Val Loss: 0.2051 - Val Acc: 0.9312
# /tmp/ipykernel_2377727/969224989.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# 📋 TEST Classification Report (Td=45, Tw=20):
#               precision    recall  f1-score   support
#
#     AESCrypt       0.97      0.97      0.97        60
# ...
#   teacher.load_state_dict(torch.load(teacher_path, map_location=device))
# 🔍 Finding optimal learning rate...
# 100%|██████████| 200/200 [00:05<00:00, 39.48it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 1.07E-02
# [Distill] Epoch 01/50 - Train Loss: 4.5062 - Train Acc: 0.6440 - Val Loss: 1.3366 - Val Acc: 0.6506
# [Distill] Epoch 02/50 - Train Loss: 1.8730 - Train Acc: 0.8358 - Val Loss: 0.6598 - Val Acc: 0.8139
# [Distill] Epoch 03/50 - Train Loss: 1.3652 - Train Acc: 0.8799 - Val Loss: 0.6905 - Val Acc: 0.8152
# [Distill] Epoch 04/50 - Train Loss: 1.1296 - Train Acc: 0.8979 - Val Loss: 0.5412 - Val Acc: 0.8570
# [Distill] Epoch 05/50 - Train Loss: 0.9826 - Train Acc: 0.9140 - Val Loss: 0.4992 - Val Acc: 0.8684
# [Distill] Epoch 06/50 - Train Loss: 0.8818 - Train Acc: 0.9201 - Val Loss: 0.5195 - Val Acc: 0.8633
# [Distill] Epoch 07/50 - Train Loss: 0.8140 - Train Acc: 0.9278 - Val Loss: 0.5616 - Val Acc: 0.8671
# [Distill] Epoch 08/50 - Train Loss: 0.7098 - Train Acc: 0.9372 - Val Loss: 0.4729 - Val Acc: 0.8835
# [Distill] Epoch 09/50 - Train Loss: 0.7292 - Train Acc: 0.9385 - Val Loss: 0.5474 - Val Acc: 0.8633
# [Distill] Epoch 10/50 - Train Loss: 0.6168 - Train Acc: 0.9449 - Val Loss: 0.4124 - Val Acc: 0.9013
# [Distill] Epoch 11/50 - Train Loss: 0.6231 - Train Acc: 0.9484 - Val Loss: 0.4810 - Val Acc: 0.8772
# [Distill] Epoch 12/50 - Train Loss: 0.5821 - Train Acc: 0.9516 - Val Loss: 0.4242 - Val Acc: 0.9025
# [Distill] Epoch 13/50 - Train Loss: 0.4926 - Train Acc: 0.9576 - Val Loss: 0.4160 - Val Acc: 0.9051
# [Distill] Epoch 14/50 - Train Loss: 0.5808 - Train Acc: 0.9497 - Val Loss: 0.3964 - Val Acc: 0.9000
# [Distill] Epoch 15/50 - Train Loss: 0.5219 - Train Acc: 0.9573 - Val Loss: 0.5096 - Val Acc: 0.8949
# [Distill] Epoch 16/50 - Train Loss: 0.4705 - Train Acc: 0.9622 - Val Loss: 0.4934 - Val Acc: 0.8886
# [Distill] Epoch 17/50 - Train Loss: 0.5049 - Train Acc: 0.9568 - Val Loss: 0.4090 - Val Acc: 0.9139
# [Distill] Epoch 18/50 - Train Loss: 0.4569 - Train Acc: 0.9625 - Val Loss: 0.4002 - Val Acc: 0.9253
# [Distill] Epoch 19/50 - Train Loss: 0.5089 - Train Acc: 0.9605 - Val Loss: 0.4022 - Val Acc: 0.9127
# [Distill] Epoch 20/50 - Train Loss: 0.4504 - Train Acc: 0.9653 - Val Loss: 0.3103 - Val Acc: 0.9329
# [Distill] Epoch 21/50 - Train Loss: 0.4169 - Train Acc: 0.9652 - Val Loss: 0.3451 - Val Acc: 0.9278
# [Distill] Epoch 22/50 - Train Loss: 0.3860 - Train Acc: 0.9694 - Val Loss: 0.4152 - Val Acc: 0.9228
# [Distill] Epoch 23/50 - Train Loss: 0.3896 - Train Acc: 0.9693 - Val Loss: 0.2876 - Val Acc: 0.9354
# [Distill] Epoch 24/50 - Train Loss: 0.4447 - Train Acc: 0.9653 - Val Loss: 0.2952 - Val Acc: 0.9380
# [Distill] Epoch 25/50 - Train Loss: 0.3747 - Train Acc: 0.9713 - Val Loss: 0.3877 - Val Acc: 0.9241
# [Distill] Epoch 26/50 - Train Loss: 0.3766 - Train Acc: 0.9722 - Val Loss: 0.3263 - Val Acc: 0.9266
# [Distill] Epoch 27/50 - Train Loss: 0.3457 - Train Acc: 0.9722 - Val Loss: 0.3181 - Val Acc: 0.9190
# [Distill] Epoch 28/50 - Train Loss: 0.3787 - Train Acc: 0.9694 - Val Loss: 0.3032 - Val Acc: 0.9329
# [Distill] Epoch 29/50 - Train Loss: 0.3591 - Train Acc: 0.9722 - Val Loss: 0.2649 - Val Acc: 0.9392
# [Distill] Epoch 30/50 - Train Loss: 0.3124 - Train Acc: 0.9766 - Val Loss: 0.3685 - Val Acc: 0.9342
# [Distill] Epoch 31/50 - Train Loss: 0.3214 - Train Acc: 0.9764 - Val Loss: 0.4738 - Val Acc: 0.9101
# [Distill] Epoch 32/50 - Train Loss: 0.4574 - Train Acc: 0.9633 - Val Loss: 0.4068 - Val Acc: 0.9127
# [Distill] Epoch 33/50 - Train Loss: 0.3604 - Train Acc: 0.9733 - Val Loss: 0.2867 - Val Acc: 0.9316
# [Distill] Epoch 34/50 - Train Loss: 0.3177 - Train Acc: 0.9744 - Val Loss: 0.3711 - Val Acc: 0.9253
# [Distill] Epoch 35/50 - Train Loss: 0.3395 - Train Acc: 0.9743 - Val Loss: 0.4109 - Val Acc: 0.9316
# [Distill] Epoch 36/50 - Train Loss: 0.2973 - Train Acc: 0.9792 - Val Loss: 0.4275 - Val Acc: 0.9241
# [Distill] Epoch 37/50 - Train Loss: 0.3119 - Train Acc: 0.9751 - Val Loss: 0.3036 - Val Acc: 0.9228
# [Distill] Epoch 38/50 - Train Loss: 0.3249 - Train Acc: 0.9752 - Val Loss: 0.2940 - Val Acc: 0.9380
# [Distill] Epoch 39/50 - Train Loss: 0.2758 - Train Acc: 0.9818 - Val Loss: 0.3893 - Val Acc: 0.9354
# [Distill] Epoch 40/50 - Train Loss: 0.3225 - Train Acc: 0.9744 - Val Loss: 0.2881 - Val Acc: 0.9380
# [Distill] Epoch 41/50 - Train Loss: 0.2753 - Train Acc: 0.9805 - Val Loss: 0.3274 - Val Acc: 0.9380
# [Distill] Epoch 42/50 - Train Loss: 0.2745 - Train Acc: 0.9805 - Val Loss: 0.3013 - Val Acc: 0.9316
# [Distill] Epoch 43/50 - Train Loss: 0.2908 - Train Acc: 0.9799 - Val Loss: 0.4141 - Val Acc: 0.9228
# [Distill] Epoch 44/50 - Train Loss: 0.2633 - Train Acc: 0.9823 - Val Loss: 0.4113 - Val Acc: 0.9354
# [Distill] Epoch 45/50 - Train Loss: 0.2607 - Train Acc: 0.9802 - Val Loss: 0.3405 - Val Acc: 0.9418
# [Distill] Epoch 46/50 - Train Loss: 0.2623 - Train Acc: 0.9823 - Val Loss: 0.6742 - Val Acc: 0.8886
# [Distill] Epoch 47/50 - Train Loss: 0.3108 - Train Acc: 0.9772 - Val Loss: 0.4979 - Val Acc: 0.9165
# [Distill] Epoch 48/50 - Train Loss: 0.2864 - Train Acc: 0.9791 - Val Loss: 0.3701 - Val Acc: 0.9266
# [Distill] Epoch 49/50 - Train Loss: 0.2631 - Train Acc: 0.9805 - Val Loss: 0.3298 - Val Acc: 0.9443
# [Distill] Epoch 50/50 - Train Loss: 0.2619 - Train Acc: 0.9818 - Val Loss: 0.3753 - Val Acc: 0.9304
# /tmp/ipykernel_2377727/969224989.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# 📋 TEST Classification Report (Td=60, Tw=15):
#               precision    recall  f1-score   support
#
#     AESCrypt       0.93      0.93      0.93        27
#       Cerber       1.00      0.99      0.99        74
#     Darkside       1.00      0.93      0.96       140
#        Excel       1.00      0.97      0.99        74
#      Firefox       1.00      0.96      0.98        82
#    GandCrab4       0.90      0.97      0.93       141
#         Ryuk       0.96      0.96      0.96        81
#      SDelete       0.93      1.00      0.96        27
#   Sodinokibi       0.97      0.94      0.96        83
#   TeslaCrypt       0.84      0.95      0.89        38
#     WannaCry       1.00      1.00      1.00        32
#          Zip       1.00      1.00      1.00        27
#
#     accuracy                           0.96       826
#    macro avg       0.96      0.97      0.96       826
# weighted avg       0.96      0.96      0.96       826
#
#
# 🚀 Knowledge Distillation for Td=60, Tw=20
# /tmp/ipykernel_2377727/1966671643.py:57: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   teacher.load_state_dict(torch.load(teacher_path, map_location=device))
# 🔍 Finding optimal learning rate...
# 100%|██████████| 200/200 [00:04<00:00, 40.20it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()
# LR suggestion: steepest gradient
# Suggested LR: 2.41E-02
# [Distill] Epoch 01/50 - Train Loss: 4.5239 - Train Acc: 0.6173 - Val Loss: 0.9039 - Val Acc: 0.7178
# [Distill] Epoch 02/50 - Train Loss: 1.5010 - Train Acc: 0.8579 - Val Loss: 0.5506 - Val Acc: 0.7951
# [Distill] Epoch 03/50 - Train Loss: 1.1954 - Train Acc: 0.8810 - Val Loss: 0.7784 - Val Acc: 0.7857
# [Distill] Epoch 04/50 - Train Loss: 0.9582 - Train Acc: 0.9061 - Val Loss: 0.7849 - Val Acc: 0.7564
# [Distill] Epoch 05/50 - Train Loss: 0.8797 - Train Acc: 0.9151 - Val Loss: 0.7644 - Val Acc: 0.8044
# [Distill] Epoch 06/50 - Train Loss: 0.7434 - Train Acc: 0.9268 - Val Loss: 0.6033 - Val Acc: 0.8396
# [Distill] Epoch 07/50 - Train Loss: 0.6885 - Train Acc: 0.9350 - Val Loss: 0.5109 - Val Acc: 0.8642
# [Distill] Epoch 08/50 - Train Loss: 0.6541 - Train Acc: 0.9369 - Val Loss: 0.3465 - Val Acc: 0.9052
# [Distill] Epoch 09/50 - Train Loss: 0.6296 - Train Acc: 0.9407 - Val Loss: 0.4397 - Val Acc: 0.8876
# [Distill] Epoch 10/50 - Train Loss: 0.5735 - Train Acc: 0.9454 - Val Loss: 0.3958 - Val Acc: 0.8911
# [Distill] Epoch 11/50 - Train Loss: 0.5609 - Train Acc: 0.9487 - Val Loss: 0.2955 - Val Acc: 0.9169
# [Distill] Epoch 12/50 - Train Loss: 0.4989 - Train Acc: 0.9534 - Val Loss: 0.3291 - Val Acc: 0.8946
# [Distill] Epoch 13/50 - Train Loss: 0.4824 - Train Acc: 0.9571 - Val Loss: 0.3163 - Val Acc: 0.9145
# [Distill] Epoch 14/50 - Train Loss: 0.4715 - Train Acc: 0.9547 - Val Loss: 0.3932 - Val Acc: 0.8899
# [Distill] Epoch 15/50 - Train Loss: 0.4943 - Train Acc: 0.9541 - Val Loss: 0.2446 - Val Acc: 0.9356
# [Distill] Epoch 16/50 - Train Loss: 0.4410 - Train Acc: 0.9583 - Val Loss: 0.2973 - Val Acc: 0.9122
# [Distill] Epoch 17/50 - Train Loss: 0.4143 - Train Acc: 0.9606 - Val Loss: 0.3077 - Val Acc: 0.9192
# [Distill] Epoch 18/50 - Train Loss: 0.3941 - Train Acc: 0.9646 - Val Loss: 0.3273 - Val Acc: 0.9192
# [Distill] Epoch 19/50 - Train Loss: 0.4482 - Train Acc: 0.9574 - Val Loss: 0.3424 - Val Acc: 0.9075
# [Distill] Epoch 20/50 - Train Loss: 0.4220 - Train Acc: 0.9602 - Val Loss: 0.3272 - Val Acc: 0.9157
# [Distill] Epoch 21/50 - Train Loss: 0.4120 - Train Acc: 0.9621 - Val Loss: 0.3471 - Val Acc: 0.9005
# [Distill] Epoch 22/50 - Train Loss: 0.4032 - Train Acc: 0.9625 - Val Loss: 0.4001 - Val Acc: 0.9122
# [Distill] Epoch 23/50 - Train Loss: 0.3820 - Train Acc: 0.9668 - Val Loss: 0.3259 - Val Acc: 0.9215
# [Distill] Epoch 24/50 - Train Loss: 0.3579 - Train Acc: 0.9674 - Val Loss: 0.2356 - Val Acc: 0.9391
# [Distill] Epoch 25/50 - Train Loss: 0.3969 - Train Acc: 0.9660 - Val Loss: 0.4117 - Val Acc: 0.9110
# [Distill] Epoch 26/50 - Train Loss: 0.3498 - Train Acc: 0.9685 - Val Loss: 0.3676 - Val Acc: 0.9262
# [Distill] Epoch 27/50 - Train Loss: 0.3432 - Train Acc: 0.9702 - Val Loss: 0.3011 - Val Acc: 0.9192
# [Distill] Epoch 28/50 - Train Loss: 0.3304 - Train Acc: 0.9727 - Val Loss: 0.2840 - Val Acc: 0.9274
# [Distill] Epoch 29/50 - Train Loss: 0.3317 - Train Acc: 0.9718 - Val Loss: 0.3048 - Val Acc: 0.9309
# [Distill] Epoch 30/50 - Train Loss: 0.3106 - Train Acc: 0.9739 - Val Loss: 0.3820 - Val Acc: 0.9133
# [Distill] Epoch 31/50 - Train Loss: 0.3726 - Train Acc: 0.9676 - Val Loss: 0.3524 - Val Acc: 0.9215
# [Distill] Epoch 32/50 - Train Loss: 0.2876 - Train Acc: 0.9776 - Val Loss: 0.3393 - Val Acc: 0.9145
# [Distill] Epoch 33/50 - Train Loss: 0.2966 - Train Acc: 0.9756 - Val Loss: 0.3062 - Val Acc: 0.9333
# [Distill] Epoch 34/50 - Train Loss: 0.3107 - Train Acc: 0.9748 - Val Loss: 0.4483 - Val Acc: 0.8934
# [Distill] Epoch 35/50 - Train Loss: 0.3456 - Train Acc: 0.9713 - Val Loss: 0.6068 - Val Acc: 0.8571
# [Distill] Epoch 36/50 - Train Loss: 0.3297 - Train Acc: 0.9719 - Val Loss: 0.2820 - Val Acc: 0.9391
# [Distill] Epoch 37/50 - Train Loss: 0.2584 - Train Acc: 0.9817 - Val Loss: 0.3243 - Val Acc: 0.9379
# [Distill] Epoch 38/50 - Train Loss: 0.2911 - Train Acc: 0.9767 - Val Loss: 0.3678 - Val Acc: 0.9239
# [Distill] Epoch 39/50 - Train Loss: 0.2764 - Train Acc: 0.9785 - Val Loss: 0.2647 - Val Acc: 0.9368
# [Distill] Epoch 40/50 - Train Loss: 0.2846 - Train Acc: 0.9788 - Val Loss: 0.2842 - Val Acc: 0.9368
# [Distill] Epoch 41/50 - Train Loss: 0.2574 - Train Acc: 0.9804 - Val Loss: 0.3363 - Val Acc: 0.9286
# [Distill] Epoch 42/50 - Train Loss: 0.2701 - Train Acc: 0.9803 - Val Loss: 0.3070 - Val Acc: 0.9368
# [Distill] Epoch 43/50 - Train Loss: 0.2911 - Train Acc: 0.9771 - Val Loss: 0.2999 - Val Acc: 0.9297
# [Distill] Epoch 44/50 - Train Loss: 0.2472 - Train Acc: 0.9820 - Val Loss: 0.3505 - Val Acc: 0.9204
# [Distill] Epoch 45/50 - Train Loss: 0.2389 - Train Acc: 0.9829 - Val Loss: 0.3575 - Val Acc: 0.9274
# [Distill] Epoch 46/50 - Train Loss: 0.2791 - Train Acc: 0.9783 - Val Loss: 0.2695 - Val Acc: 0.9415
# [Distill] Epoch 47/50 - Train Loss: 0.2538 - Train Acc: 0.9825 - Val Loss: 0.2945 - Val Acc: 0.9344
# [Distill] Epoch 48/50 - Train Loss: 0.2763 - Train Acc: 0.9777 - Val Loss: 0.2670 - Val Acc: 0.9262
# [Distill] Epoch 49/50 - Train Loss: 0.2829 - Train Acc: 0.9768 - Val Loss: 0.2630 - Val Acc: 0.9438
# [Distill] Epoch 50/50 - Train Loss: 0.2686 - Train Acc: 0.9786 - Val Loss: 0.2867 - Val Acc: 0.9461
# /tmp/ipykernel_2377727/969224989.py:81: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# 📋 TEST Classification Report (Td=60, Tw=20):
#               precision    recall  f1-score   support
#
#     AESCrypt       1.00      0.97      0.98        29
#       Cerber       0.99      0.98      0.98        81
#     Darkside       0.97      0.94      0.95       154
#        Excel       1.00      1.00      1.00        81
#      Firefox       0.98      0.98      0.98        88
#    GandCrab4       0.92      0.94      0.93       154
#         Ryuk       0.95      0.89      0.92        91
#      SDelete       0.97      1.00      0.98        28
#   Sodinokibi       0.88      0.94      0.91        93
#   TeslaCrypt       0.87      0.93      0.90        43
#     WannaCry       1.00      1.00      1.00        33
#          Zip       1.00      1.00      1.00        29
#
#     accuracy                           0.95       904
#    macro avg       0.96      0.96      0.96       904
# weighted avg       0.95      0.95      0.95       904

# %%
import torch
import torch.nn as nn
import torch.optim as optim

def train_student_baseline(student, train_loader, val_loader, device,
                           epochs=50, lr=0.0005, class_weights=None,
                           best_model_path="best_student_baseline.pth"):
    
    student.to(device)
    optimizer = optim.Adam(student.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss(weight=class_weights)

    best_val_acc = 0
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    for epoch in range(epochs):
        student.train()
        total_loss, correct = 0.0, 0

        for streams, labels in train_loader:
            streams = [s.to(device) for s in streams]
            labels = labels.to(device)

            outputs = student(streams)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            correct += (outputs.argmax(dim=1) == labels).sum().item()

        train_acc = correct / len(train_loader.dataset)
        train_losses.append(total_loss / len(train_loader))
        train_accuracies.append(train_acc)

        # === Validation ===
        student.eval()
        val_loss, val_correct = 0.0, 0
        with torch.no_grad():
            for streams, labels in val_loader:
                streams = [s.to(device) for s in streams]
                labels = labels.to(device)

                outputs = student(streams)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                val_correct += (outputs.argmax(dim=1) == labels).sum().item()

        val_acc = val_correct / len(val_loader.dataset)
        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(val_acc)

        print(f"[Baseline] Epoch {epoch+1:02d}/{epochs} - "
              f"Train Loss: {train_losses[-1]:.4f} - Train Acc: {train_acc:.4f} "
              f"- Val Loss: {val_losses[-1]:.4f} - Val Acc: {val_acc:.4f}")

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(student.state_dict(), best_model_path)

    student.load_state_dict(torch.load(best_model_path))
    return train_accuracies, val_accuracies, train_losses, val_losses

# %%
import os
import torch
from sklearn.preprocessing import LabelEncoder
from imblearn.over_sampling import SMOTE
from torch.utils.data import DataLoader

baseline_save_dir = "/home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student"
os.makedirs(baseline_save_dir, exist_ok=True)

for T_d in detection_times:
    for T_w in window_sizes:
        T_len = T_d - T_w + 1
        expected_shape = (T_len, NUM_FEATURES)

        print(f"\n🚀 Training Standalone Student for Td={T_d}, Tw={T_w} (T_len={T_len})")

        # === Paths
        folder_name = f"X_csv_split_{T_len}"
        input_dir = os.path.join(base_dir, f"New_{T_d}", f"{T_w}", "split_tws", folder_name)
        train_path = os.path.join(input_dir, "train")
        val_path   = os.path.join(input_dir, "val")
        model_path = os.path.join(baseline_save_dir, f"student_baseline_Td{T_d}_Tw{T_w}.pth")

        # === Load Data
        X_train_raw, y_train_raw = load_split_from_folder(train_path, expected_shape)
        X_val_raw, y_val_raw     = load_split_from_folder(val_path, expected_shape)

        # === Encode + Apply SMOTE
        label_encoder = LabelEncoder()
        y_train_enc = label_encoder.fit_transform(y_train_raw)
        X_train_flat = X_train_raw.reshape(X_train_raw.shape[0], -1)
        X_resampled, y_resampled = SMOTE().fit_resample(X_train_flat, y_train_enc)
        X_train_bal = X_resampled.reshape(-1, T_len, NUM_FEATURES)
        y_train_str = label_encoder.inverse_transform(y_resampled)

        # === Create Datasets and Loaders
        train_dataset = MultiStreamDataset(X_train_bal, y_train_str, label_encoder, augment=True)
        val_dataset   = MultiStreamDataset(X_val_raw, y_val_raw, label_encoder, augment=False)
        train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        val_loader   = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)

        # === Compute class weights from rebalanced data
        class_weights_tensor = compute_class_weights(label_encoder.transform(y_train_str), device)

        # === Initialize and Train Model
        student_model = StudentCNN(input_length=T_len, num_classes=len(label_encoder.classes_)).to(device)
        train_accs, val_accs, train_losses, val_losses = train_student_baseline(
            student=student_model,
            train_loader=train_loader,
            val_loader=val_loader,
            device=device,
            epochs=NUM_EPOCHS,
            lr=0.01,
            class_weights=class_weights_tensor,
            best_model_path=model_path
        )

        print(f"✅ Saved baseline model to: {model_path}")
# Out:
# 🚀 Training Standalone Student for Td=30, Tw=10 (T_len=21)
# [Baseline] Epoch 01/50 - Train Loss: 1.0485 - Train Acc: 0.6023 - Val Loss: 0.8469 - Val Acc: 0.6578
# [Baseline] Epoch 02/50 - Train Loss: 0.6584 - Train Acc: 0.7589 - Val Loss: 0.6692 - Val Acc: 0.7435
# [Baseline] Epoch 03/50 - Train Loss: 0.5806 - Train Acc: 0.7833 - Val Loss: 0.6508 - Val Acc: 0.7570
# [Baseline] Epoch 04/50 - Train Loss: 0.5307 - Train Acc: 0.8000 - Val Loss: 0.5574 - Val Acc: 0.7976
# [Baseline] Epoch 05/50 - Train Loss: 0.5038 - Train Acc: 0.8127 - Val Loss: 0.5345 - Val Acc: 0.7876
# [Baseline] Epoch 06/50 - Train Loss: 0.4654 - Train Acc: 0.8277 - Val Loss: 0.5637 - Val Acc: 0.7951
# [Baseline] Epoch 07/50 - Train Loss: 0.4595 - Train Acc: 0.8273 - Val Loss: 0.5632 - Val Acc: 0.7961
# [Baseline] Epoch 08/50 - Train Loss: 0.4411 - Train Acc: 0.8333 - Val Loss: 0.5155 - Val Acc: 0.8101
# [Baseline] Epoch 09/50 - Train Loss: 0.4315 - Train Acc: 0.8377 - Val Loss: 0.4730 - Val Acc: 0.8362
# [Baseline] Epoch 10/50 - Train Loss: 0.4238 - Train Acc: 0.8395 - Val Loss: 0.4653 - Val Acc: 0.8342
# [Baseline] Epoch 11/50 - Train Loss: 0.4229 - Train Acc: 0.8413 - Val Loss: 0.5163 - Val Acc: 0.8151
# [Baseline] Epoch 12/50 - Train Loss: 0.4074 - Train Acc: 0.8480 - Val Loss: 0.4760 - Val Acc: 0.8231
# [Baseline] Epoch 13/50 - Train Loss: 0.4102 - Train Acc: 0.8454 - Val Loss: 0.4444 - Val Acc: 0.8377
# [Baseline] Epoch 14/50 - Train Loss: 0.3921 - Train Acc: 0.8540 - Val Loss: 0.4524 - Val Acc: 0.8432
# [Baseline] Epoch 15/50 - Train Loss: 0.3788 - Train Acc: 0.8591 - Val Loss: 0.4737 - Val Acc: 0.8342
# [Baseline] Epoch 16/50 - Train Loss: 0.3828 - Train Acc: 0.8572 - Val Loss: 0.4701 - Val Acc: 0.8156
# [Baseline] Epoch 17/50 - Train Loss: 0.3804 - Train Acc: 0.8580 - Val Loss: 0.5048 - Val Acc: 0.8191
# [Baseline] Epoch 18/50 - Train Loss: 0.3728 - Train Acc: 0.8588 - Val Loss: 0.4294 - Val Acc: 0.8452
# [Baseline] Epoch 19/50 - Train Loss: 0.3620 - Train Acc: 0.8649 - Val Loss: 0.4358 - Val Acc: 0.8522
# [Baseline] Epoch 20/50 - Train Loss: 0.3741 - Train Acc: 0.8588 - Val Loss: 0.4466 - Val Acc: 0.8472
# [Baseline] Epoch 21/50 - Train Loss: 0.3626 - Train Acc: 0.8667 - Val Loss: 0.4538 - Val Acc: 0.8357
# [Baseline] Epoch 22/50 - Train Loss: 0.3479 - Train Acc: 0.8713 - Val Loss: 0.4128 - Val Acc: 0.8622
# [Baseline] Epoch 23/50 - Train Loss: 0.3622 - Train Acc: 0.8661 - Val Loss: 0.4246 - Val Acc: 0.8527
# [Baseline] Epoch 24/50 - Train Loss: 0.3495 - Train Acc: 0.8719 - Val Loss: 0.4769 - Val Acc: 0.8126
# [Baseline] Epoch 25/50 - Train Loss: 0.3541 - Train Acc: 0.8658 - Val Loss: 0.4342 - Val Acc: 0.8462
# [Baseline] Epoch 26/50 - Train Loss: 0.3466 - Train Acc: 0.8719 - Val Loss: 0.4473 - Val Acc: 0.8557
# [Baseline] Epoch 27/50 - Train Loss: 0.3406 - Train Acc: 0.8718 - Val Loss: 0.4316 - Val Acc: 0.8597
# [Baseline] Epoch 28/50 - Train Loss: 0.3410 - Train Acc: 0.8715 - Val Loss: 0.4853 - Val Acc: 0.8302
# [Baseline] Epoch 29/50 - Train Loss: 0.3373 - Train Acc: 0.8752 - Val Loss: 0.4963 - Val Acc: 0.7991
# [Baseline] Epoch 30/50 - Train Loss: 0.3388 - Train Acc: 0.8723 - Val Loss: 0.4055 - Val Acc: 0.8617
# [Baseline] Epoch 31/50 - Train Loss: 0.3256 - Train Acc: 0.8779 - Val Loss: 0.4195 - Val Acc: 0.8612
# [Baseline] Epoch 32/50 - Train Loss: 0.3332 - Train Acc: 0.8755 - Val Loss: 0.4388 - Val Acc: 0.8532
# [Baseline] Epoch 33/50 - Train Loss: 0.3318 - Train Acc: 0.8756 - Val Loss: 0.4419 - Val Acc: 0.8497
# [Baseline] Epoch 34/50 - Train Loss: 0.3212 - Train Acc: 0.8790 - Val Loss: 0.4070 - Val Acc: 0.8577
# [Baseline] Epoch 35/50 - Train Loss: 0.3240 - Train Acc: 0.8807 - Val Loss: 0.3964 - Val Acc: 0.8677
# [Baseline] Epoch 36/50 - Train Loss: 0.3153 - Train Acc: 0.8812 - Val Loss: 0.4106 - Val Acc: 0.8642
# [Baseline] Epoch 37/50 - Train Loss: 0.3230 - Train Acc: 0.8799 - Val Loss: 0.4010 - Val Acc: 0.8647
# [Baseline] Epoch 38/50 - Train Loss: 0.3140 - Train Acc: 0.8819 - Val Loss: 0.3875 - Val Acc: 0.8557
# [Baseline] Epoch 39/50 - Train Loss: 0.3170 - Train Acc: 0.8797 - Val Loss: 0.4192 - Val Acc: 0.8427
# [Baseline] Epoch 40/50 - Train Loss: 0.3144 - Train Acc: 0.8817 - Val Loss: 0.4877 - Val Acc: 0.8111
# [Baseline] Epoch 41/50 - Train Loss: 0.3165 - Train Acc: 0.8820 - Val Loss: 0.4492 - Val Acc: 0.8562
# [Baseline] Epoch 42/50 - Train Loss: 0.3172 - Train Acc: 0.8821 - Val Loss: 0.4095 - Val Acc: 0.8637
# [Baseline] Epoch 43/50 - Train Loss: 0.3114 - Train Acc: 0.8845 - Val Loss: 0.4284 - Val Acc: 0.8492
# [Baseline] Epoch 44/50 - Train Loss: 0.3088 - Train Acc: 0.8843 - Val Loss: 0.4565 - Val Acc: 0.8317
# [Baseline] Epoch 45/50 - Train Loss: 0.3057 - Train Acc: 0.8876 - Val Loss: 0.4082 - Val Acc: 0.8627
# [Baseline] Epoch 46/50 - Train Loss: 0.3029 - Train Acc: 0.8866 - Val Loss: 0.3922 - Val Acc: 0.8512
# [Baseline] Epoch 47/50 - Train Loss: 0.3020 - Train Acc: 0.8856 - Val Loss: 0.5062 - Val Acc: 0.7996
# [Baseline] Epoch 48/50 - Train Loss: 0.3001 - Train Acc: 0.8874 - Val Loss: 0.4383 - Val Acc: 0.8477
# [Baseline] Epoch 49/50 - Train Loss: 0.2948 - Train Acc: 0.8905 - Val Loss: 0.4757 - Val Acc: 0.8472
# [Baseline] Epoch 50/50 - Train Loss: 0.2991 - Train Acc: 0.8900 - Val Loss: 0.4074 - Val Acc: 0.8647
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td30_Tw10.pth
#
# 🚀 Training Standalone Student for Td=30, Tw=15 (T_len=16)
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# [Baseline] Epoch 01/50 - Train Loss: 0.9532 - Train Acc: 0.6598 - Val Loss: 0.8298 - Val Acc: 0.6875
# [Baseline] Epoch 02/50 - Train Loss: 0.5531 - Train Acc: 0.7932 - Val Loss: 0.6660 - Val Acc: 0.7658
# [Baseline] Epoch 03/50 - Train Loss: 0.4739 - Train Acc: 0.8235 - Val Loss: 0.6289 - Val Acc: 0.7559
# [Baseline] Epoch 04/50 - Train Loss: 0.4284 - Train Acc: 0.8390 - Val Loss: 0.5735 - Val Acc: 0.7980
# [Baseline] Epoch 05/50 - Train Loss: 0.3923 - Train Acc: 0.8530 - Val Loss: 0.5616 - Val Acc: 0.8075
# [Baseline] Epoch 06/50 - Train Loss: 0.3645 - Train Acc: 0.8656 - Val Loss: 0.5193 - Val Acc: 0.8174
# [Baseline] Epoch 07/50 - Train Loss: 0.3605 - Train Acc: 0.8669 - Val Loss: 0.4710 - Val Acc: 0.8402
# [Baseline] Epoch 08/50 - Train Loss: 0.3377 - Train Acc: 0.8750 - Val Loss: 0.5251 - Val Acc: 0.8140
# [Baseline] Epoch 09/50 - Train Loss: 0.3231 - Train Acc: 0.8805 - Val Loss: 0.4986 - Val Acc: 0.8231
# [Baseline] Epoch 10/50 - Train Loss: 0.3189 - Train Acc: 0.8819 - Val Loss: 0.4864 - Val Acc: 0.8394
# [Baseline] Epoch 11/50 - Train Loss: 0.2993 - Train Acc: 0.8894 - Val Loss: 0.4641 - Val Acc: 0.8349
# [Baseline] Epoch 12/50 - Train Loss: 0.3051 - Train Acc: 0.8838 - Val Loss: 0.4185 - Val Acc: 0.8633
# [Baseline] Epoch 13/50 - Train Loss: 0.2841 - Train Acc: 0.8941 - Val Loss: 0.4305 - Val Acc: 0.8527
# [Baseline] Epoch 14/50 - Train Loss: 0.2894 - Train Acc: 0.8939 - Val Loss: 0.5058 - Val Acc: 0.8314
# [Baseline] Epoch 15/50 - Train Loss: 0.2730 - Train Acc: 0.8998 - Val Loss: 0.4844 - Val Acc: 0.8356
# [Baseline] Epoch 16/50 - Train Loss: 0.2752 - Train Acc: 0.8987 - Val Loss: 0.4153 - Val Acc: 0.8675
# [Baseline] Epoch 17/50 - Train Loss: 0.2669 - Train Acc: 0.9001 - Val Loss: 0.4992 - Val Acc: 0.8250
# [Baseline] Epoch 18/50 - Train Loss: 0.2608 - Train Acc: 0.9026 - Val Loss: 0.4693 - Val Acc: 0.8405
# [Baseline] Epoch 19/50 - Train Loss: 0.2496 - Train Acc: 0.9077 - Val Loss: 0.4181 - Val Acc: 0.8610
# [Baseline] Epoch 20/50 - Train Loss: 0.2551 - Train Acc: 0.9048 - Val Loss: 0.4792 - Val Acc: 0.8459
# [Baseline] Epoch 21/50 - Train Loss: 0.2458 - Train Acc: 0.9075 - Val Loss: 0.4405 - Val Acc: 0.8595
# [Baseline] Epoch 22/50 - Train Loss: 0.2414 - Train Acc: 0.9099 - Val Loss: 0.3602 - Val Acc: 0.8778
# [Baseline] Epoch 23/50 - Train Loss: 0.2453 - Train Acc: 0.9080 - Val Loss: 0.4425 - Val Acc: 0.8622
# [Baseline] Epoch 24/50 - Train Loss: 0.2422 - Train Acc: 0.9086 - Val Loss: 0.4021 - Val Acc: 0.8648
# [Baseline] Epoch 25/50 - Train Loss: 0.2417 - Train Acc: 0.9082 - Val Loss: 0.4351 - Val Acc: 0.8645
# [Baseline] Epoch 26/50 - Train Loss: 0.2343 - Train Acc: 0.9124 - Val Loss: 0.3731 - Val Acc: 0.8683
# [Baseline] Epoch 27/50 - Train Loss: 0.2371 - Train Acc: 0.9104 - Val Loss: 0.3661 - Val Acc: 0.8656
# [Baseline] Epoch 28/50 - Train Loss: 0.2298 - Train Acc: 0.9153 - Val Loss: 0.4862 - Val Acc: 0.8386
# [Baseline] Epoch 29/50 - Train Loss: 0.2332 - Train Acc: 0.9125 - Val Loss: 0.4272 - Val Acc: 0.8614
# [Baseline] Epoch 30/50 - Train Loss: 0.2218 - Train Acc: 0.9175 - Val Loss: 0.4002 - Val Acc: 0.8709
# [Baseline] Epoch 31/50 - Train Loss: 0.2235 - Train Acc: 0.9167 - Val Loss: 0.4392 - Val Acc: 0.8569
# [Baseline] Epoch 32/50 - Train Loss: 0.2222 - Train Acc: 0.9160 - Val Loss: 0.4141 - Val Acc: 0.8622
# [Baseline] Epoch 33/50 - Train Loss: 0.2182 - Train Acc: 0.9180 - Val Loss: 0.3882 - Val Acc: 0.8785
# [Baseline] Epoch 34/50 - Train Loss: 0.2197 - Train Acc: 0.9181 - Val Loss: 0.3970 - Val Acc: 0.8755
# [Baseline] Epoch 35/50 - Train Loss: 0.2207 - Train Acc: 0.9185 - Val Loss: 0.3551 - Val Acc: 0.8865
# [Baseline] Epoch 36/50 - Train Loss: 0.2134 - Train Acc: 0.9193 - Val Loss: 0.4120 - Val Acc: 0.8728
# [Baseline] Epoch 37/50 - Train Loss: 0.2155 - Train Acc: 0.9194 - Val Loss: 0.4541 - Val Acc: 0.8664
# [Baseline] Epoch 38/50 - Train Loss: 0.2132 - Train Acc: 0.9196 - Val Loss: 0.3446 - Val Acc: 0.8827
# [Baseline] Epoch 39/50 - Train Loss: 0.2161 - Train Acc: 0.9189 - Val Loss: 0.3954 - Val Acc: 0.8789
# [Baseline] Epoch 40/50 - Train Loss: 0.2079 - Train Acc: 0.9210 - Val Loss: 0.4210 - Val Acc: 0.8660
# [Baseline] Epoch 41/50 - Train Loss: 0.2046 - Train Acc: 0.9238 - Val Loss: 0.4307 - Val Acc: 0.8626
# [Baseline] Epoch 42/50 - Train Loss: 0.2064 - Train Acc: 0.9220 - Val Loss: 0.4624 - Val Acc: 0.8535
# [Baseline] Epoch 43/50 - Train Loss: 0.2020 - Train Acc: 0.9241 - Val Loss: 0.4072 - Val Acc: 0.8762
# [Baseline] Epoch 44/50 - Train Loss: 0.2002 - Train Acc: 0.9256 - Val Loss: 0.3772 - Val Acc: 0.8732
# [Baseline] Epoch 45/50 - Train Loss: 0.2094 - Train Acc: 0.9217 - Val Loss: 0.3835 - Val Acc: 0.8793
# [Baseline] Epoch 46/50 - Train Loss: 0.2031 - Train Acc: 0.9234 - Val Loss: 0.3886 - Val Acc: 0.8785
# [Baseline] Epoch 47/50 - Train Loss: 0.2032 - Train Acc: 0.9240 - Val Loss: 0.4400 - Val Acc: 0.8542
# [Baseline] Epoch 48/50 - Train Loss: 0.2037 - Train Acc: 0.9232 - Val Loss: 0.3980 - Val Acc: 0.8812
# [Baseline] Epoch 49/50 - Train Loss: 0.1986 - Train Acc: 0.9260 - Val Loss: 0.4280 - Val Acc: 0.8573
# [Baseline] Epoch 50/50 - Train Loss: 0.1967 - Train Acc: 0.9261 - Val Loss: 0.3747 - Val Acc: 0.8789
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td30_Tw15.pth
#
# 🚀 Training Standalone Student for Td=30, Tw=20 (T_len=11)
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# [Baseline] Epoch 01/50 - Train Loss: 0.7920 - Train Acc: 0.7140 - Val Loss: 0.7552 - Val Acc: 0.7187
# [Baseline] Epoch 02/50 - Train Loss: 0.5128 - Train Acc: 0.8090 - Val Loss: 0.6543 - Val Acc: 0.7560
# [Baseline] Epoch 03/50 - Train Loss: 0.4422 - Train Acc: 0.8343 - Val Loss: 0.6438 - Val Acc: 0.7652
# [Baseline] Epoch 04/50 - Train Loss: 0.3965 - Train Acc: 0.8527 - Val Loss: 0.5360 - Val Acc: 0.8256
# [Baseline] Epoch 05/50 - Train Loss: 0.3804 - Train Acc: 0.8570 - Val Loss: 0.5737 - Val Acc: 0.7895
# [Baseline] Epoch 06/50 - Train Loss: 0.3525 - Train Acc: 0.8659 - Val Loss: 0.5357 - Val Acc: 0.8117
# [Baseline] Epoch 07/50 - Train Loss: 0.3362 - Train Acc: 0.8730 - Val Loss: 0.5005 - Val Acc: 0.8361
# [Baseline] Epoch 08/50 - Train Loss: 0.3231 - Train Acc: 0.8775 - Val Loss: 0.4610 - Val Acc: 0.8375
# [Baseline] Epoch 09/50 - Train Loss: 0.3158 - Train Acc: 0.8820 - Val Loss: 0.4963 - Val Acc: 0.8442
# [Baseline] Epoch 10/50 - Train Loss: 0.3032 - Train Acc: 0.8852 - Val Loss: 0.4595 - Val Acc: 0.8620
# [Baseline] Epoch 11/50 - Train Loss: 0.2970 - Train Acc: 0.8869 - Val Loss: 0.4428 - Val Acc: 0.8461
# [Baseline] Epoch 12/50 - Train Loss: 0.2977 - Train Acc: 0.8884 - Val Loss: 0.4684 - Val Acc: 0.8365
# [Baseline] Epoch 13/50 - Train Loss: 0.2845 - Train Acc: 0.8922 - Val Loss: 0.4954 - Val Acc: 0.8514
# [Baseline] Epoch 14/50 - Train Loss: 0.2698 - Train Acc: 0.8976 - Val Loss: 0.4333 - Val Acc: 0.8671
# [Baseline] Epoch 15/50 - Train Loss: 0.2734 - Train Acc: 0.8969 - Val Loss: 0.5056 - Val Acc: 0.8296
# [Baseline] Epoch 16/50 - Train Loss: 0.2716 - Train Acc: 0.8971 - Val Loss: 0.4096 - Val Acc: 0.8721
# [Baseline] Epoch 17/50 - Train Loss: 0.2616 - Train Acc: 0.9008 - Val Loss: 0.4546 - Val Acc: 0.8614
# [Baseline] Epoch 18/50 - Train Loss: 0.2584 - Train Acc: 0.9031 - Val Loss: 0.4121 - Val Acc: 0.8679
# [Baseline] Epoch 19/50 - Train Loss: 0.2584 - Train Acc: 0.9030 - Val Loss: 0.4303 - Val Acc: 0.8635
# [Baseline] Epoch 20/50 - Train Loss: 0.2491 - Train Acc: 0.9061 - Val Loss: 0.4854 - Val Acc: 0.8453
# [Baseline] Epoch 21/50 - Train Loss: 0.2498 - Train Acc: 0.9055 - Val Loss: 0.4477 - Val Acc: 0.8652
# [Baseline] Epoch 22/50 - Train Loss: 0.2491 - Train Acc: 0.9071 - Val Loss: 0.4484 - Val Acc: 0.8690
# [Baseline] Epoch 23/50 - Train Loss: 0.2393 - Train Acc: 0.9088 - Val Loss: 0.4734 - Val Acc: 0.8514
# [Baseline] Epoch 24/50 - Train Loss: 0.2418 - Train Acc: 0.9080 - Val Loss: 0.4225 - Val Acc: 0.8685
# [Baseline] Epoch 25/50 - Train Loss: 0.2381 - Train Acc: 0.9086 - Val Loss: 0.4603 - Val Acc: 0.8604
# [Baseline] Epoch 26/50 - Train Loss: 0.2324 - Train Acc: 0.9118 - Val Loss: 0.5498 - Val Acc: 0.8438
# [Baseline] Epoch 27/50 - Train Loss: 0.2293 - Train Acc: 0.9129 - Val Loss: 0.4500 - Val Acc: 0.8627
# [Baseline] Epoch 28/50 - Train Loss: 0.2346 - Train Acc: 0.9110 - Val Loss: 0.4729 - Val Acc: 0.8646
# [Baseline] Epoch 29/50 - Train Loss: 0.2303 - Train Acc: 0.9123 - Val Loss: 0.4454 - Val Acc: 0.8685
# [Baseline] Epoch 30/50 - Train Loss: 0.2250 - Train Acc: 0.9145 - Val Loss: 0.3981 - Val Acc: 0.8755
# [Baseline] Epoch 31/50 - Train Loss: 0.2240 - Train Acc: 0.9141 - Val Loss: 0.4390 - Val Acc: 0.8717
# [Baseline] Epoch 32/50 - Train Loss: 0.2237 - Train Acc: 0.9162 - Val Loss: 0.4483 - Val Acc: 0.8727
# [Baseline] Epoch 33/50 - Train Loss: 0.2204 - Train Acc: 0.9159 - Val Loss: 0.4011 - Val Acc: 0.8728
# [Baseline] Epoch 34/50 - Train Loss: 0.2229 - Train Acc: 0.9170 - Val Loss: 0.4427 - Val Acc: 0.8757
# [Baseline] Epoch 35/50 - Train Loss: 0.2187 - Train Acc: 0.9177 - Val Loss: 0.4645 - Val Acc: 0.8694
# [Baseline] Epoch 36/50 - Train Loss: 0.2162 - Train Acc: 0.9174 - Val Loss: 0.4303 - Val Acc: 0.8702
# [Baseline] Epoch 37/50 - Train Loss: 0.2108 - Train Acc: 0.9194 - Val Loss: 0.4890 - Val Acc: 0.8658
# [Baseline] Epoch 38/50 - Train Loss: 0.2171 - Train Acc: 0.9173 - Val Loss: 0.4371 - Val Acc: 0.8753
# [Baseline] Epoch 39/50 - Train Loss: 0.2111 - Train Acc: 0.9197 - Val Loss: 0.4326 - Val Acc: 0.8759
# [Baseline] Epoch 40/50 - Train Loss: 0.2125 - Train Acc: 0.9198 - Val Loss: 0.4667 - Val Acc: 0.8625
# [Baseline] Epoch 41/50 - Train Loss: 0.2118 - Train Acc: 0.9201 - Val Loss: 0.4436 - Val Acc: 0.8755
# [Baseline] Epoch 42/50 - Train Loss: 0.2080 - Train Acc: 0.9218 - Val Loss: 0.5398 - Val Acc: 0.8535
# [Baseline] Epoch 43/50 - Train Loss: 0.2091 - Train Acc: 0.9203 - Val Loss: 0.4791 - Val Acc: 0.8788
# [Baseline] Epoch 44/50 - Train Loss: 0.2068 - Train Acc: 0.9212 - Val Loss: 0.4411 - Val Acc: 0.8706
# [Baseline] Epoch 45/50 - Train Loss: 0.2075 - Train Acc: 0.9220 - Val Loss: 0.4198 - Val Acc: 0.8860
# [Baseline] Epoch 46/50 - Train Loss: 0.2015 - Train Acc: 0.9235 - Val Loss: 0.4178 - Val Acc: 0.8843
# [Baseline] Epoch 47/50 - Train Loss: 0.2060 - Train Acc: 0.9216 - Val Loss: 0.4631 - Val Acc: 0.8736
# [Baseline] Epoch 48/50 - Train Loss: 0.2033 - Train Acc: 0.9228 - Val Loss: 0.4808 - Val Acc: 0.8688
# [Baseline] Epoch 49/50 - Train Loss: 0.2031 - Train Acc: 0.9225 - Val Loss: 0.4499 - Val Acc: 0.8746
# [Baseline] Epoch 50/50 - Train Loss: 0.1999 - Train Acc: 0.9237 - Val Loss: 0.4957 - Val Acc: 0.8608
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td30_Tw20.pth
#
# 🚀 Training Standalone Student for Td=45, Tw=10 (T_len=36)
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# [Baseline] Epoch 01/50 - Train Loss: 1.0171 - Train Acc: 0.6216 - Val Loss: 0.9154 - Val Acc: 0.6095
# [Baseline] Epoch 02/50 - Train Loss: 0.4212 - Train Acc: 0.8436 - Val Loss: 0.5490 - Val Acc: 0.7868
# [Baseline] Epoch 03/50 - Train Loss: 0.3494 - Train Acc: 0.8731 - Val Loss: 0.6565 - Val Acc: 0.7384
# [Baseline] Epoch 04/50 - Train Loss: 0.3075 - Train Acc: 0.8869 - Val Loss: 0.4536 - Val Acc: 0.8353
# [Baseline] Epoch 05/50 - Train Loss: 0.2619 - Train Acc: 0.9040 - Val Loss: 0.3998 - Val Acc: 0.8537
# [Baseline] Epoch 06/50 - Train Loss: 0.2450 - Train Acc: 0.9127 - Val Loss: 0.4527 - Val Acc: 0.8343
# [Baseline] Epoch 07/50 - Train Loss: 0.2201 - Train Acc: 0.9184 - Val Loss: 0.3220 - Val Acc: 0.8828
# [Baseline] Epoch 08/50 - Train Loss: 0.2152 - Train Acc: 0.9205 - Val Loss: 0.3662 - Val Acc: 0.8576
# [Baseline] Epoch 09/50 - Train Loss: 0.2223 - Train Acc: 0.9185 - Val Loss: 0.3096 - Val Acc: 0.8915
# [Baseline] Epoch 10/50 - Train Loss: 0.1920 - Train Acc: 0.9285 - Val Loss: 0.5010 - Val Acc: 0.8314
# [Baseline] Epoch 11/50 - Train Loss: 0.1947 - Train Acc: 0.9290 - Val Loss: 0.3122 - Val Acc: 0.8915
# [Baseline] Epoch 12/50 - Train Loss: 0.1696 - Train Acc: 0.9375 - Val Loss: 0.3570 - Val Acc: 0.8837
# [Baseline] Epoch 13/50 - Train Loss: 0.1725 - Train Acc: 0.9398 - Val Loss: 0.4369 - Val Acc: 0.8411
# [Baseline] Epoch 14/50 - Train Loss: 0.1826 - Train Acc: 0.9392 - Val Loss: 0.3465 - Val Acc: 0.8876
# [Baseline] Epoch 15/50 - Train Loss: 0.1888 - Train Acc: 0.9314 - Val Loss: 0.3189 - Val Acc: 0.8983
# [Baseline] Epoch 16/50 - Train Loss: 0.1589 - Train Acc: 0.9427 - Val Loss: 0.3218 - Val Acc: 0.8934
# [Baseline] Epoch 17/50 - Train Loss: 0.1595 - Train Acc: 0.9427 - Val Loss: 0.3515 - Val Acc: 0.8750
# [Baseline] Epoch 18/50 - Train Loss: 0.1750 - Train Acc: 0.9371 - Val Loss: 0.2988 - Val Acc: 0.8905
# [Baseline] Epoch 19/50 - Train Loss: 0.1467 - Train Acc: 0.9466 - Val Loss: 0.2723 - Val Acc: 0.8963
# [Baseline] Epoch 20/50 - Train Loss: 0.1477 - Train Acc: 0.9475 - Val Loss: 0.3041 - Val Acc: 0.9089
# [Baseline] Epoch 21/50 - Train Loss: 0.1548 - Train Acc: 0.9424 - Val Loss: 0.3119 - Val Acc: 0.9109
# [Baseline] Epoch 22/50 - Train Loss: 0.1274 - Train Acc: 0.9533 - Val Loss: 0.3007 - Val Acc: 0.9002
# [Baseline] Epoch 23/50 - Train Loss: 0.1267 - Train Acc: 0.9538 - Val Loss: 0.3499 - Val Acc: 0.8953
# [Baseline] Epoch 24/50 - Train Loss: 0.1312 - Train Acc: 0.9528 - Val Loss: 0.2584 - Val Acc: 0.9012
# [Baseline] Epoch 25/50 - Train Loss: 0.1412 - Train Acc: 0.9500 - Val Loss: 0.3650 - Val Acc: 0.8769
# [Baseline] Epoch 26/50 - Train Loss: 0.1928 - Train Acc: 0.9319 - Val Loss: 0.3144 - Val Acc: 0.8808
# [Baseline] Epoch 27/50 - Train Loss: 0.1277 - Train Acc: 0.9551 - Val Loss: 0.3287 - Val Acc: 0.8983
# [Baseline] Epoch 28/50 - Train Loss: 0.1410 - Train Acc: 0.9487 - Val Loss: 0.3534 - Val Acc: 0.9070
# [Baseline] Epoch 29/50 - Train Loss: 0.1277 - Train Acc: 0.9541 - Val Loss: 0.2977 - Val Acc: 0.9070
# [Baseline] Epoch 30/50 - Train Loss: 0.1276 - Train Acc: 0.9542 - Val Loss: 0.3011 - Val Acc: 0.9060
# [Baseline] Epoch 31/50 - Train Loss: 0.1185 - Train Acc: 0.9569 - Val Loss: 0.3789 - Val Acc: 0.8934
# [Baseline] Epoch 32/50 - Train Loss: 0.1253 - Train Acc: 0.9557 - Val Loss: 0.3027 - Val Acc: 0.9060
# [Baseline] Epoch 33/50 - Train Loss: 0.1215 - Train Acc: 0.9575 - Val Loss: 0.2370 - Val Acc: 0.9283
# [Baseline] Epoch 34/50 - Train Loss: 0.1121 - Train Acc: 0.9592 - Val Loss: 0.3146 - Val Acc: 0.8953
# [Baseline] Epoch 35/50 - Train Loss: 0.1334 - Train Acc: 0.9533 - Val Loss: 0.2994 - Val Acc: 0.9196
# [Baseline] Epoch 36/50 - Train Loss: 0.1229 - Train Acc: 0.9568 - Val Loss: 0.2569 - Val Acc: 0.9234
# [Baseline] Epoch 37/50 - Train Loss: 0.1288 - Train Acc: 0.9554 - Val Loss: 0.2896 - Val Acc: 0.9118
# [Baseline] Epoch 38/50 - Train Loss: 0.1137 - Train Acc: 0.9572 - Val Loss: 0.3093 - Val Acc: 0.9002
# [Baseline] Epoch 39/50 - Train Loss: 0.0997 - Train Acc: 0.9652 - Val Loss: 0.2932 - Val Acc: 0.9089
# [Baseline] Epoch 40/50 - Train Loss: 0.1109 - Train Acc: 0.9606 - Val Loss: 0.3211 - Val Acc: 0.9021
# [Baseline] Epoch 41/50 - Train Loss: 0.0962 - Train Acc: 0.9656 - Val Loss: 0.2754 - Val Acc: 0.9128
# [Baseline] Epoch 42/50 - Train Loss: 0.1096 - Train Acc: 0.9620 - Val Loss: 0.3066 - Val Acc: 0.9041
# [Baseline] Epoch 43/50 - Train Loss: 0.1181 - Train Acc: 0.9567 - Val Loss: 0.2549 - Val Acc: 0.9147
# [Baseline] Epoch 44/50 - Train Loss: 0.1008 - Train Acc: 0.9621 - Val Loss: 0.2863 - Val Acc: 0.9089
# [Baseline] Epoch 45/50 - Train Loss: 0.1024 - Train Acc: 0.9635 - Val Loss: 0.3047 - Val Acc: 0.9060
# [Baseline] Epoch 46/50 - Train Loss: 0.0967 - Train Acc: 0.9640 - Val Loss: 0.2589 - Val Acc: 0.9196
# [Baseline] Epoch 47/50 - Train Loss: 0.0953 - Train Acc: 0.9659 - Val Loss: 0.2788 - Val Acc: 0.9176
# [Baseline] Epoch 48/50 - Train Loss: 0.0975 - Train Acc: 0.9655 - Val Loss: 0.3500 - Val Acc: 0.9012
# [Baseline] Epoch 49/50 - Train Loss: 0.0990 - Train Acc: 0.9638 - Val Loss: 0.2973 - Val Acc: 0.9099
# [Baseline] Epoch 50/50 - Train Loss: 0.1007 - Train Acc: 0.9670 - Val Loss: 0.3224 - Val Acc: 0.9089
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td45_Tw10.pth
#
# 🚀 Training Standalone Student for Td=45, Tw=15 (T_len=31)
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# [Baseline] Epoch 01/50 - Train Loss: 0.9135 - Train Acc: 0.6722 - Val Loss: 0.8558 - Val Acc: 0.6896
# [Baseline] Epoch 02/50 - Train Loss: 0.4157 - Train Acc: 0.8490 - Val Loss: 0.5372 - Val Acc: 0.7999
# [Baseline] Epoch 03/50 - Train Loss: 0.3216 - Train Acc: 0.8839 - Val Loss: 0.5066 - Val Acc: 0.8064
# [Baseline] Epoch 04/50 - Train Loss: 0.2840 - Train Acc: 0.9003 - Val Loss: 0.4866 - Val Acc: 0.8159
# [Baseline] Epoch 05/50 - Train Loss: 0.2425 - Train Acc: 0.9107 - Val Loss: 0.4374 - Val Acc: 0.8459
# [Baseline] Epoch 06/50 - Train Loss: 0.2288 - Train Acc: 0.9161 - Val Loss: 0.3724 - Val Acc: 0.8817
# [Baseline] Epoch 07/50 - Train Loss: 0.2201 - Train Acc: 0.9184 - Val Loss: 0.4089 - Val Acc: 0.8473
# [Baseline] Epoch 08/50 - Train Loss: 0.2110 - Train Acc: 0.9210 - Val Loss: 0.3278 - Val Acc: 0.8817
# [Baseline] Epoch 09/50 - Train Loss: 0.1954 - Train Acc: 0.9280 - Val Loss: 0.3918 - Val Acc: 0.8671
# [Baseline] Epoch 10/50 - Train Loss: 0.1810 - Train Acc: 0.9321 - Val Loss: 0.3492 - Val Acc: 0.8663
# [Baseline] Epoch 11/50 - Train Loss: 0.1651 - Train Acc: 0.9391 - Val Loss: 0.2959 - Val Acc: 0.8955
# [Baseline] Epoch 12/50 - Train Loss: 0.1638 - Train Acc: 0.9408 - Val Loss: 0.3002 - Val Acc: 0.8934
# [Baseline] Epoch 13/50 - Train Loss: 0.1515 - Train Acc: 0.9457 - Val Loss: 0.3157 - Val Acc: 0.8890
# [Baseline] Epoch 14/50 - Train Loss: 0.1542 - Train Acc: 0.9450 - Val Loss: 0.3617 - Val Acc: 0.8787
# [Baseline] Epoch 15/50 - Train Loss: 0.1521 - Train Acc: 0.9441 - Val Loss: 0.3144 - Val Acc: 0.8904
# [Baseline] Epoch 16/50 - Train Loss: 0.1386 - Train Acc: 0.9498 - Val Loss: 0.2684 - Val Acc: 0.9160
# [Baseline] Epoch 17/50 - Train Loss: 0.1268 - Train Acc: 0.9528 - Val Loss: 0.2972 - Val Acc: 0.9058
# [Baseline] Epoch 18/50 - Train Loss: 0.1392 - Train Acc: 0.9488 - Val Loss: 0.2990 - Val Acc: 0.8955
# [Baseline] Epoch 19/50 - Train Loss: 0.1278 - Train Acc: 0.9523 - Val Loss: 0.2983 - Val Acc: 0.8999
# [Baseline] Epoch 20/50 - Train Loss: 0.1299 - Train Acc: 0.9512 - Val Loss: 0.3278 - Val Acc: 0.8970
# [Baseline] Epoch 21/50 - Train Loss: 0.1280 - Train Acc: 0.9526 - Val Loss: 0.2698 - Val Acc: 0.9138
# [Baseline] Epoch 22/50 - Train Loss: 0.1225 - Train Acc: 0.9550 - Val Loss: 0.2930 - Val Acc: 0.9065
# [Baseline] Epoch 23/50 - Train Loss: 0.1199 - Train Acc: 0.9544 - Val Loss: 0.3543 - Val Acc: 0.9028
# [Baseline] Epoch 24/50 - Train Loss: 0.1143 - Train Acc: 0.9595 - Val Loss: 0.4135 - Val Acc: 0.8948
# [Baseline] Epoch 25/50 - Train Loss: 0.1183 - Train Acc: 0.9574 - Val Loss: 0.2794 - Val Acc: 0.9138
# [Baseline] Epoch 26/50 - Train Loss: 0.1066 - Train Acc: 0.9617 - Val Loss: 0.2728 - Val Acc: 0.9043
# [Baseline] Epoch 27/50 - Train Loss: 0.1262 - Train Acc: 0.9541 - Val Loss: 0.3141 - Val Acc: 0.9065
# [Baseline] Epoch 28/50 - Train Loss: 0.1012 - Train Acc: 0.9629 - Val Loss: 0.3132 - Val Acc: 0.9182
# [Baseline] Epoch 29/50 - Train Loss: 0.1099 - Train Acc: 0.9597 - Val Loss: 0.3330 - Val Acc: 0.9043
# [Baseline] Epoch 30/50 - Train Loss: 0.0997 - Train Acc: 0.9648 - Val Loss: 0.3023 - Val Acc: 0.9196
# [Baseline] Epoch 31/50 - Train Loss: 0.1064 - Train Acc: 0.9599 - Val Loss: 0.2987 - Val Acc: 0.9050
# [Baseline] Epoch 32/50 - Train Loss: 0.1109 - Train Acc: 0.9605 - Val Loss: 0.3006 - Val Acc: 0.9211
# [Baseline] Epoch 33/50 - Train Loss: 0.0995 - Train Acc: 0.9632 - Val Loss: 0.2804 - Val Acc: 0.9204
# [Baseline] Epoch 34/50 - Train Loss: 0.1019 - Train Acc: 0.9627 - Val Loss: 0.2871 - Val Acc: 0.9167
# [Baseline] Epoch 35/50 - Train Loss: 0.0972 - Train Acc: 0.9651 - Val Loss: 0.3037 - Val Acc: 0.9094
# [Baseline] Epoch 36/50 - Train Loss: 0.1009 - Train Acc: 0.9608 - Val Loss: 0.3337 - Val Acc: 0.9087
# [Baseline] Epoch 37/50 - Train Loss: 0.0930 - Train Acc: 0.9656 - Val Loss: 0.2609 - Val Acc: 0.9262
# [Baseline] Epoch 38/50 - Train Loss: 0.0896 - Train Acc: 0.9660 - Val Loss: 0.2550 - Val Acc: 0.9211
# [Baseline] Epoch 39/50 - Train Loss: 0.0943 - Train Acc: 0.9646 - Val Loss: 0.3551 - Val Acc: 0.9087
# [Baseline] Epoch 40/50 - Train Loss: 0.0880 - Train Acc: 0.9693 - Val Loss: 0.2434 - Val Acc: 0.9226
# [Baseline] Epoch 41/50 - Train Loss: 0.0876 - Train Acc: 0.9674 - Val Loss: 0.3130 - Val Acc: 0.9233
# [Baseline] Epoch 42/50 - Train Loss: 0.0811 - Train Acc: 0.9709 - Val Loss: 0.2827 - Val Acc: 0.9313
# [Baseline] Epoch 43/50 - Train Loss: 0.0953 - Train Acc: 0.9667 - Val Loss: 0.2885 - Val Acc: 0.9240
# [Baseline] Epoch 44/50 - Train Loss: 0.0797 - Train Acc: 0.9709 - Val Loss: 0.2644 - Val Acc: 0.9226
# [Baseline] Epoch 45/50 - Train Loss: 0.0954 - Train Acc: 0.9660 - Val Loss: 0.2627 - Val Acc: 0.9218
# [Baseline] Epoch 46/50 - Train Loss: 0.0795 - Train Acc: 0.9703 - Val Loss: 0.3167 - Val Acc: 0.9248
# [Baseline] Epoch 47/50 - Train Loss: 0.0922 - Train Acc: 0.9666 - Val Loss: 0.2874 - Val Acc: 0.9248
# [Baseline] Epoch 48/50 - Train Loss: 0.0850 - Train Acc: 0.9702 - Val Loss: 0.2538 - Val Acc: 0.9211
# [Baseline] Epoch 49/50 - Train Loss: 0.0806 - Train Acc: 0.9718 - Val Loss: 0.2557 - Val Acc: 0.9240
# [Baseline] Epoch 50/50 - Train Loss: 0.0795 - Train Acc: 0.9717 - Val Loss: 0.2600 - Val Acc: 0.9335
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td45_Tw15.pth
#
# 🚀 Training Standalone Student for Td=45, Tw=20 (T_len=26)
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# [Baseline] Epoch 01/50 - Train Loss: 0.8696 - Train Acc: 0.6882 - Val Loss: 0.7179 - Val Acc: 0.7293
# [Baseline] Epoch 02/50 - Train Loss: 0.4265 - Train Acc: 0.8439 - Val Loss: 0.5289 - Val Acc: 0.7722
# [Baseline] Epoch 03/50 - Train Loss: 0.3461 - Train Acc: 0.8726 - Val Loss: 0.5362 - Val Acc: 0.7880
# [Baseline] Epoch 04/50 - Train Loss: 0.3134 - Train Acc: 0.8843 - Val Loss: 0.5212 - Val Acc: 0.7975
# [Baseline] Epoch 05/50 - Train Loss: 0.2750 - Train Acc: 0.8983 - Val Loss: 0.4950 - Val Acc: 0.7968
# [Baseline] Epoch 06/50 - Train Loss: 0.2665 - Train Acc: 0.9040 - Val Loss: 0.5683 - Val Acc: 0.7899
# [Baseline] Epoch 07/50 - Train Loss: 0.2507 - Train Acc: 0.9071 - Val Loss: 0.3870 - Val Acc: 0.8593
# [Baseline] Epoch 08/50 - Train Loss: 0.2361 - Train Acc: 0.9114 - Val Loss: 0.3878 - Val Acc: 0.8524
# [Baseline] Epoch 09/50 - Train Loss: 0.2161 - Train Acc: 0.9209 - Val Loss: 0.4017 - Val Acc: 0.8580
# [Baseline] Epoch 10/50 - Train Loss: 0.2119 - Train Acc: 0.9249 - Val Loss: 0.4123 - Val Acc: 0.8681
# [Baseline] Epoch 11/50 - Train Loss: 0.2118 - Train Acc: 0.9213 - Val Loss: 0.3928 - Val Acc: 0.8688
# [Baseline] Epoch 12/50 - Train Loss: 0.1988 - Train Acc: 0.9246 - Val Loss: 0.3579 - Val Acc: 0.8795
# [Baseline] Epoch 13/50 - Train Loss: 0.2036 - Train Acc: 0.9257 - Val Loss: 0.3623 - Val Acc: 0.8864
# [Baseline] Epoch 14/50 - Train Loss: 0.1905 - Train Acc: 0.9290 - Val Loss: 0.3578 - Val Acc: 0.8637
# [Baseline] Epoch 15/50 - Train Loss: 0.1925 - Train Acc: 0.9281 - Val Loss: 0.3350 - Val Acc: 0.8877
# [Baseline] Epoch 16/50 - Train Loss: 0.1718 - Train Acc: 0.9352 - Val Loss: 0.3661 - Val Acc: 0.8826
# [Baseline] Epoch 17/50 - Train Loss: 0.1679 - Train Acc: 0.9367 - Val Loss: 0.2990 - Val Acc: 0.8896
# [Baseline] Epoch 18/50 - Train Loss: 0.1739 - Train Acc: 0.9363 - Val Loss: 0.3350 - Val Acc: 0.8953
# [Baseline] Epoch 19/50 - Train Loss: 0.1713 - Train Acc: 0.9366 - Val Loss: 0.3652 - Val Acc: 0.8852
# [Baseline] Epoch 20/50 - Train Loss: 0.1665 - Train Acc: 0.9395 - Val Loss: 0.3560 - Val Acc: 0.8763
# [Baseline] Epoch 21/50 - Train Loss: 0.1513 - Train Acc: 0.9440 - Val Loss: 0.3999 - Val Acc: 0.8713
# [Baseline] Epoch 22/50 - Train Loss: 0.1490 - Train Acc: 0.9438 - Val Loss: 0.3335 - Val Acc: 0.8852
# [Baseline] Epoch 23/50 - Train Loss: 0.1466 - Train Acc: 0.9464 - Val Loss: 0.4599 - Val Acc: 0.8517
# [Baseline] Epoch 24/50 - Train Loss: 0.1489 - Train Acc: 0.9452 - Val Loss: 0.3340 - Val Acc: 0.8965
# [Baseline] Epoch 25/50 - Train Loss: 0.1446 - Train Acc: 0.9464 - Val Loss: 0.3597 - Val Acc: 0.8883
# [Baseline] Epoch 26/50 - Train Loss: 0.1429 - Train Acc: 0.9486 - Val Loss: 0.3667 - Val Acc: 0.8909
# [Baseline] Epoch 27/50 - Train Loss: 0.1351 - Train Acc: 0.9498 - Val Loss: 0.3104 - Val Acc: 0.8978
# [Baseline] Epoch 28/50 - Train Loss: 0.1460 - Train Acc: 0.9448 - Val Loss: 0.3091 - Val Acc: 0.9054
# [Baseline] Epoch 29/50 - Train Loss: 0.1400 - Train Acc: 0.9492 - Val Loss: 0.3179 - Val Acc: 0.8997
# [Baseline] Epoch 30/50 - Train Loss: 0.1233 - Train Acc: 0.9548 - Val Loss: 0.3287 - Val Acc: 0.9060
# [Baseline] Epoch 31/50 - Train Loss: 0.1265 - Train Acc: 0.9521 - Val Loss: 0.3350 - Val Acc: 0.9073
# [Baseline] Epoch 32/50 - Train Loss: 0.1262 - Train Acc: 0.9548 - Val Loss: 0.3129 - Val Acc: 0.9073
# [Baseline] Epoch 33/50 - Train Loss: 0.1203 - Train Acc: 0.9559 - Val Loss: 0.3312 - Val Acc: 0.8997
# [Baseline] Epoch 34/50 - Train Loss: 0.1210 - Train Acc: 0.9581 - Val Loss: 0.3180 - Val Acc: 0.9085
# [Baseline] Epoch 35/50 - Train Loss: 0.1302 - Train Acc: 0.9536 - Val Loss: 0.4282 - Val Acc: 0.8934
# [Baseline] Epoch 36/50 - Train Loss: 0.1199 - Train Acc: 0.9567 - Val Loss: 0.3535 - Val Acc: 0.9035
# [Baseline] Epoch 37/50 - Train Loss: 0.1334 - Train Acc: 0.9513 - Val Loss: 0.3604 - Val Acc: 0.9073
# [Baseline] Epoch 38/50 - Train Loss: 0.1159 - Train Acc: 0.9582 - Val Loss: 0.3100 - Val Acc: 0.9142
# [Baseline] Epoch 39/50 - Train Loss: 0.1072 - Train Acc: 0.9618 - Val Loss: 0.2968 - Val Acc: 0.9155
# [Baseline] Epoch 40/50 - Train Loss: 0.1111 - Train Acc: 0.9607 - Val Loss: 0.3337 - Val Acc: 0.9098
# [Baseline] Epoch 41/50 - Train Loss: 0.1121 - Train Acc: 0.9581 - Val Loss: 0.3397 - Val Acc: 0.9085
# [Baseline] Epoch 42/50 - Train Loss: 0.1118 - Train Acc: 0.9584 - Val Loss: 0.2989 - Val Acc: 0.9249
# [Baseline] Epoch 43/50 - Train Loss: 0.1119 - Train Acc: 0.9587 - Val Loss: 0.3900 - Val Acc: 0.9054
# [Baseline] Epoch 44/50 - Train Loss: 0.0994 - Train Acc: 0.9636 - Val Loss: 0.3211 - Val Acc: 0.9148
# [Baseline] Epoch 45/50 - Train Loss: 0.1057 - Train Acc: 0.9611 - Val Loss: 0.4046 - Val Acc: 0.9009
# [Baseline] Epoch 46/50 - Train Loss: 0.1067 - Train Acc: 0.9602 - Val Loss: 0.2881 - Val Acc: 0.9073
# [Baseline] Epoch 47/50 - Train Loss: 0.1033 - Train Acc: 0.9611 - Val Loss: 0.3564 - Val Acc: 0.9041
# [Baseline] Epoch 48/50 - Train Loss: 0.0989 - Train Acc: 0.9642 - Val Loss: 0.3580 - Val Acc: 0.9009
# [Baseline] Epoch 49/50 - Train Loss: 0.1080 - Train Acc: 0.9617 - Val Loss: 0.3461 - Val Acc: 0.8953
# [Baseline] Epoch 50/50 - Train Loss: 0.1014 - Train Acc: 0.9622 - Val Loss: 0.3112 - Val Acc: 0.9148
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td45_Tw20.pth
#
# 🚀 Training Standalone Student for Td=60, Tw=10 (T_len=51)
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# [Baseline] Epoch 01/50 - Train Loss: 1.2312 - Train Acc: 0.5594 - Val Loss: 0.8409 - Val Acc: 0.7132
# [Baseline] Epoch 02/50 - Train Loss: 0.4938 - Train Acc: 0.8239 - Val Loss: 0.4896 - Val Acc: 0.8253
# [Baseline] Epoch 03/50 - Train Loss: 0.3423 - Train Acc: 0.8797 - Val Loss: 0.4518 - Val Acc: 0.8413
# [Baseline] Epoch 04/50 - Train Loss: 0.2866 - Train Acc: 0.8948 - Val Loss: 0.4059 - Val Acc: 0.8632
# [Baseline] Epoch 05/50 - Train Loss: 0.2428 - Train Acc: 0.9122 - Val Loss: 0.3341 - Val Acc: 0.8894
# [Baseline] Epoch 06/50 - Train Loss: 0.2105 - Train Acc: 0.9221 - Val Loss: 0.4018 - Val Acc: 0.8734
# [Baseline] Epoch 07/50 - Train Loss: 0.2016 - Train Acc: 0.9267 - Val Loss: 0.5421 - Val Acc: 0.8413
# [Baseline] Epoch 08/50 - Train Loss: 0.2005 - Train Acc: 0.9277 - Val Loss: 0.2475 - Val Acc: 0.9141
# [Baseline] Epoch 09/50 - Train Loss: 0.1774 - Train Acc: 0.9353 - Val Loss: 0.2934 - Val Acc: 0.9127
# [Baseline] Epoch 10/50 - Train Loss: 0.1762 - Train Acc: 0.9359 - Val Loss: 0.2934 - Val Acc: 0.9025
# [Baseline] Epoch 11/50 - Train Loss: 0.1657 - Train Acc: 0.9403 - Val Loss: 0.3236 - Val Acc: 0.8981
# [Baseline] Epoch 12/50 - Train Loss: 0.1564 - Train Acc: 0.9427 - Val Loss: 0.2937 - Val Acc: 0.9068
# [Baseline] Epoch 13/50 - Train Loss: 0.1363 - Train Acc: 0.9487 - Val Loss: 0.3387 - Val Acc: 0.9054
# [Baseline] Epoch 14/50 - Train Loss: 0.1292 - Train Acc: 0.9553 - Val Loss: 0.2905 - Val Acc: 0.9127
# [Baseline] Epoch 15/50 - Train Loss: 0.1333 - Train Acc: 0.9517 - Val Loss: 0.2339 - Val Acc: 0.9199
# [Baseline] Epoch 16/50 - Train Loss: 0.1331 - Train Acc: 0.9545 - Val Loss: 0.2549 - Val Acc: 0.9243
# [Baseline] Epoch 17/50 - Train Loss: 0.1243 - Train Acc: 0.9559 - Val Loss: 0.2839 - Val Acc: 0.9127
# [Baseline] Epoch 18/50 - Train Loss: 0.1143 - Train Acc: 0.9573 - Val Loss: 0.3180 - Val Acc: 0.9025
# [Baseline] Epoch 19/50 - Train Loss: 0.1114 - Train Acc: 0.9566 - Val Loss: 0.2924 - Val Acc: 0.9141
# [Baseline] Epoch 20/50 - Train Loss: 0.1129 - Train Acc: 0.9601 - Val Loss: 0.3040 - Val Acc: 0.9199
# [Baseline] Epoch 21/50 - Train Loss: 0.1175 - Train Acc: 0.9566 - Val Loss: 0.2347 - Val Acc: 0.9243
# [Baseline] Epoch 22/50 - Train Loss: 0.0973 - Train Acc: 0.9641 - Val Loss: 0.2344 - Val Acc: 0.9301
# [Baseline] Epoch 23/50 - Train Loss: 0.1182 - Train Acc: 0.9578 - Val Loss: 0.2959 - Val Acc: 0.9229
# [Baseline] Epoch 24/50 - Train Loss: 0.1123 - Train Acc: 0.9584 - Val Loss: 0.2682 - Val Acc: 0.9156
# [Baseline] Epoch 25/50 - Train Loss: 0.1033 - Train Acc: 0.9615 - Val Loss: 0.2633 - Val Acc: 0.9229
# [Baseline] Epoch 26/50 - Train Loss: 0.0925 - Train Acc: 0.9684 - Val Loss: 0.2700 - Val Acc: 0.9243
# [Baseline] Epoch 27/50 - Train Loss: 0.1129 - Train Acc: 0.9592 - Val Loss: 0.2402 - Val Acc: 0.9360
# [Baseline] Epoch 28/50 - Train Loss: 0.1015 - Train Acc: 0.9598 - Val Loss: 0.3848 - Val Acc: 0.8967
# [Baseline] Epoch 29/50 - Train Loss: 0.0997 - Train Acc: 0.9637 - Val Loss: 0.2394 - Val Acc: 0.9258
# [Baseline] Epoch 30/50 - Train Loss: 0.1055 - Train Acc: 0.9627 - Val Loss: 0.2821 - Val Acc: 0.9287
# [Baseline] Epoch 31/50 - Train Loss: 0.0812 - Train Acc: 0.9729 - Val Loss: 0.2776 - Val Acc: 0.9287
# [Baseline] Epoch 32/50 - Train Loss: 0.0814 - Train Acc: 0.9716 - Val Loss: 0.2974 - Val Acc: 0.9170
# [Baseline] Epoch 33/50 - Train Loss: 0.0976 - Train Acc: 0.9668 - Val Loss: 0.2933 - Val Acc: 0.9185
# [Baseline] Epoch 34/50 - Train Loss: 0.0848 - Train Acc: 0.9694 - Val Loss: 0.2159 - Val Acc: 0.9330
# [Baseline] Epoch 35/50 - Train Loss: 0.0968 - Train Acc: 0.9648 - Val Loss: 0.4211 - Val Acc: 0.8923
# [Baseline] Epoch 36/50 - Train Loss: 0.1035 - Train Acc: 0.9633 - Val Loss: 0.2294 - Val Acc: 0.9258
# [Baseline] Epoch 37/50 - Train Loss: 0.0889 - Train Acc: 0.9680 - Val Loss: 0.2660 - Val Acc: 0.9258
# [Baseline] Epoch 38/50 - Train Loss: 0.0890 - Train Acc: 0.9672 - Val Loss: 0.2573 - Val Acc: 0.9272
# [Baseline] Epoch 39/50 - Train Loss: 0.0825 - Train Acc: 0.9681 - Val Loss: 0.3117 - Val Acc: 0.9185
# [Baseline] Epoch 40/50 - Train Loss: 0.0884 - Train Acc: 0.9686 - Val Loss: 0.3010 - Val Acc: 0.9214
# [Baseline] Epoch 41/50 - Train Loss: 0.0759 - Train Acc: 0.9715 - Val Loss: 0.2061 - Val Acc: 0.9534
# [Baseline] Epoch 42/50 - Train Loss: 0.0725 - Train Acc: 0.9748 - Val Loss: 0.2439 - Val Acc: 0.9360
# [Baseline] Epoch 43/50 - Train Loss: 0.0632 - Train Acc: 0.9759 - Val Loss: 0.2633 - Val Acc: 0.9389
# [Baseline] Epoch 44/50 - Train Loss: 0.0700 - Train Acc: 0.9762 - Val Loss: 0.2257 - Val Acc: 0.9389
# [Baseline] Epoch 45/50 - Train Loss: 0.0927 - Train Acc: 0.9658 - Val Loss: 0.2415 - Val Acc: 0.9330
# [Baseline] Epoch 46/50 - Train Loss: 0.0694 - Train Acc: 0.9737 - Val Loss: 0.2708 - Val Acc: 0.9330
# [Baseline] Epoch 47/50 - Train Loss: 0.0740 - Train Acc: 0.9730 - Val Loss: 0.3580 - Val Acc: 0.9229
# [Baseline] Epoch 48/50 - Train Loss: 0.0765 - Train Acc: 0.9748 - Val Loss: 0.2947 - Val Acc: 0.9199
# [Baseline] Epoch 49/50 - Train Loss: 0.0719 - Train Acc: 0.9744 - Val Loss: 0.2715 - Val Acc: 0.9403
# [Baseline] Epoch 50/50 - Train Loss: 0.0739 - Train Acc: 0.9715 - Val Loss: 0.2543 - Val Acc: 0.9476
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td60_Tw10.pth
#
# 🚀 Training Standalone Student for Td=60, Tw=15 (T_len=46)
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# [Baseline] Epoch 01/50 - Train Loss: 1.0054 - Train Acc: 0.6404 - Val Loss: 0.6541 - Val Acc: 0.7367
# [Baseline] Epoch 02/50 - Train Loss: 0.3769 - Train Acc: 0.8628 - Val Loss: 0.5108 - Val Acc: 0.8101
# [Baseline] Epoch 03/50 - Train Loss: 0.2773 - Train Acc: 0.8999 - Val Loss: 0.4351 - Val Acc: 0.8380
# [Baseline] Epoch 04/50 - Train Loss: 0.2434 - Train Acc: 0.9120 - Val Loss: 0.6169 - Val Acc: 0.7899
# [Baseline] Epoch 05/50 - Train Loss: 0.2334 - Train Acc: 0.9142 - Val Loss: 0.3890 - Val Acc: 0.8722
# [Baseline] Epoch 06/50 - Train Loss: 0.1891 - Train Acc: 0.9337 - Val Loss: 0.3549 - Val Acc: 0.8722
# [Baseline] Epoch 07/50 - Train Loss: 0.1742 - Train Acc: 0.9392 - Val Loss: 0.2993 - Val Acc: 0.8759
# [Baseline] Epoch 08/50 - Train Loss: 0.1810 - Train Acc: 0.9358 - Val Loss: 0.2944 - Val Acc: 0.8937
# [Baseline] Epoch 09/50 - Train Loss: 0.1434 - Train Acc: 0.9500 - Val Loss: 0.3067 - Val Acc: 0.8949
# [Baseline] Epoch 10/50 - Train Loss: 0.1664 - Train Acc: 0.9395 - Val Loss: 0.3683 - Val Acc: 0.8772
# [Baseline] Epoch 11/50 - Train Loss: 0.1744 - Train Acc: 0.9362 - Val Loss: 0.3348 - Val Acc: 0.8848
# [Baseline] Epoch 12/50 - Train Loss: 0.1426 - Train Acc: 0.9492 - Val Loss: 0.3041 - Val Acc: 0.8924
# [Baseline] Epoch 13/50 - Train Loss: 0.1235 - Train Acc: 0.9585 - Val Loss: 0.2370 - Val Acc: 0.9177
# [Baseline] Epoch 14/50 - Train Loss: 0.1188 - Train Acc: 0.9573 - Val Loss: 0.3154 - Val Acc: 0.8886
# [Baseline] Epoch 15/50 - Train Loss: 0.1235 - Train Acc: 0.9550 - Val Loss: 0.3006 - Val Acc: 0.8899
# [Baseline] Epoch 16/50 - Train Loss: 0.1123 - Train Acc: 0.9595 - Val Loss: 0.2458 - Val Acc: 0.9291
# [Baseline] Epoch 17/50 - Train Loss: 0.1213 - Train Acc: 0.9570 - Val Loss: 0.2327 - Val Acc: 0.9228
# [Baseline] Epoch 18/50 - Train Loss: 0.1070 - Train Acc: 0.9614 - Val Loss: 0.2686 - Val Acc: 0.9076
# [Baseline] Epoch 19/50 - Train Loss: 0.1028 - Train Acc: 0.9629 - Val Loss: 0.3220 - Val Acc: 0.8924
# [Baseline] Epoch 20/50 - Train Loss: 0.0966 - Train Acc: 0.9649 - Val Loss: 0.2861 - Val Acc: 0.8962
# [Baseline] Epoch 21/50 - Train Loss: 0.1037 - Train Acc: 0.9623 - Val Loss: 0.2343 - Val Acc: 0.9228
# [Baseline] Epoch 22/50 - Train Loss: 0.1034 - Train Acc: 0.9610 - Val Loss: 0.2512 - Val Acc: 0.9101
# [Baseline] Epoch 23/50 - Train Loss: 0.0957 - Train Acc: 0.9662 - Val Loss: 0.2839 - Val Acc: 0.9228
# [Baseline] Epoch 24/50 - Train Loss: 0.1020 - Train Acc: 0.9643 - Val Loss: 0.2564 - Val Acc: 0.9089
# [Baseline] Epoch 25/50 - Train Loss: 0.0803 - Train Acc: 0.9724 - Val Loss: 0.2145 - Val Acc: 0.9203
# [Baseline] Epoch 26/50 - Train Loss: 0.0978 - Train Acc: 0.9644 - Val Loss: 0.2549 - Val Acc: 0.9101
# [Baseline] Epoch 27/50 - Train Loss: 0.0833 - Train Acc: 0.9690 - Val Loss: 0.2463 - Val Acc: 0.9253
# [Baseline] Epoch 28/50 - Train Loss: 0.0916 - Train Acc: 0.9657 - Val Loss: 0.2959 - Val Acc: 0.9165
# [Baseline] Epoch 29/50 - Train Loss: 0.0714 - Train Acc: 0.9733 - Val Loss: 0.2399 - Val Acc: 0.9190
# [Baseline] Epoch 30/50 - Train Loss: 0.0760 - Train Acc: 0.9732 - Val Loss: 0.2722 - Val Acc: 0.9215
# [Baseline] Epoch 31/50 - Train Loss: 0.0863 - Train Acc: 0.9714 - Val Loss: 0.2614 - Val Acc: 0.9228
# [Baseline] Epoch 32/50 - Train Loss: 0.0666 - Train Acc: 0.9767 - Val Loss: 0.2409 - Val Acc: 0.9367
# [Baseline] Epoch 33/50 - Train Loss: 0.0868 - Train Acc: 0.9701 - Val Loss: 0.2298 - Val Acc: 0.9316
# [Baseline] Epoch 34/50 - Train Loss: 0.0756 - Train Acc: 0.9733 - Val Loss: 0.2162 - Val Acc: 0.9405
# [Baseline] Epoch 35/50 - Train Loss: 0.0695 - Train Acc: 0.9743 - Val Loss: 0.2529 - Val Acc: 0.9190
# [Baseline] Epoch 36/50 - Train Loss: 0.0723 - Train Acc: 0.9746 - Val Loss: 0.2521 - Val Acc: 0.9215
# [Baseline] Epoch 37/50 - Train Loss: 0.0633 - Train Acc: 0.9773 - Val Loss: 0.2165 - Val Acc: 0.9329
# [Baseline] Epoch 38/50 - Train Loss: 0.0754 - Train Acc: 0.9734 - Val Loss: 0.1923 - Val Acc: 0.9304
# [Baseline] Epoch 39/50 - Train Loss: 0.0806 - Train Acc: 0.9717 - Val Loss: 0.2247 - Val Acc: 0.9405
# [Baseline] Epoch 40/50 - Train Loss: 0.0601 - Train Acc: 0.9808 - Val Loss: 0.2224 - Val Acc: 0.9266
# [Baseline] Epoch 41/50 - Train Loss: 0.0539 - Train Acc: 0.9815 - Val Loss: 0.2240 - Val Acc: 0.9392
# [Baseline] Epoch 42/50 - Train Loss: 0.0610 - Train Acc: 0.9797 - Val Loss: 0.1978 - Val Acc: 0.9342
# [Baseline] Epoch 43/50 - Train Loss: 0.0559 - Train Acc: 0.9797 - Val Loss: 0.2383 - Val Acc: 0.9329
# [Baseline] Epoch 44/50 - Train Loss: 0.0643 - Train Acc: 0.9773 - Val Loss: 0.1788 - Val Acc: 0.9380
# [Baseline] Epoch 45/50 - Train Loss: 0.0660 - Train Acc: 0.9781 - Val Loss: 0.2085 - Val Acc: 0.9266
# [Baseline] Epoch 46/50 - Train Loss: 0.0682 - Train Acc: 0.9764 - Val Loss: 0.1883 - Val Acc: 0.9494
# [Baseline] Epoch 47/50 - Train Loss: 0.0527 - Train Acc: 0.9806 - Val Loss: 0.1993 - Val Acc: 0.9354
# [Baseline] Epoch 48/50 - Train Loss: 0.0560 - Train Acc: 0.9808 - Val Loss: 0.2001 - Val Acc: 0.9354
# [Baseline] Epoch 49/50 - Train Loss: 0.0614 - Train Acc: 0.9791 - Val Loss: 0.1997 - Val Acc: 0.9392
# [Baseline] Epoch 50/50 - Train Loss: 0.0473 - Train Acc: 0.9838 - Val Loss: 0.2176 - Val Acc: 0.9316
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td60_Tw15.pth
#
# 🚀 Training Standalone Student for Td=60, Tw=20 (T_len=41)
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))
# [Baseline] Epoch 01/50 - Train Loss: 0.9908 - Train Acc: 0.6389 - Val Loss: 0.8670 - Val Acc: 0.6698
# [Baseline] Epoch 02/50 - Train Loss: 0.4139 - Train Acc: 0.8452 - Val Loss: 0.6481 - Val Acc: 0.7576
# [Baseline] Epoch 03/50 - Train Loss: 0.3211 - Train Acc: 0.8775 - Val Loss: 0.5965 - Val Acc: 0.7775
# [Baseline] Epoch 04/50 - Train Loss: 0.2670 - Train Acc: 0.9006 - Val Loss: 0.4116 - Val Acc: 0.8173
# [Baseline] Epoch 05/50 - Train Loss: 0.2335 - Train Acc: 0.9128 - Val Loss: 0.4869 - Val Acc: 0.8126
# [Baseline] Epoch 06/50 - Train Loss: 0.2206 - Train Acc: 0.9158 - Val Loss: 0.3798 - Val Acc: 0.8396
# [Baseline] Epoch 07/50 - Train Loss: 0.2015 - Train Acc: 0.9258 - Val Loss: 0.4690 - Val Acc: 0.8384
# [Baseline] Epoch 08/50 - Train Loss: 0.1954 - Train Acc: 0.9284 - Val Loss: 0.3477 - Val Acc: 0.8864
# [Baseline] Epoch 09/50 - Train Loss: 0.1915 - Train Acc: 0.9306 - Val Loss: 0.4767 - Val Acc: 0.8361
# [Baseline] Epoch 10/50 - Train Loss: 0.1596 - Train Acc: 0.9411 - Val Loss: 0.3136 - Val Acc: 0.9075
# [Baseline] Epoch 11/50 - Train Loss: 0.1590 - Train Acc: 0.9423 - Val Loss: 0.3960 - Val Acc: 0.8384
# [Baseline] Epoch 12/50 - Train Loss: 0.1510 - Train Acc: 0.9465 - Val Loss: 0.3684 - Val Acc: 0.8759
# [Baseline] Epoch 13/50 - Train Loss: 0.1426 - Train Acc: 0.9472 - Val Loss: 0.4262 - Val Acc: 0.8407
# [Baseline] Epoch 14/50 - Train Loss: 0.1247 - Train Acc: 0.9559 - Val Loss: 0.3033 - Val Acc: 0.8852
# [Baseline] Epoch 15/50 - Train Loss: 0.1433 - Train Acc: 0.9488 - Val Loss: 0.2291 - Val Acc: 0.9286
# [Baseline] Epoch 16/50 - Train Loss: 0.1252 - Train Acc: 0.9542 - Val Loss: 0.2661 - Val Acc: 0.9005
# [Baseline] Epoch 17/50 - Train Loss: 0.1444 - Train Acc: 0.9472 - Val Loss: 0.3291 - Val Acc: 0.8829
# [Baseline] Epoch 18/50 - Train Loss: 0.1232 - Train Acc: 0.9546 - Val Loss: 0.4354 - Val Acc: 0.8653
# [Baseline] Epoch 19/50 - Train Loss: 0.1447 - Train Acc: 0.9459 - Val Loss: 0.3220 - Val Acc: 0.9005
# [Baseline] Epoch 20/50 - Train Loss: 0.1107 - Train Acc: 0.9608 - Val Loss: 0.3884 - Val Acc: 0.8747
# [Baseline] Epoch 21/50 - Train Loss: 0.1148 - Train Acc: 0.9598 - Val Loss: 0.3073 - Val Acc: 0.9169
# [Baseline] Epoch 22/50 - Train Loss: 0.0987 - Train Acc: 0.9639 - Val Loss: 0.3288 - Val Acc: 0.9192
# [Baseline] Epoch 23/50 - Train Loss: 0.1128 - Train Acc: 0.9592 - Val Loss: 0.2623 - Val Acc: 0.9122
# [Baseline] Epoch 24/50 - Train Loss: 0.1031 - Train Acc: 0.9623 - Val Loss: 0.2621 - Val Acc: 0.9145
# [Baseline] Epoch 25/50 - Train Loss: 0.1154 - Train Acc: 0.9570 - Val Loss: 0.2378 - Val Acc: 0.9204
# [Baseline] Epoch 26/50 - Train Loss: 0.1002 - Train Acc: 0.9660 - Val Loss: 0.2542 - Val Acc: 0.9145
# [Baseline] Epoch 27/50 - Train Loss: 0.0927 - Train Acc: 0.9665 - Val Loss: 0.2229 - Val Acc: 0.9297
# [Baseline] Epoch 28/50 - Train Loss: 0.0996 - Train Acc: 0.9629 - Val Loss: 0.3181 - Val Acc: 0.8911
# [Baseline] Epoch 29/50 - Train Loss: 0.1059 - Train Acc: 0.9633 - Val Loss: 0.2908 - Val Acc: 0.9016
# [Baseline] Epoch 30/50 - Train Loss: 0.0929 - Train Acc: 0.9662 - Val Loss: 0.2557 - Val Acc: 0.9215
# [Baseline] Epoch 31/50 - Train Loss: 0.0949 - Train Acc: 0.9656 - Val Loss: 0.2553 - Val Acc: 0.9227
# [Baseline] Epoch 32/50 - Train Loss: 0.0869 - Train Acc: 0.9694 - Val Loss: 0.2549 - Val Acc: 0.9180
# [Baseline] Epoch 33/50 - Train Loss: 0.0912 - Train Acc: 0.9647 - Val Loss: 0.3156 - Val Acc: 0.9192
# [Baseline] Epoch 34/50 - Train Loss: 0.0838 - Train Acc: 0.9709 - Val Loss: 0.2698 - Val Acc: 0.9180
# [Baseline] Epoch 35/50 - Train Loss: 0.0871 - Train Acc: 0.9686 - Val Loss: 0.2458 - Val Acc: 0.9286
# [Baseline] Epoch 36/50 - Train Loss: 0.0878 - Train Acc: 0.9681 - Val Loss: 0.2402 - Val Acc: 0.9274
# [Baseline] Epoch 37/50 - Train Loss: 0.0933 - Train Acc: 0.9662 - Val Loss: 0.3331 - Val Acc: 0.8958
# [Baseline] Epoch 38/50 - Train Loss: 0.0794 - Train Acc: 0.9711 - Val Loss: 0.3163 - Val Acc: 0.9122
# [Baseline] Epoch 39/50 - Train Loss: 0.0829 - Train Acc: 0.9709 - Val Loss: 0.3382 - Val Acc: 0.9180
# [Baseline] Epoch 40/50 - Train Loss: 0.0718 - Train Acc: 0.9736 - Val Loss: 0.2369 - Val Acc: 0.9274
# [Baseline] Epoch 41/50 - Train Loss: 0.0723 - Train Acc: 0.9747 - Val Loss: 0.2991 - Val Acc: 0.9180
# [Baseline] Epoch 42/50 - Train Loss: 0.0748 - Train Acc: 0.9731 - Val Loss: 0.2177 - Val Acc: 0.9368
# [Baseline] Epoch 43/50 - Train Loss: 0.0681 - Train Acc: 0.9767 - Val Loss: 0.2847 - Val Acc: 0.9215
# [Baseline] Epoch 44/50 - Train Loss: 0.0771 - Train Acc: 0.9720 - Val Loss: 0.2625 - Val Acc: 0.9309
# [Baseline] Epoch 45/50 - Train Loss: 0.0775 - Train Acc: 0.9728 - Val Loss: 0.2840 - Val Acc: 0.9239
# [Baseline] Epoch 46/50 - Train Loss: 0.0619 - Train Acc: 0.9777 - Val Loss: 0.2327 - Val Acc: 0.9309
# [Baseline] Epoch 47/50 - Train Loss: 0.0481 - Train Acc: 0.9822 - Val Loss: 0.3234 - Val Acc: 0.9145
# [Baseline] Epoch 48/50 - Train Loss: 0.0848 - Train Acc: 0.9731 - Val Loss: 0.3456 - Val Acc: 0.9087
# [Baseline] Epoch 49/50 - Train Loss: 0.0795 - Train Acc: 0.9698 - Val Loss: 0.2297 - Val Acc: 0.9286
# [Baseline] Epoch 50/50 - Train Loss: 0.0721 - Train Acc: 0.9739 - Val Loss: 0.3100 - Val Acc: 0.8946
# ✅ Saved baseline model to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/baseline_student/student_baseline_Td60_Tw20.pth
# /tmp/ipykernel_2377727/1032884115.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   student.load_state_dict(torch.load(best_model_path))

# %%
student_baseline.eval()
final_preds_b, final_labels_b = [], []
with torch.no_grad():
    for streams, labels in val_loader:
        streams = [s.to(device) for s in streams]
        labels = labels.to(device)
        outputs = student_baseline(streams)
        preds = torch.argmax(outputs, dim=1)
        final_preds_b.extend(preds.cpu().numpy())
        final_labels_b.extend(labels.cpu().numpy())
# === Plot
plot_loss_curve(train_losses_b, val_losses_b)
plot_accuracy_curve(train_accs_b, val_accs_b)
# Confusion matrix
cm_b = confusion_matrix(final_labels_b, final_preds_b)
plt.figure(figsize=(10, 8))
sns.heatmap(cm_b, annot=True, fmt='d', cmap='Greens',
            xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Baseline Student - Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.tight_layout()
plt.show()

# Report
print("\n📋 Baseline Classification Report (Student, No KD):\n")
print(classification_report(final_labels_b, final_preds_b, target_names=label_encoder.classes_))
print(f"✅ Final Training Accuracy (baseline): {train_accs_b[-1]:.4f}")
print(f"✅ Final Validation Accuracy (baseline): {val_accs_b[-1]:.4f}")
# Out:
# 📋 Baseline Classification Report (Student, No KD):
#
#               precision    recall  f1-score   support
#
#     AESCrypt       1.00      0.94      0.97       112
#       Cerber       0.89      0.93      0.91       249
#     Darkside       0.99      0.82      0.90       427
#        Excel       1.00      1.00      1.00       194
#      Firefox       0.98      0.96      0.97       271
#    GandCrab4       0.81      0.91      0.86       420
#         Ryuk       0.87      0.84      0.86       258
#      SDelete       0.97      1.00      0.99       103
#   Sodinokibi       0.93      0.96      0.94       271
#   TeslaCrypt       0.84      0.98      0.91       114
#     WannaCry       1.00      1.00      1.00       103
#          Zip       1.00      0.98      0.99       112
#
#     accuracy                           0.92      2634
#    macro avg       0.94      0.94      0.94      2634
# weighted avg       0.93      0.92      0.92      2634
#
# ✅ Final Training Accuracy (baseline): 0.9629
# ✅ Final Validation Accuracy (baseline): 0.9146

# %%
expected_shape = (CHUNK_SIZE, NUM_FEATURES)
X_test, y_test = load_split_from_folder(os.path.join(INPUT_DIR, "test"), expected_shape)
y_test_str = y_test

test_dataset = MultiStreamDataset(X_test, y_test_str, label_encoder, augment=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=collate_fn)

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# Rebuild same model architecture
model = StudentCNN(input_length=CHUNK_SIZE, num_classes=len(label_encoder.classes_))
model.load_state_dict(torch.load("best_student_baseline.pth"))
model.to(device)
model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for streams, labels in test_loader:
        # Move to device
        streams = [s.to(device) for s in streams]
        labels = labels.to(device)

        outputs = model(streams)
        preds = outputs.argmax(dim=1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

# Inverse-transform for reporting
pred_labels_str = label_encoder.inverse_transform(all_preds)
true_labels_str = label_encoder.inverse_transform(all_labels)

# === 5. Classification Report
print("=== 🧪 Final Test Set Classification Report ===")
print(classification_report(true_labels_str, pred_labels_str, digits=4))

# === 6. Seaborn Confusion Matrix
cm = confusion_matrix(true_labels_str, pred_labels_str, labels=label_encoder.classes_)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel("Predicted")
plt.ylabel("True Label")
plt.title("Seaborn Confusion Matrix (Test Set)")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3245880/952631451.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_student_baseline.pth"))
# === 🧪 Final Test Set Classification Report ===
#               precision    recall  f1-score   support
#
#     AESCrypt     1.0000    0.9732    0.9864       112
#       Cerber     0.9833    0.9592    0.9711       245
#     Darkside     0.9793    0.8873    0.9310       426
#        Excel     1.0000    0.9799    0.9899       249
#      Firefox     0.9771    0.9771    0.9771       262
#    GandCrab4     0.8252    0.9085    0.8648       426
#         Ryuk     0.8689    0.8657    0.8673       268
#      SDelete     0.9911    1.0000    0.9955       111
#   Sodinokibi     0.8989    0.8889    0.8939       270
#   TeslaCrypt     0.8205    0.8707    0.8449       147
#     WannaCry     0.9697    1.0000    0.9846       128
#          Zip     0.9825    0.9912    0.9868       113
#
#     accuracy                         0.9285      2757
#    macro avg     0.9414    0.9418    0.9411      2757
# weighted avg     0.9314    0.9285    0.9292      2757

# %% [markdown]
# ### Lightweight Measure student

# %%
# import torch
# import torch.nn as nn
# import time
# import os
# import psutil
# import copy
# from thop import profile

# # === Profiling functions using clean model copies ===
# def get_stream_macs_params(stream):
#     dummy_input = torch.randn(1, 1, CHUNK_SIZE)
#     stream_copy = copy.deepcopy(stream)
#     macs, params = profile(stream_copy, inputs=(dummy_input,), verbose=False)
#     return macs, params

# def get_linear_macs_params(layer, in_features):
#     dummy_input = torch.randn(1, in_features)
#     layer_copy = copy.deepcopy(layer)
#     macs, params = profile(layer_copy, inputs=(dummy_input,), verbose=False)
#     return macs, params

# # === Utility functions ===
# def get_model_size(model):
#     temp_path = "temp_model.pth"
#     torch.save(model.state_dict(), temp_path)
#     size_mb = os.path.getsize(temp_path) / (1024 ** 2)
#     os.remove(temp_path)
#     return size_mb

# def measure_latency(model, inputs, n_runs=100):
#     model.eval()
#     with torch.no_grad():
#         start = time.time()
#         for _ in range(n_runs):
#             model(inputs)
#         end = time.time()
#     return (end - start) / n_runs * 1000

# def measure_cpu_usage(model, inputs, duration=2):
#     model.eval()
#     process = psutil.Process(os.getpid())
#     num_cpus = psutil.cpu_count(logical=True)
#     _ = process.cpu_percent(interval=None)
#     with torch.no_grad():
#         start_time = time.time()
#         while time.time() - start_time < duration:
#             model(inputs)
#     total_cpu_percent = process.cpu_percent(interval=None)
#     return total_cpu_percent / num_cpus

# # === Final evaluation logic ===
# def evaluate_full_model(model_class, model_path, *args, **kwargs):
#     # 🔁 Create two fresh instances using passed args
#     prof_model = model_class(*args, **kwargs)
#     prof_model.load_state_dict(torch.load(model_path))
#     prof_model.eval()

#     clean_model = model_class(*args, **kwargs)
#     clean_model.load_state_dict(torch.load(model_path))
#     clean_model.eval()

#     total_macs, total_params = 0, 0

#     # 🔍 Stream MACs
#     print("🔍 Stream MAC breakdown:")
#     for i in range(8):
#         macs_i, params_i = get_stream_macs_params(prof_model.streams[i])
#         print(f"  Stream[{i}] MACs: {macs_i}, Params: {params_i}")
#         total_macs += macs_i
#         total_params += params_i

#     # 🔍 FC layers
#     print("\n🔍 FC Layer breakdown:")
#     macs_fc1, params_fc1 = get_linear_macs_params(prof_model.fc[0], in_features=64)
#     print(f"  FC[0] (64→128) MACs: {macs_fc1}, Params: {params_fc1}")
#     macs_fc2, params_fc2 = get_linear_macs_params(prof_model.fc[4], in_features=128)
#     print(f"  FC[4] (128→classes) MACs: {macs_fc2}, Params: {params_fc2}")
#     total_macs += macs_fc1 + macs_fc2
#     total_params += params_fc1 + params_fc2

#     # 🔍 Projection
#     print("\n🔍 Projection Layer:")
#     macs_proj, params_proj = get_linear_macs_params(prof_model.proj, in_features=64)
#     print(f"  Proj (64→128) MACs: {macs_proj}, Params: {params_proj}")
#     total_macs += macs_proj
#     total_params += params_proj


#     flops = 2 * total_macs
#     size_mb = get_model_size(clean_model)

#     dummy_inputs = [torch.randn(1, 1, CHUNK_SIZE) for _ in range(8)]
#     latency = measure_latency(clean_model, dummy_inputs)
#     cpu_usage = measure_cpu_usage(clean_model, dummy_inputs)

#     return {
#         "Model Size (MB)": round(size_mb, 4),
#         "Latency (ms)": round(latency, 3),
#         "CPU Usage (%)": round(cpu_usage, 2),
#         "Total MACs": int(total_macs),
#         "FLOPs": int(flops),
#         "Total Params": int(total_params)
#     }


# # === Usage ===
# # You must define your StudentCNN class and load the model first
# model = StudentCNN(input_length=CHUNK_SIZE, num_classes=len(label_encoder.classes_))
# model.load_state_dict(torch.load("best_student_baseline.pth"))
# # Then:
# #torch.save(model.state_dict(), "student_model.pth")
# stats = evaluate_full_model(StudentCNN, "best_student_baseline.pth", input_length=CHUNK_SIZE, num_classes=len(label_encoder.classes_))
# for k, v in stats.items():
#     print(f"{k}: {v}")
# Out:
# /tmp/ipykernel_3245880/3242020110.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("best_student_baseline.pth"))
# /tmp/ipykernel_3245880/3242020110.py:55: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   prof_model.load_state_dict(torch.load(model_path))
# /tmp/ipykernel_3245880/3242020110.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   clean_model.load_state_dict(torch.load(model_path))
# 🔍 Stream MAC breakdown:
#   Stream[0] MACs: 1864.0, Params: 120.0
#   Stream[1] MACs: 1864.0, Params: 120.0
#   Stream[2] MACs: 1864.0, Params: 120.0
#   Stream[3] MACs: 1864.0, Params: 120.0
#   Stream[4] MACs: 1864.0, Params: 120.0
#   Stream[5] MACs: 1864.0, Params: 120.0
#   Stream[6] MACs: 1864.0, Params: 120.0
#   Stream[7] MACs: 1864.0, Params: 120.0
#
# 🔍 FC Layer breakdown:
#   FC[0] (64→128) MACs: 8192.0, Params: 0
#   FC[4] (128→classes) MACs: 1536.0, Params: 0
#
# 🔍 Projection Layer:
#   Proj (64→128) MACs: 8192.0, Params: 0
# Model Size (MB): 0.0867
# Latency (ms): 2.31
# CPU Usage (%): 35.61
# Total MACs: 32832
# FLOPs: 65664
# Total Params: 960

# %%
# import shap
# import torch
# import torch.nn as nn
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd

# # ===== 1. Load model =====
# model.eval()
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# # ===== 2. Load data batch =====
# streams, labels = next(iter(test_loader))
# sample_batch = [s.to(device) for s in streams]

# def batch_to_shap_input(batch):
#     return torch.cat(batch, dim=1)

# shap_input_full = batch_to_shap_input(sample_batch)  # [B,8,T]
# shap_input_full.requires_grad = True

# # ===== 3. Sample 100 examples randomly =====
# torch.manual_seed(42)
# np.random.seed(42)

# N = shap_input_full.shape[0]
# indices = np.random.choice(N, size=100)
# background_idx = indices[:30]
# test_idx = indices[30:]

# background = shap_input_full[background_idx]
# test_samples = shap_input_full[test_idx]

# # ===== 4. Wrapped model (return full logits) =====
# class MultiOutputWrapper(nn.Module):
#     def __init__(self, model):
#         super().__init__()
#         self.model = model

#     def forward(self, x):
#         split = [x[:, i:i+1, :] for i in range(x.size(1))]  # List of 8 [B,1,T]
#         return self.model(split)  # [B, num_classes]

# wrapped_model = MultiOutputWrapper(model).to(device)
# wrapped_model.eval()

# # ===== 5. Run GradientExplainer for all outputs =====
# explainer = shap.GradientExplainer(wrapped_model, background)
# shap_values = explainer.shap_values(test_samples)  # List of [B_test, 8, T] × num_classes

# # ===== 6. Global average over all classes =====
# num_classes = len(shap_values)
# num_streams = len(shap_values[0])  # Should be 8
# avg_importance = []

# for i in range(num_streams):
#     stream_total = 0.0
#     for c in range(num_classes):
#         stream_shap = shap_values[c][:, i, :]  # [B, T]
#         stream_total += np.abs(stream_shap).mean()
#     avg_importance.append(stream_total / num_classes)

# # ===== 7. Plot + Save Figure =====
# stream_names = ["T_write", "T_read", "V_write", "V_read", "H_write", "H_var", "SLR_write", "SLR_read"]

# # Sort and plot
# importance_df = pd.DataFrame({'Feature': stream_names, 'Importance': avg_importance})
# importance_df = importance_df.sort_values('Feature')  # Force fixed order

# plt.figure(figsize=(10, 6))
# plt.bar(importance_df['Feature'], importance_df['Importance'], width=0.6)
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.xticks(fontsize=12)
# plt.yticks(fontsize=12)
# plt.ylabel("Mean Absolute SHAP Value", fontsize=14)
# plt.xlabel("Feature Stream", fontsize=14)
# plt.title("Global SHAP Feature Importance Averaged Over All Classes", fontsize=16)
# plt.tight_layout()

# plt.savefig("global_avg_shap_per_stream.png", dpi=300)
# plt.savefig("global_avg_shap_per_stream.pdf")
# plt.show()

# print("✅ Saved global SHAP bar plot as PNG and PDF.")
# Out:
# ✅ Saved global SHAP bar plot as PNG and PDF.

# %%
# import matplotlib.pyplot as plt

# # ===== Pie Chart of SHAP Importance with External Legend =====
# plt.figure(figsize=(10, 6))
# stream_names = ["Write Throughput", "read Throughput", "Write Variance", "Read Variance", "Average Shannon Entropy", "Variance Shannon Entropy",
#                  "Write SLR", "Read SLR"]

# # Sort and plot
# importance_df = pd.DataFrame({'Feature': stream_names, 'Importance': avg_importance})
# # Keep original order based on stream_names
# importance_df = pd.DataFrame({'Feature': stream_names, 'Importance': avg_importance})
# colors = plt.cm.tab20.colors  # or any color palette you prefer

# # Create pie chart without labels
# wedges, texts, autotexts = plt.pie(
#     importance_df['Importance'], 
#     autopct='%1.1f%%',
#     startangle=140,
#     colors=colors[:len(importance_df)],
#     textprops={'fontsize': 12},
#     wedgeprops={'edgecolor': 'white'}
# )

# # Add legend outside the pie
# plt.legend(
#     wedges, 
#     importance_df['Feature'], 
#     # title="Feature Streams",
#     loc="center left",
#     bbox_to_anchor=(1, 0.5),
#     fontsize=12,
#     title_fontsize=14
# )

# # plt.title('Global SHAP Feature Importance per Stream', fontsize=16)
# plt.tight_layout()

# # Save the plot
# plt.savefig("global_avg_shap_pie_with_legend.png", dpi=300, bbox_inches="tight")
# plt.savefig("global_avg_shap_pie_with_legend.pdf", bbox_inches="tight")
# plt.show()

# print("✅ Pie chart with external legend saved as PNG and PDF.")
# Out:
# ✅ Pie chart with external legend saved as PNG and PDF.

# %%
# # ===== 0. First fix shap_values =====
# # shap_values: [70, 8, 51, 12]
# shap_values_split = [shap_values[..., i] for i in range(12)]  # List of 12 arrays [70, 8, 51]

# # ===== 1. Stack over classes =====
# shap_values_stack = np.stack(shap_values_split, axis=0)  # [12, 70, 8, 51]
# print("shap_values_stack.shape:", shap_values_stack.shape)  # Should now be (12, 70, 8, 51)

# # ===== 2. Average over time (axis=3)
# shap_values_avg_time = shap_values_stack.mean(axis=3)  # [12, 70, 8]
# print("shap_values_avg_time.shape:", shap_values_avg_time.shape)  # (12, 70, 8)

# # ===== 3. Average over classes (axis=0)
# shap_vals_flat = shap_values_avg_time.mean(axis=0)  # [70, 8]
# print("shap_vals_flat.shape:", shap_vals_flat.shape)  # ✅ (70, 8)

# # ===== 4. Feature values (inputs)
# features_flat = test_samples.detach().cpu().numpy().mean(axis=2)  # [70, 8]
# print("features_flat.shape:", features_flat.shape)  # ✅ (70, 8)

# # ===== 5. Plot
# stream_names = ["T_write", "T_read", "V_write", "V_read", "H_write", "H_var", "SLR_write", "SLR_read"]

# shap.summary_plot(
#     shap_vals_flat,
#     features_flat,
#     feature_names=stream_names,
#     plot_type="dot",
#     max_display=8,
#     show=False
# )

# plt.gcf().set_size_inches(10, 6)
# plt.tight_layout()
# plt.savefig("shap_beeswarm_streams.png", dpi=300, bbox_inches="tight")
# plt.savefig("shap_beeswarm_streams.pdf", bbox_inches="tight")
# plt.show()
# Out:
# shap_values_stack.shape: (12, 70, 8, 16)
# shap_values_avg_time.shape: (12, 70, 8)
# shap_vals_flat.shape: (70, 8)
# features_flat.shape: (70, 8)
# /tmp/ipykernel_3245880/1431495212.py:24: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(

# %%
import os
import torch
import pandas as pd
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader

# === CONFIGURATION ===
detection_times = [30, 45, 60]
window_sizes = [10, 15, 20]
NUM_FEATURES = 8
BATCH_SIZE = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

base_dir = "/home/HardDisk/Satang/thesis_proj/"
base_teacher_dir = os.path.join(base_dir, "Deep_Learning", "multi_cnn", "teacher")
student_kd_dir = os.path.join(base_dir, "Deep_Learning", "multi_cnn", "student")
student_baseline_dir = os.path.join(base_dir, "Deep_Learning", "multi_cnn", "baseline_student")
csv_output_path = os.path.join(base_dir, "Deep_Learning", "multi_cnn", "results", "model_eval_summary.csv")
os.makedirs(os.path.dirname(csv_output_path), exist_ok=True)

results = []

# === Evaluation Function ===
def evaluate_and_log(model, model_path, test_loader, label_encoder, T_d, T_w, model_type, results_list):
    model.load_state_dict(torch.load(model_path, map_location=DEVICE))
    model.to(DEVICE)
    model.eval()

    all_preds, all_labels = [], []
    with torch.no_grad():
        for streams, labels in test_loader:
            streams = [s.to(DEVICE) for s in streams]
            labels = labels.to(DEVICE)
            outputs = model(streams)
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    report = classification_report(all_labels, all_preds, target_names=label_encoder.classes_, output_dict=True)
    acc = accuracy_score(all_labels, all_preds)

    results_list.append({
        "Td": T_d,
        "Tw": T_w,
        "T_len": T_d - T_w + 1,
        "Model": model_type,
        "Accuracy": round(acc, 4),
        "Precision_macro": round(report["macro avg"]["precision"], 4),
        "Recall_macro": round(report["macro avg"]["recall"], 4),
        "F1_macro": round(report["macro avg"]["f1-score"], 4),
        "F1_weighted": round(report["weighted avg"]["f1-score"], 4),
    })

# === MAIN LOOP ===
for T_d in detection_times:
    for T_w in window_sizes:
        T_len = T_d - T_w + 1
        expected_shape = (T_len, NUM_FEATURES)
        folder_name = f"X_csv_split_{T_len}"
        test_path = os.path.join(base_dir, f"New_{T_d}", f"{T_w}", "split_tws", folder_name, "test")

        # === Load Test Data ===
        X_test_raw, y_test_raw = load_split_from_folder(test_path, expected_shape)
        label_encoder = LabelEncoder()
        label_encoder.fit(y_test_raw)

        test_dataset = MultiStreamDataset(X_test_raw, y_test_raw, label_encoder, augment=False)
        test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

        # === Teacher ===
        teacher_path = os.path.join(base_teacher_dir, f"teacher_Td{T_d}_Tw{T_w}.pth")
        teacher_model = MultiStreamCNN(input_length=T_len, num_classes=len(label_encoder.classes_))
        evaluate_and_log(teacher_model, teacher_path, test_loader, label_encoder, T_d, T_w, "Teacher", results)

        # === Student (KD) ===
        student_kd_path = os.path.join(student_kd_dir, f"student_KD_Td{T_d}_Tw{T_w}.pth")
        student_kd_model = StudentCNN(input_length=T_len, num_classes=len(label_encoder.classes_))
        evaluate_and_log(student_kd_model, student_kd_path, test_loader, label_encoder, T_d, T_w, "Student_KD", results)

        # === Student (Baseline) ===
        student_baseline_path = os.path.join(student_baseline_dir, f"student_baseline_Td{T_d}_Tw{T_w}.pth")
        student_baseline_model = StudentCNN(input_length=T_len, num_classes=len(label_encoder.classes_))
        evaluate_and_log(student_baseline_model, student_baseline_path, test_loader, label_encoder, T_d, T_w, "Student_Baseline", results)

# === Save Results ===
df_results = pd.DataFrame(results)
df_results.to_csv(csv_output_path, index=False)
print(f"\n✅ All evaluation results saved to: {csv_output_path}")
# Out:
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4254435440.py:26: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# ✅ All evaluation results saved to: /home/HardDisk/Satang/thesis_proj/Deep_Learning/multi_cnn/results/model_eval_summary.csv

# %%
import os
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader


# === CONFIG ===
base_dir = "/home/HardDisk/Satang/thesis_proj/"
teacher_dir = os.path.join(base_dir, "Deep_Learning", "multi_cnn", "teacher")
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
NUM_FEATURES = 8
BATCH_SIZE = 64
detection_times = [30, 45, 60]
window_sizes = [10, 15, 20]

conf_matrix_dict = {}

# === Load and Evaluate ===
for T_d in detection_times:
    for T_w in window_sizes:
        T_len = T_d - T_w + 1
        test_csv_path = os.path.join(base_dir, f"New_{T_d}", f"{T_w}", "split_tws", f"X_csv_split_{T_len}", "test")

        X_test, y_test = load_split_from_folder(test_csv_path, expected_shape=(T_len, NUM_FEATURES))
        label_encoder = LabelEncoder()
        y_test_encoded = label_encoder.fit_transform(y_test)

        test_dataset = MultiStreamDataset(X_test, y_test, label_encoder, augment=False)
        test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

        model_path = os.path.join(teacher_dir, f"teacher_Td{T_d}_Tw{T_w}.pth")
        model = MultiStreamCNN(input_length=T_len, num_classes=len(label_encoder.classes_))
        model.load_state_dict(torch.load(model_path, map_location=DEVICE))
        model.to(DEVICE)
        model.eval()

        all_preds, all_labels = [], []
        with torch.no_grad():
            for streams, labels in test_loader:
                streams = [s.to(DEVICE) for s in streams]
                outputs = model(streams)
                preds = outputs.argmax(dim=1)
                all_preds.extend(preds.cpu().numpy())
                all_labels.extend(labels.cpu().numpy())

        cm = confusion_matrix(all_labels, all_preds)
        conf_matrix_dict[(T_d, T_w)] = (cm, label_encoder.classes_)

# === Plot Beautiful Seaborn Grid ===
fig, axes = plt.subplots(3, 3, figsize=(18, 18))
fig.suptitle("Teacher Model Confusion Matrices", fontsize=24)

for i, Td in enumerate(detection_times):
    for j, Tw in enumerate(window_sizes):
        ax = axes[i, j]
        cm, class_names = conf_matrix_dict[(Td, Tw)]
        sns.heatmap(
            cm, annot=True, fmt='d', cmap='Blues', cbar=True, ax=ax,
            xticklabels=class_names, yticklabels=class_names,
            annot_kws={"size": 9}
        )
        ax.set_title(f"T_d={Td}, T_w={Tw}", fontsize=14)
        ax.tick_params(axis='x', labelrotation=45)
        ax.tick_params(axis='y', labelrotation=0)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig("teacher_confusion_matrices_beautiful.pdf", format="pdf", bbox_inches="tight", dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/4061706332.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))

# %%
import os
import torch
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from torch.utils.data import DataLoader

# === CONFIG ===
base_dir = "/home/HardDisk/Satang/thesis_proj/"
student_dirs = {
    "Student": os.path.join(base_dir, "Deep_Learning", "multi_cnn", "baseline_student"),
    "Student_KD": os.path.join(base_dir, "Deep_Learning", "multi_cnn", "student")
}
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
NUM_FEATURES = 8
BATCH_SIZE = 64
detection_times = [30, 45, 60]
window_sizes = [10, 15, 20]

# === EVALUATE & PLOT FUNCTION ===
def evaluate_and_plot(model_name, model_dir, output_pdf):
    conf_matrix_dict = {}

    for T_d in detection_times:
        for T_w in window_sizes:
            T_len = T_d - T_w + 1
            test_csv_path = os.path.join(base_dir, f"New_{T_d}", f"{T_w}", "split_tws", f"X_csv_split_{T_len}", "test")

            X_test, y_test = load_split_from_folder(test_csv_path, expected_shape=(T_len, NUM_FEATURES))
            label_encoder = LabelEncoder()
            y_test_encoded = label_encoder.fit_transform(y_test)

            test_dataset = MultiStreamDataset(X_test, y_test, label_encoder, augment=False)
            test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

            if model_name == "Student":
                model_prefix = "student_baseline"
            elif model_name == "Student_KD":
                model_prefix = "student_KD"
            else:
                raise ValueError("Unknown model name")

            model_path = os.path.join(model_dir, f"{model_prefix}_Td{T_d}_Tw{T_w}.pth")
            model = StudentCNN(input_length=T_len, num_classes=len(label_encoder.classes_))
            model.load_state_dict(torch.load(model_path, map_location=DEVICE))
            model.to(DEVICE)
            model.eval()

            all_preds, all_labels = [], []
            with torch.no_grad():
                for streams, labels in test_loader:
                    streams = [s.to(DEVICE) for s in streams]
                    outputs = model(streams)
                    preds = outputs.argmax(dim=1)
                    all_preds.extend(preds.cpu().numpy())
                    all_labels.extend(labels.cpu().numpy())

            cm = confusion_matrix(all_labels, all_preds)
            conf_matrix_dict[(T_d, T_w)] = (cm, label_encoder.classes_)

    # === Plot 3x3 ===
    fig, axes = plt.subplots(3, 3, figsize=(18, 18))
    fig.suptitle(f"{model_name} Model Confusion Matrices", fontsize=24)

    for i, Td in enumerate(detection_times):
        for j, Tw in enumerate(window_sizes):
            ax = axes[i, j]
            cm, class_names = conf_matrix_dict[(Td, Tw)]
            sns.heatmap(
                cm, annot=True, fmt='d', cmap='Blues', cbar=True, ax=ax,
                xticklabels=class_names, yticklabels=class_names,
                annot_kws={"size": 9}
            )
            ax.set_title(f"T_d={Td}, T_w={Tw}", fontsize=14)
            ax.tick_params(axis='x', labelrotation=45)
            ax.tick_params(axis='y', labelrotation=0)

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.savefig(output_pdf, format="pdf", bbox_inches="tight", dpi=300)
    plt.close()
    print(f"[✓] Saved {model_name} confusion matrix to {output_pdf}")

# === Run for both student models ===
evaluate_and_plot("Student", student_dirs["Student"], "student_confusion_matrices_beautiful.pdf")
evaluate_and_plot("Student_KD", student_dirs["Student_KD"], "student_kd_confusion_matrices_beautiful.pdf")
# Out:
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# [✓] Saved Student confusion matrix to student_confusion_matrices_beautiful.pdf
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# /tmp/ipykernel_2377727/1402582378.py:47: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path, map_location=DEVICE))
# [✓] Saved Student_KD confusion matrix to student_kd_confusion_matrices_beautiful.pdf
